# %% [markdown]
# # SOILGRIDS checks
# We've been having quite a lot of problems with this data set. This script loops over all the subset maps and compares their sizes, to ensure we have the same grids for every part of the data set. If there's a mismatch, files are regridded to the most common grid size in this basin.

# %%
from collections import defaultdict
import glob
import numpy as np
import os
import pandas as pd
import rasterio
from rasterio.enums import Resampling
import shutil
import sys
from pathlib import Path
sys.path.append(str(Path().absolute().parent))
import python_cs_functions as cs

# %% [markdown]
# ### Config handling

# %%
# Specify where the config file can be found
config_file = '../0_config/config.txt'

# Get the required info from the config file
data_path = cs.read_from_config(config_file,'data_path')

# CAMELS-spat metadata
cs_meta_path = cs.read_from_config(config_file,'cs_basin_path')
cs_meta_name = cs.read_from_config(config_file,'cs_meta_name')
cs_unusable_name = cs.read_from_config(config_file,'cs_unusable_name')

# Basin folder
cs_basin_folder = cs.read_from_config(config_file, 'cs_basin_path')
basins_path = Path(data_path) / cs_basin_folder

# %% [markdown]
# ### Data loading

# %%
# CAMELS-spat metadata file
cs_meta_path = Path(data_path) / cs_meta_path
cs_meta = pd.read_csv(cs_meta_path / cs_meta_name)

# Open list of unusable stations; Enforce reading IDs as string to keep leading 0's
cs_unusable = pd.read_csv(cs_meta_path / cs_unusable_name, dtype={'Station_id': object})

# %% [markdown]
# ### Check that we actually have all files we expect

# %%
# Define the soilgrids folder
sub_folders = ['bdod','cfvo','clay','sand','silt','soc']

# %%
# Check if we have allt he files we expect
for ix,row in cs_meta.iterrows():
    basin_id = row['Country'] + '_' + row['Station_id']
    soil_folder = basins_path / 'basin_data' / basin_id / 'geospatial' / 'soilgrids' / 'raw'
    tif_files = []
    for sub_folder in sub_folders:
        tif_files.append(glob.glob( str( soil_folder / sub_folder / '*.tif' ) ))
    tif_files = [file for files in tif_files for file in files] # flattens
    assert len(tif_files) == 180, f'Files missing for basin {basin_id}'
print('All expected files found.')
# Out:
# All expected files found.

# %% [markdown]
# We have all the expected files. Now check if they have the right size.

# %% [markdown]
# ### Check that all files for a given basin have the same grid size and regrid if not

# %% [markdown]
# #### Functions we need for this

# %%
def get_raster_size(file_paths):
    '''Extracts the raster sizes for a list of geotiffs'''
    size_counts = defaultdict(int)
    file_sizes = {}
    for file_path in file_paths:
        with rasterio.open(file_path) as src:
            width = src.width
            height = src.height
            size = (height, width)
            size_counts[size] += 1
            file_sizes[file_path] = size

    return file_paths,file_sizes,size_counts

# %%
def check_if_regrid_needed(file_paths,file_sizes,size_counts,disp_individual=True):
    '''Checks if the outcomes of get_raster_size() are identical and flags if not'''   
    if len(size_counts) == 1:
        print("All files have the same raster size:", next(iter(size_counts)))
        needs_regrid = False
    else:
        print("Files have different raster sizes:")
        needs_regrid = True
        for size, count in size_counts.items():
            print(f"Size {size} occurs {count} times")

        if disp_individual:
            print("\nIndividual file sizes:")
            for file_path, size in file_sizes.items():
                print(f"File {file_path:<150} : {size}")

    return needs_regrid

# %%
def get_most_common_profile(sizes,most_common):
    '''Extracts the GeoTIFF profile from a file that matches the most common size (H,W) across all files'''
    for path,size in sizes.items():
        if size == most_common:
            with rasterio.open(path, 'r') as src:
                return src.profile

# %%
def get_most_common_nodata_mask(sizes,most_common):
    '''Extracts the data as a masked array from a file that matches the most common size (H,W) across all files'''
    for path,size in sizes.items():
        if size == most_common:
            with rasterio.open(path, 'r') as src:
                return np.ma.masked_equal(src.read(), src.nodata)

# %%
def extract_edges(arr):
    '''Extracts the values along the edges of a 3D matrix, assuming that size of dimension 1 is 1.'''
    if arr.shape[0] != 1:
        raise ValueError("The first dimension of the array assumed to have size 1.")
    
    # Extract the edges
    top_edge = arr[:, 0, :]        # First row
    bottom_edge = arr[:, -1, :]    # Last row
    left_edge = arr[:, :, 0]       # First column
    right_edge = arr[:, :, -1]     # Last column

    return top_edge, bottom_edge, left_edge, right_edge

# %%
def update_geotiff_nodata_value(input_file):
    '''Sets the nodata value of an existing GeoTIFF file to the most common value found along the data's edges'''
    with rasterio.open(input_file, 'r+') as src:
        # Current values
        data = src.read()
        current_nodata = src.nodata

        # Check if the values on the edges and find most likely nodata value
        top,bottom,left,right = extract_edges(data)
        edge_values = np.concatenate(
            (top.flatten()[1:],
             bottom.flatten()[1:],
             left.flatten()[1:],
             right.flatten()[1:])
            ) # [1:] so we don't double-count the corners
        edge_uniques,edge_counts = np.unique(edge_values, return_counts=True)
        likely_nodata = edge_uniques[np.argmax(edge_counts)]

        # Compare and update
        if likely_nodata != current_nodata:
            print(f'Setting nodata to {likely_nodata} instead of {current_nodata} in {input_file}')
            src.nodata = likely_nodata

    return likely_nodata,current_nodata

# %%
def regrid_geotiff(input_file, output_file, new_height, new_width, nodata_template, profile_template):

    # In some of the files we had to obtain later the nodata value is
    # set correctly to -32768, but the actual nodata cells are set to
    # 0 (or maybe something else). Here we check the edges of the matrix
    # under the assumption that the edges should be mostly nodata values
    # and set the file's nodata value to whatever that is. 
    # This prevents issues with interpolation in the next step, where a
    # basin bordered by 0s will interpolate differently along its 
    # boundary than a basin bordered by nodata values will.    
    new_nodata,old_nodata = update_geotiff_nodata_value(input_file)
    
    # Resample the raster to the desired size
    with rasterio.open(input_file) as src:
        data = src.read(
            out_shape=(src.count, new_height, new_width),
            resampling=Resampling.bilinear
        )
        profile = src.profile

    # Update the profile with the new (correct) transform and nodata values.
    # The benefit of doing this over simply writing the new geotiff with the
    # template profile is that we keep things like datatype intact.
    profile['width'] = new_width
    profile['height'] = new_height
    profile['transform'] = profile_template['transform']
    
    # Apply the nodata mask. This ensures that the interpolated data has
    # the same internal and external nodata gaps as the other files have.
    if new_nodata != old_nodata:
        if profile['dtype'] == 'int16': # e.g. clay, sand, silt
            profile['nodata'] = -32768 # Found empirically by checking existing files
        elif profile['dtype'] == 'uint16': # e.g. bdod
            profile['nodata'] = 65535 # Found empirically by checking existing files
        
    data[nodata_template.mask] = profile['nodata'] # This is where we have known nodata

    # It may be that we replaced actual data values with nodata in the first
    # step (update_geotiff_value()). Here we check if there are any nodata
    # values in the regridded matrix that do not appear in our template nodata
    # mask, and set those cells back to their original value.
    if old_nodata is not None:
        data[(data == profile['nodata']) & (~nodata_template.mask)] =  old_nodata
        
    # Write the resampled data to a new GeoTIFF file
    with rasterio.open(output_file, 'w', **profile) as dst:
        dst.write(data)

# %% [markdown]
# #### Processing

# %%
# Loop over all basins
for ix,row in cs_meta.iterrows():

    # Get the basin ID
    basin_id = row['Country'] + '_' + row['Station_id']

    # Find the folder and files
    soil_folder = basins_path / 'basin_data' / basin_id / 'geospatial' / 'soilgrids' / 'raw'
    tif_files = []
    for sub_folder in sub_folders:
        tif_files.append(glob.glob( str( soil_folder / sub_folder / '*.tif' ) ))
        
    tif_files = [file for files in tif_files for file in files] # flattens
    tif_files = sorted(tif_files) # doesn't matter, but cleaner when looking at logs

    # Loop over the files and extract the raster sizes
    paths,sizes,counts = get_raster_size(tif_files)

    # Regrid if needed
    if check_if_regrid_needed(paths,sizes,counts, disp_individual = False):

        # Progress
        print(f' - {basin_id} regridding starting.')
    
        # Create a backup folder
        shutil.copytree(soil_folder, soil_folder.parent / 'raw_backup')
        
        # Get the most common size
        most_common = max(counts, key=counts.get) # (height, width)
    
        # Get the associated GeoTIFF profile
        template_profile = get_most_common_profile(sizes, most_common)
    
        # Get the nodata mask, to fix those geotiffs that don't have proper nodata values set
        template_masked_array = get_most_common_nodata_mask(sizes,most_common)
    
        # Loop over the files and regrid if needed
        for path,size in sizes.items():
            if size != most_common:
                regrid_geotiff(path, path, most_common[0], most_common[1], template_masked_array, template_profile)

        # progress
        print(f'   {basin_id} regridding complete.')

    else:
        print(f' - {basin_id} OK as is.')
# Out:
# Files have different raster sizes:
# Size (814, 1037) occurs 60 times
# Size (815, 1038) occurs 120 times
#  - CAN_01AD002 regridding starting.
#    CAN_01AD002 regridding complete.
# All files have the same raster size: (283, 227)
#  - CAN_01AD003 OK as is.
# All files have the same raster size: (274, 393)
#  - CAN_01AE001 OK as is.
# Files have different raster sizes:
# Size (112, 175) occurs 60 times
# Size (112, 176) occurs 120 times
#  - CAN_01AF007 regridding starting.
#    CAN_01AF007 regridding complete.
# Files have different raster sizes:
# Size (102, 70) occurs 60 times
# Size (102, 69) occurs 120 times
#  - CAN_01AF009 regridding starting.
#    CAN_01AF009 regridding complete.
# Files have different raster sizes:
# Size (246, 206) occurs 60 times
# Size (247, 207) occurs 120 times
#  - CAN_01AJ003 regridding starting.
#    CAN_01AJ003 regridding complete.
# Files have different raster sizes:
# Size (167, 124) occurs 60 times
# Size (167, 125) occurs 120 times
#  - CAN_01AJ004 regridding starting.
#    CAN_01AJ004 regridding complete.
# Files have different raster sizes:
# Size (108, 139) occurs 60 times
# Size (108, 138) occurs 120 times
#  - CAN_01AJ010 regridding starting.
#    CAN_01AJ010 regridding complete.
# Files have different raster sizes:
# Size (99, 97) occurs 60 times
# Size (99, 98) occurs 120 times
#  - CAN_01AK001 regridding starting.
#    CAN_01AK001 regridding complete.
# All files have the same raster size: (18, 21)
#  - CAN_01AK006 OK as is.
# All files have the same raster size: (99, 104)
#  - CAN_01AK007 OK as is.
# Files have different raster sizes:
# Size (172, 378) occurs 60 times
# Size (172, 377) occurs 120 times
#  - CAN_01AL002 regridding starting.
#    CAN_01AL002 regridding complete.
# Files have different raster sizes:
# Size (9, 13) occurs 60 times
# Size (9, 12) occurs 120 times
#  - CAN_01AL004 regridding starting.
#    CAN_01AL004 regridding complete.
# All files have the same raster size: (123, 180)
#  - CAN_01AM001 OK as is.
# All files have the same raster size: (151, 267)
#  - CAN_01AN002 OK as is.
# All files have the same raster size: (161, 171)
#  - CAN_01AP002 OK as is.
# Files have different raster sizes:
# Size (162, 250) occurs 60 times
# Size (161, 251) occurs 120 times
#  - CAN_01AP004 regridding starting.
#    CAN_01AP004 regridding complete.
# All files have the same raster size: (88, 113)
#  - CAN_01AP006 OK as is.
# Files have different raster sizes:
# Size (113, 131) occurs 60 times
# Size (114, 130) occurs 120 times
#  - CAN_01AQ001 regridding starting.
#    CAN_01AQ001 regridding complete.
# All files have the same raster size: (382, 462)
#  - CAN_01BC001 OK as is.
# Files have different raster sizes:
# Size (106, 209) occurs 60 times
# Size (106, 210) occurs 120 times
#  - CAN_01BD008 regridding starting.
#    CAN_01BD008 regridding complete.
# Files have different raster sizes:
# Size (193, 413) occurs 60 times
# Size (192, 412) occurs 120 times
#  - CAN_01BE001 regridding starting.
#    CAN_01BE001 regridding complete.
# Files have different raster sizes:
# Size (198, 381) occurs 60 times
# Size (197, 381) occurs 120 times
#  - CAN_01BG005 regridding starting.
#    CAN_01BG005 regridding complete.
# Files have different raster sizes:
# Size (309, 206) occurs 60 times
# Size (309, 205) occurs 120 times
#  - CAN_01BG008 regridding starting.
#    CAN_01BG008 regridding complete.
# Files have different raster sizes:
# Size (324, 270) occurs 60 times
# Size (325, 269) occurs 120 times
#  - CAN_01BG009 regridding starting.
#    CAN_01BG009 regridding complete.
# Files have different raster sizes:
# Size (146, 221) occurs 60 times
# Size (146, 220) occurs 120 times
#  - CAN_01BH005 regridding starting.
#    CAN_01BH005 regridding complete.
# All files have the same raster size: (132, 297)
#  - CAN_01BH010 OK as is.
# All files have the same raster size: (114, 227)
#  - CAN_01BJ003 OK as is.
# Files have different raster sizes:
# Size (433, 862) occurs 60 times
# Size (432, 862) occurs 120 times
#  - CAN_01BJ007 regridding starting.
#    CAN_01BJ007 regridding complete.
# Files have different raster sizes:
# Size (60, 200) occurs 60 times
# Size (61, 200) occurs 120 times
#  - CAN_01BJ010 regridding starting.
#    CAN_01BJ010 regridding complete.
# All files have the same raster size: (41, 85)
#  - CAN_01BJ012 OK as is.
# Files have different raster sizes:
# Size (65, 109) occurs 60 times
# Size (65, 110) occurs 120 times
#  - CAN_01BL002 regridding starting.
#    CAN_01BL002 regridding complete.
# Files have different raster sizes:
# Size (96, 180) occurs 60 times
# Size (96, 179) occurs 120 times
#  - CAN_01BL003 regridding starting.
#    CAN_01BL003 regridding complete.
# All files have the same raster size: (324, 868)
#  - CAN_01BO001 OK as is.
# Files have different raster sizes:
# Size (176, 422) occurs 60 times
# Size (176, 421) occurs 120 times
#  - CAN_01BP001 regridding starting.
#    CAN_01BP001 regridding complete.
# All files have the same raster size: (20, 62)
#  - CAN_01BP002 OK as is.
# Files have different raster sizes:
# Size (124, 385) occurs 60 times
# Size (124, 386) occurs 120 times
#  - CAN_01BQ001 regridding starting.
#    CAN_01BQ001 regridding complete.
# All files have the same raster size: (77, 126)
#  - CAN_01BS001 OK as is.
# Files have different raster sizes:
# Size (162, 212) occurs 60 times
# Size (163, 212) occurs 120 times
#  - CAN_01BU002 regridding starting.
#    CAN_01BU002 regridding complete.
# Files have different raster sizes:
# Size (14, 16) occurs 60 times
# Size (15, 17) occurs 120 times
#  - CAN_01BU009 regridding starting.
#    CAN_01BU009 regridding complete.
# Files have different raster sizes:
# Size (31, 62) occurs 60 times
# Size (31, 63) occurs 120 times
#  - CAN_01BV004 regridding starting.
#    CAN_01BV004 regridding complete.
# Files have different raster sizes:
# Size (53, 115) occurs 60 times
# Size (54, 115) occurs 120 times
#  - CAN_01BV006 regridding starting.
#    CAN_01BV006 regridding complete.
# All files have the same raster size: (32, 67)
#  - CAN_01CA003 OK as is.
# Files have different raster sizes:
# Size (48, 61) occurs 60 times
# Size (48, 60) occurs 120 times
#  - CAN_01CC005 regridding starting.
#    CAN_01CC005 regridding complete.
# Files have different raster sizes:
# Size (31, 22) occurs 60 times
# Size (30, 21) occurs 120 times
#  - CAN_01CD005 regridding starting.
#    CAN_01CD005 regridding complete.
# Files have different raster sizes:
# Size (66, 60) occurs 60 times
# Size (65, 60) occurs 120 times
#  - CAN_01DG003 regridding starting.
#    CAN_01DG003 regridding complete.
# All files have the same raster size: (61, 55)
#  - CAN_01DJ005 OK as is.
# Files have different raster sizes:
# Size (49, 59) occurs 60 times
# Size (50, 58) occurs 120 times
#  - CAN_01DL001 regridding starting.
#    CAN_01DL001 regridding complete.
# Files have different raster sizes:
# Size (55, 64) occurs 60 times
# Size (56, 64) occurs 120 times
#  - CAN_01DP004 regridding starting.
#    CAN_01DP004 regridding complete.
# Files have different raster sizes:
# Size (93, 94) occurs 60 times
# Size (93, 93) occurs 120 times
#  - CAN_01DR001 regridding starting.
#    CAN_01DR001 regridding complete.
# Files have different raster sizes:
# Size (186, 129) occurs 60 times
# Size (186, 130) occurs 120 times
#  - CAN_01EC001 regridding starting.
#    CAN_01EC001 regridding complete.
# All files have the same raster size: (166, 180)
#  - CAN_01ED005 OK as is.
# Files have different raster sizes:
# Size (107, 135) occurs 60 times
# Size (106, 136) occurs 120 times
#  - CAN_01ED007 regridding starting.
#    CAN_01ED007 regridding complete.
# Files have different raster sizes:
# Size (27, 26) occurs 60 times
# Size (27, 25) occurs 120 times
#  - CAN_01EE005 regridding starting.
#    CAN_01EE005 regridding complete.
# Files have different raster sizes:
# Size (205, 217) occurs 60 times
# Size (205, 218) occurs 120 times
#  - CAN_01EF001 regridding starting.
#    CAN_01EF001 regridding complete.
# Files have different raster sizes:
# Size (167, 419) occurs 60 times
# Size (167, 418) occurs 120 times
#  - CAN_01EO001 regridding starting.
#    CAN_01EO001 regridding complete.
# Files have different raster sizes:
# Size (79, 104) occurs 60 times
# Size (78, 103) occurs 120 times
#  - CAN_01FA001 regridding starting.
#    CAN_01FA001 regridding complete.
# Files have different raster sizes:
# Size (122, 140) occurs 60 times
# Size (122, 139) occurs 120 times
#  - CAN_01FB001 regridding starting.
#    CAN_01FB001 regridding complete.
# Files have different raster sizes:
# Size (106, 160) occurs 60 times
# Size (106, 161) occurs 120 times
#  - CAN_01FB003 regridding starting.
#    CAN_01FB003 regridding complete.
# Files have different raster sizes:
# Size (16, 48) occurs 60 times
# Size (16, 49) occurs 120 times
#  - CAN_01FJ002 regridding starting.
#    CAN_01FJ002 regridding complete.
# All files have the same raster size: (77, 99)
#  - CAN_02AB008 OK as is.
# Files have different raster sizes:
# Size (76, 74) occurs 60 times
# Size (76, 75) occurs 120 times
#  - CAN_02AB014 regridding starting.
#    CAN_02AB014 regridding complete.
# All files have the same raster size: (62, 126)
#  - CAN_02AB017 OK as is.
# Files have different raster sizes:
# Size (124, 178) occurs 60 times
# Size (125, 178) occurs 120 times
#  - CAN_02AB021 regridding starting.
#    CAN_02AB021 regridding complete.
# Files have different raster sizes:
# Size (158, 180) occurs 60 times
# Size (158, 179) occurs 120 times
#  - CAN_02AC001 regridding starting.
#    CAN_02AC001 regridding complete.
# All files have the same raster size: (295, 460)
#  - CAN_02AC002 OK as is.
# All files have the same raster size: (120, 295)
#  - CAN_02AD010 OK as is.
# Files have different raster sizes:
# Size (214, 229) occurs 60 times
# Size (214, 228) occurs 120 times
#  - CAN_02AE001 regridding starting.
#    CAN_02AE001 regridding complete.
# All files have the same raster size: (305, 254)
#  - CAN_02BA003 OK as is.
# Files have different raster sizes:
# Size (17, 29) occurs 60 times
# Size (18, 28) occurs 120 times
#  - CAN_02BA005 regridding starting.
#    CAN_02BA005 regridding complete.
# Files have different raster sizes:
# Size (477, 563) occurs 60 times
# Size (477, 562) occurs 120 times
#  - CAN_02BB003 regridding starting.
#    CAN_02BB003 regridding complete.
# All files have the same raster size: (187, 520)
#  - CAN_02BF001 OK as is.
# All files have the same raster size: (216, 245)
#  - CAN_02BF002 OK as is.
# Files have different raster sizes:
# Size (46, 53) occurs 60 times
# Size (47, 54) occurs 120 times
#  - CAN_02BF004 regridding starting.
#    CAN_02BF004 regridding complete.
# All files have the same raster size: (18, 25)
#  - CAN_02BF005 OK as is.
# All files have the same raster size: (18, 25)
#  - CAN_02BF006 OK as is.
# Files have different raster sizes:
# Size (18, 16) occurs 60 times
# Size (18, 15) occurs 120 times
#  - CAN_02BF007 regridding starting.
#    CAN_02BF007 regridding complete.
# Files have different raster sizes:
# Size (13, 13) occurs 60 times
# Size (14, 12) occurs 120 times
#  - CAN_02BF008 regridding starting.
#    CAN_02BF008 regridding complete.
# All files have the same raster size: (8, 12)
#  - CAN_02BF009 OK as is.
# All files have the same raster size: (6, 8)
#  - CAN_02BF012 OK as is.
# All files have the same raster size: (4, 6)
#  - CAN_02BF013 OK as is.
# Files have different raster sizes:
# Size (50, 62) occurs 60 times
# Size (50, 63) occurs 120 times
#  - CAN_02CA002 regridding starting.
#    CAN_02CA002 regridding complete.
# Files have different raster sizes:
# Size (256, 198) occurs 60 times
# Size (256, 199) occurs 120 times
#  - CAN_02CB003 regridding starting.
#    CAN_02CB003 regridding complete.
# Files have different raster sizes:
# Size (70, 184) occurs 60 times
# Size (70, 183) occurs 120 times
#  - CAN_02CF007 regridding starting.
#    CAN_02CF007 regridding complete.
# All files have the same raster size: (70, 112)
#  - CAN_02CF008 OK as is.
# Files have different raster sizes:
# Size (234, 208) occurs 60 times
# Size (235, 207) occurs 120 times
#  - CAN_02CF011 regridding starting.
#    CAN_02CF011 regridding complete.
# Files have different raster sizes:
# Size (26, 26) occurs 60 times
# Size (27, 27) occurs 120 times
#  - CAN_02CG003 regridding starting.
#    CAN_02CG003 regridding complete.
# All files have the same raster size: (53, 67)
#  - CAN_02DB007 OK as is.
# Files have different raster sizes:
# Size (267, 254) occurs 60 times
# Size (267, 255) occurs 120 times
#  - CAN_02DC012 regridding starting.
#    CAN_02DC012 regridding complete.
# Files have different raster sizes:
# Size (157, 297) occurs 60 times
# Size (156, 296) occurs 120 times
#  - CAN_02DD012 regridding starting.
#    CAN_02DD012 regridding complete.
# All files have the same raster size: (49, 94)
#  - CAN_02DD013 OK as is.
# All files have the same raster size: (86, 56)
#  - CAN_02DD015 OK as is.
# Files have different raster sizes:
# Size (116, 139) occurs 60 times
# Size (115, 138) occurs 120 times
#  - CAN_02EA005 regridding starting.
#    CAN_02EA005 regridding complete.
# Files have different raster sizes:
# Size (75, 115) occurs 60 times
# Size (74, 115) occurs 120 times
#  - CAN_02EA010 regridding starting.
#    CAN_02EA010 regridding complete.
# Files have different raster sizes:
# Size (177, 201) occurs 60 times
# Size (178, 201) occurs 120 times
#  - CAN_02EB014 regridding starting.
#    CAN_02EB014 regridding complete.
# Files have different raster sizes:
# Size (293, 231) occurs 60 times
# Size (292, 231) occurs 120 times
#  - CAN_02EC002 regridding starting.
#    CAN_02EC002 regridding complete.
# Files have different raster sizes:
# Size (30, 49) occurs 60 times
# Size (31, 50) occurs 120 times
#  - CAN_02EC010 regridding starting.
#    CAN_02EC010 regridding complete.
# All files have the same raster size: (158, 82)
#  - CAN_02EC011 OK as is.
# Files have different raster sizes:
# Size (112, 106) occurs 60 times
# Size (112, 105) occurs 120 times
#  - CAN_02EC018 regridding starting.
#    CAN_02EC018 regridding complete.
# All files have the same raster size: (176, 310)
#  - CAN_02ED003 OK as is.
# All files have the same raster size: (91, 78)
#  - CAN_02ED007 OK as is.
# Files have different raster sizes:
# Size (52, 93) occurs 60 times
# Size (52, 92) occurs 120 times
#  - CAN_02ED013 regridding starting.
#    CAN_02ED013 regridding complete.
# Files have different raster sizes:
# Size (69, 142) occurs 60 times
# Size (70, 143) occurs 120 times
#  - CAN_02ED014 regridding starting.
#    CAN_02ED014 regridding complete.
# Files have different raster sizes:
# Size (81, 121) occurs 60 times
# Size (80, 122) occurs 120 times
#  - CAN_02ED015 regridding starting.
#    CAN_02ED015 regridding complete.
# Files have different raster sizes:
# Size (47, 49) occurs 60 times
# Size (47, 50) occurs 120 times
#  - CAN_02ED017 regridding starting.
#    CAN_02ED017 regridding complete.
# All files have the same raster size: (107, 80)
#  - CAN_02ED024 OK as is.
# Files have different raster sizes:
# Size (59, 108) occurs 60 times
# Size (59, 109) occurs 120 times
#  - CAN_02ED026 regridding starting.
#    CAN_02ED026 regridding complete.
# Files have different raster sizes:
# Size (90, 144) occurs 60 times
# Size (90, 145) occurs 120 times
#  - CAN_02ED101 regridding starting.
#    CAN_02ED101 regridding complete.
# Files have different raster sizes:
# Size (70, 175) occurs 60 times
# Size (69, 175) occurs 120 times
#  - CAN_02ED102 regridding starting.
#    CAN_02ED102 regridding complete.
# All files have the same raster size: (39, 45)
#  - CAN_02FA002 OK as is.
# Files have different raster sizes:
# Size (101, 128) occurs 60 times
# Size (100, 128) occurs 120 times
#  - CAN_02FA004 regridding starting.
#    CAN_02FA004 regridding complete.
# Files have different raster sizes:
# Size (69, 89) occurs 60 times
# Size (70, 88) occurs 120 times
#  - CAN_02FB007 regridding starting.
#    CAN_02FB007 regridding complete.
# Files have different raster sizes:
# Size (97, 131) occurs 60 times
# Size (98, 132) occurs 120 times
#  - CAN_02FB010 regridding starting.
#    CAN_02FB010 regridding complete.
# Files have different raster sizes:
# Size (87, 118) occurs 60 times
# Size (87, 117) occurs 120 times
#  - CAN_02FC011 regridding starting.
#    CAN_02FC011 regridding complete.
# Files have different raster sizes:
# Size (77, 206) occurs 60 times
# Size (78, 207) occurs 120 times
#  - CAN_02FC016 regridding starting.
#    CAN_02FC016 regridding complete.
# Files have different raster sizes:
# Size (49, 61) occurs 60 times
# Size (48, 60) occurs 120 times
#  - CAN_02FC017 regridding starting.
#    CAN_02FC017 regridding complete.
# All files have the same raster size: (48, 118)
#  - CAN_02FD001 OK as is.
# All files have the same raster size: (58, 66)
#  - CAN_02FD002 OK as is.
# All files have the same raster size: (134, 262)
#  - CAN_02FE008 OK as is.
# All files have the same raster size: (97, 148)
#  - CAN_02FE009 OK as is.
# Files have different raster sizes:
# Size (49, 109) occurs 60 times
# Size (50, 108) occurs 120 times
#  - CAN_02FE011 regridding starting.
#    CAN_02FE011 regridding complete.
# Files have different raster sizes:
# Size (124, 167) occurs 60 times
# Size (123, 168) occurs 120 times
#  - CAN_02FE013 regridding starting.
#    CAN_02FE013 regridding complete.
# Files have different raster sizes:
# Size (43, 78) occurs 60 times
# Size (42, 77) occurs 120 times
#  - CAN_02FE014 regridding starting.
#    CAN_02FE014 regridding complete.
# Files have different raster sizes:
# Size (30, 56) occurs 60 times
# Size (31, 55) occurs 120 times
#  - CAN_02FF004 regridding starting.
#    CAN_02FF004 regridding complete.
# Files have different raster sizes:
# Size (94, 196) occurs 60 times
# Size (93, 196) occurs 120 times
#  - CAN_02FF007 regridding starting.
#    CAN_02FF007 regridding complete.
# Files have different raster sizes:
# Size (106, 46) occurs 60 times
# Size (106, 45) occurs 120 times
#  - CAN_02FF008 regridding starting.
#    CAN_02FF008 regridding complete.
# Files have different raster sizes:
# Size (235, 268) occurs 60 times
# Size (234, 267) occurs 120 times
#  - CAN_02GA010 regridding starting.
#    CAN_02GA010 regridding complete.
# Files have different raster sizes:
# Size (160, 142) occurs 60 times
# Size (159, 142) occurs 120 times
#  - CAN_02GA018 regridding starting.
#    CAN_02GA018 regridding complete.
# Files have different raster sizes:
# Size (107, 99) occurs 60 times
# Size (106, 98) occurs 120 times
#  - CAN_02GA038 regridding starting.
#    CAN_02GA038 regridding complete.
# All files have the same raster size: (47, 54)
#  - CAN_02GA041 OK as is.
# All files have the same raster size: (21, 23)
#  - CAN_02GA043 OK as is.
# Files have different raster sizes:
# Size (128, 113) occurs 60 times
# Size (129, 114) occurs 120 times
#  - CAN_02GB007 regridding starting.
#    CAN_02GB007 regridding complete.
# All files have the same raster size: (76, 206)
#  - CAN_02GC002 OK as is.
# Files have different raster sizes:
# Size (86, 150) occurs 60 times
# Size (86, 151) occurs 120 times
#  - CAN_02GC010 regridding starting.
#    CAN_02GC010 regridding complete.
# Files have different raster sizes:
# Size (76, 161) occurs 60 times
# Size (77, 162) occurs 120 times
#  - CAN_02GC018 regridding starting.
#    CAN_02GC018 regridding complete.
# All files have the same raster size: (71, 47)
#  - CAN_02GC021 OK as is.
# Files have different raster sizes:
# Size (49, 129) occurs 60 times
# Size (49, 128) occurs 120 times
#  - CAN_02GC029 regridding starting.
#    CAN_02GC029 regridding complete.
# Files have different raster sizes:
# Size (60, 94) occurs 60 times
# Size (61, 95) occurs 120 times
#  - CAN_02GC030 regridding starting.
#    CAN_02GC030 regridding complete.
# Files have different raster sizes:
# Size (54, 82) occurs 60 times
# Size (53, 82) occurs 120 times
#  - CAN_02GC031 regridding starting.
#    CAN_02GC031 regridding complete.
# All files have the same raster size: (104, 140)
#  - CAN_02GD004 OK as is.
# Files have different raster sizes:
# Size (94, 66) occurs 60 times
# Size (95, 67) occurs 120 times
#  - CAN_02GD010 regridding starting.
#    CAN_02GD010 regridding complete.
# Files have different raster sizes:
# Size (38, 62) occurs 60 times
# Size (37, 62) occurs 120 times
#  - CAN_02GD019 regridding starting.
#    CAN_02GD019 regridding complete.
# All files have the same raster size: (72, 97)
#  - CAN_02GD021 OK as is.
# All files have the same raster size: (74, 128)
#  - CAN_02GE007 OK as is.
# Files have different raster sizes:
# Size (140, 238) occurs 60 times
# Size (141, 237) occurs 120 times
#  - CAN_02GG002 regridding starting.
#    CAN_02GG002 regridding complete.
# All files have the same raster size: (209, 290)
#  - CAN_02GG003 OK as is.
# All files have the same raster size: (78, 116)
#  - CAN_02GG005 OK as is.
# All files have the same raster size: (83, 148)
#  - CAN_02GG006 OK as is.
# Files have different raster sizes:
# Size (121, 257) occurs 60 times
# Size (122, 257) occurs 120 times
#  - CAN_02GG009 regridding starting.
#    CAN_02GG009 regridding complete.
# Files have different raster sizes:
# Size (61, 55) occurs 60 times
# Size (61, 56) occurs 120 times
#  - CAN_02GH002 regridding starting.
#    CAN_02GH002 regridding complete.
# All files have the same raster size: (88, 112)
#  - CAN_02GH003 OK as is.
# Files have different raster sizes:
# Size (71, 250) occurs 60 times
# Size (70, 250) occurs 120 times
#  - CAN_02HA006 regridding starting.
#    CAN_02HA006 regridding complete.
# Files have different raster sizes:
# Size (54, 176) occurs 60 times
# Size (53, 177) occurs 120 times
#  - CAN_02HA020 regridding starting.
#    CAN_02HA020 regridding complete.
# All files have the same raster size: (47, 74)
#  - CAN_02HB012 OK as is.
# All files have the same raster size: (83, 52)
#  - CAN_02HB022 OK as is.
# Files have different raster sizes:
# Size (99, 81) occurs 60 times
# Size (98, 82) occurs 120 times
#  - CAN_02HB023 regridding starting.
#    CAN_02HB023 regridding complete.
# Files have different raster sizes:
# Size (65, 52) occurs 60 times
# Size (65, 53) occurs 120 times
#  - CAN_02HC019 regridding starting.
#    CAN_02HC019 regridding complete.
# Files have different raster sizes:
# Size (36, 61) occurs 60 times
# Size (35, 62) occurs 120 times
#  - CAN_02HC023 regridding starting.
#    CAN_02HC023 regridding complete.
# Files have different raster sizes:
# Size (78, 179) occurs 60 times
# Size (79, 180) occurs 120 times
#  - CAN_02HC025 regridding starting.
#    CAN_02HC025 regridding complete.
# Files have different raster sizes:
# Size (59, 44) occurs 60 times
# Size (60, 45) occurs 120 times
#  - CAN_02HC038 regridding starting.
#    CAN_02HC038 regridding complete.
# Files have different raster sizes:
# Size (59, 101) occurs 60 times
# Size (60, 102) occurs 120 times
#  - CAN_02HC047 regridding starting.
#    CAN_02HC047 regridding complete.
# Files have different raster sizes:
# Size (92, 99) occurs 60 times
# Size (93, 100) occurs 120 times
#  - CAN_02HC049 regridding starting.
#    CAN_02HC049 regridding complete.
# Files have different raster sizes:
# Size (63, 72) occurs 60 times
# Size (63, 71) occurs 120 times
#  - CAN_02HD009 regridding starting.
#    CAN_02HD009 regridding complete.
# Files have different raster sizes:
# Size (63, 157) occurs 60 times
# Size (62, 157) occurs 120 times
#  - CAN_02HD012 regridding starting.
#    CAN_02HD012 regridding complete.
# Files have different raster sizes:
# Size (82, 89) occurs 60 times
# Size (81, 89) occurs 120 times
#  - CAN_02HG001 regridding starting.
#    CAN_02HG001 regridding complete.
# Files have different raster sizes:
# Size (66, 106) occurs 60 times
# Size (66, 107) occurs 120 times
#  - CAN_02HJ001 regridding starting.
#    CAN_02HJ001 regridding complete.
# All files have the same raster size: (56, 108)
#  - CAN_02HK007 OK as is.
# Files have different raster sizes:
# Size (76, 59) occurs 60 times
# Size (77, 59) occurs 120 times
#  - CAN_02HK008 regridding starting.
#    CAN_02HK008 regridding complete.
# Files have different raster sizes:
# Size (169, 97) occurs 60 times
# Size (168, 97) occurs 120 times
#  - CAN_02HL003 regridding starting.
#    CAN_02HL003 regridding complete.
# All files have the same raster size: (184, 181)
#  - CAN_02HL004 OK as is.
# Files have different raster sizes:
# Size (170, 85) occurs 60 times
# Size (170, 84) occurs 120 times
#  - CAN_02HL005 regridding starting.
#    CAN_02HL005 regridding complete.
# Files have different raster sizes:
# Size (99, 101) occurs 60 times
# Size (100, 102) occurs 120 times
#  - CAN_02HM004 regridding starting.
#    CAN_02HM004 regridding complete.
# All files have the same raster size: (82, 122)
#  - CAN_02HM005 OK as is.
# Files have different raster sizes:
# Size (301, 435) occurs 60 times
# Size (300, 435) occurs 120 times
#  - CAN_02JB013 regridding starting.
#    CAN_02JB013 regridding complete.
# All files have the same raster size: (232, 325)
#  - CAN_02JC008 OK as is.
# Files have different raster sizes:
# Size (142, 121) occurs 60 times
# Size (142, 122) occurs 120 times
#  - CAN_02KF016 regridding starting.
#    CAN_02KF016 regridding complete.
# Files have different raster sizes:
# Size (60, 109) occurs 60 times
# Size (59, 108) occurs 120 times
#  - CAN_02KF017 regridding starting.
#    CAN_02KF017 regridding complete.
# Files have different raster sizes:
# Size (140, 171) occurs 60 times
# Size (140, 172) occurs 120 times
#  - CAN_02LA007 regridding starting.
#    CAN_02LA007 regridding complete.
# Files have different raster sizes:
# Size (140, 135) occurs 60 times
# Size (141, 135) occurs 120 times
#  - CAN_02LB006 regridding starting.
#    CAN_02LB006 regridding complete.
# Files have different raster sizes:
# Size (108, 84) occurs 60 times
# Size (109, 84) occurs 120 times
#  - CAN_02LB007 regridding starting.
#    CAN_02LB007 regridding complete.
# All files have the same raster size: (105, 225)
#  - CAN_02LB008 OK as is.
# All files have the same raster size: (61, 66)
#  - CAN_02LB017 OK as is.
# All files have the same raster size: (95, 91)
#  - CAN_02LB020 OK as is.
# Files have different raster sizes:
# Size (62, 114) occurs 60 times
# Size (62, 115) occurs 120 times
#  - CAN_02LB022 regridding starting.
#    CAN_02LB022 regridding complete.
# Files have different raster sizes:
# Size (67, 69) occurs 60 times
# Size (66, 68) occurs 120 times
#  - CAN_02LC027 regridding starting.
#    CAN_02LC027 regridding complete.
# Files have different raster sizes:
# Size (24, 65) occurs 60 times
# Size (23, 66) occurs 120 times
#  - CAN_02LC043 regridding starting.
#    CAN_02LC043 regridding complete.
# Files have different raster sizes:
# Size (298, 189) occurs 60 times
# Size (297, 189) occurs 120 times
#  - CAN_02LD005 regridding starting.
#    CAN_02LD005 regridding complete.
# All files have the same raster size: (494, 683)
#  - CAN_02LG005 OK as is.
# Files have different raster sizes:
# Size (73, 64) occurs 60 times
# Size (74, 64) occurs 120 times
#  - CAN_02MB006 regridding starting.
#    CAN_02MB006 regridding complete.
# All files have the same raster size: (96, 187)
#  - CAN_02MC001 OK as is.
# All files have the same raster size: (56, 149)
#  - CAN_02MC026 OK as is.
# All files have the same raster size: (44, 108)
#  - CAN_02MC028 OK as is.
# Files have different raster sizes:
# Size (342, 232) occurs 60 times
# Size (342, 233) occurs 120 times
#  - CAN_02NE011 regridding starting.
#    CAN_02NE011 regridding complete.
# All files have the same raster size: (188, 368)
#  - CAN_02NF003 OK as is.
# All files have the same raster size: (151, 180)
#  - CAN_02OA057 OK as is.
# All files have the same raster size: (97, 87)
#  - CAN_02OB032 OK as is.
# Files have different raster sizes:
# Size (127, 263) occurs 60 times
# Size (127, 264) occurs 120 times
#  - CAN_02OB037 regridding starting.
#    CAN_02OB037 regridding complete.
# Files have different raster sizes:
# Size (190, 354) occurs 60 times
# Size (191, 355) occurs 120 times
#  - CAN_02OD003 regridding starting.
#    CAN_02OD003 regridding complete.
# All files have the same raster size: (114, 196)
#  - CAN_02OE027 OK as is.
# All files have the same raster size: (157, 203)
#  - CAN_02OE032 OK as is.
# Files have different raster sizes:
# Size (88, 135) occurs 60 times
# Size (89, 135) occurs 120 times
#  - CAN_02OG026 regridding starting.
#    CAN_02OG026 regridding complete.
# Files have different raster sizes:
# Size (153, 83) occurs 60 times
# Size (153, 82) occurs 120 times
#  - CAN_02OJ024 regridding starting.
#    CAN_02OJ024 regridding complete.
# Files have different raster sizes:
# Size (180, 141) occurs 60 times
# Size (180, 142) occurs 120 times
#  - CAN_02OJ026 regridding starting.
#    CAN_02OJ026 regridding complete.
# All files have the same raster size: (525, 451)
#  - CAN_02PA007 OK as is.
# All files have the same raster size: (217, 168)
#  - CAN_02PB006 OK as is.
# All files have the same raster size: (10, 10)
#  - CAN_02PC018 OK as is.
# Files have different raster sizes:
# Size (67, 81) occurs 60 times
# Size (67, 82) occurs 120 times
#  - CAN_02PC019 regridding starting.
#    CAN_02PC019 regridding complete.
# Files have different raster sizes:
# Size (290, 163) occurs 60 times
# Size (290, 162) occurs 120 times
#  - CAN_02PD002 regridding starting.
#    CAN_02PD002 regridding complete.
# Files have different raster sizes:
# Size (92, 61) occurs 60 times
# Size (92, 60) occurs 120 times
#  - CAN_02PD004 regridding starting.
#    CAN_02PD004 regridding complete.
# Files have different raster sizes:
# Size (12, 14) occurs 60 times
# Size (11, 13) occurs 120 times
#  - CAN_02PD012 regridding starting.
#    CAN_02PD012 regridding complete.
# Files have different raster sizes:
# Size (18, 23) occurs 60 times
# Size (18, 22) occurs 120 times
#  - CAN_02PD013 regridding starting.
#    CAN_02PD013 regridding complete.
# Files have different raster sizes:
# Size (7, 7) occurs 60 times
# Size (7, 8) occurs 120 times
#  - CAN_02PD014 regridding starting.
# Setting nodata to 27 instead of -32768.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/bdod/bdod_0-5cm_Q0.05.tif
# Setting nodata to 8 instead of 65535.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/bdod/bdod_100-200cm_uncertainty.tif
# Setting nodata to 11 instead of 65535.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/bdod/bdod_15-30cm_uncertainty.tif
# Setting nodata to 123 instead of -32768.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/bdod/bdod_30-60cm_Q0.5.tif
# Setting nodata to 176 instead of -32768.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/bdod/bdod_30-60cm_Q0.95.tif
# Setting nodata to 9 instead of 65535.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/bdod/bdod_30-60cm_uncertainty.tif
# Setting nodata to 11 instead of 65535.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/bdod/bdod_5-15cm_uncertainty.tif
# Setting nodata to 77 instead of -32768.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/bdod/bdod_60-100cm_Q0.05.tif
# Setting nodata to 190 instead of -32768.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/bdod/bdod_60-100cm_Q0.95.tif
# Setting nodata to 8 instead of 65535.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/bdod/bdod_60-100cm_uncertainty.tif
# Setting nodata to 66 instead of -32768.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/soc/soc_0-5cm_Q0.05.tif
# Setting nodata to 55 instead of -32768.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/soc/soc_100-200cm_Q0.5.tif
# Setting nodata to 66 instead of -32768.0 in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/CAN_02PD014/geospatial/soilgrids/raw/soc/soc_5-15cm_Q0.05.tif
#    CAN_02PD014 regridding complete.
# Files have different raster sizes:
# Size (13, 13) occurs 60 times
# Size (13, 14) occurs 120 times
#  - CAN_02PD015 regridding starting.
#    CAN_02PD015 regridding complete.
# Files have different raster sizes:
# Size (25, 50) occurs 60 times
# Size (25, 49) occurs 120 times
#  - CAN_02PE014 regridding starting.
#    CAN_02PE014 regridding complete.
# Files have different raster sizes:
# Size (163, 140) occurs 60 times
# Size (163, 139) occurs 120 times
#  - CAN_02PG006 regridding starting.
#    CAN_02PG006 regridding complete.
# Files have different raster sizes:
# Size (182, 210) occurs 60 times
# Size (182, 211) occurs 120 times
#  - CAN_02PG022 regridding starting.
#    CAN_02PG022 regridding complete.
# Files have different raster sizes:
# Size (170, 227) occurs 60 times
# Size (170, 228) occurs 120 times
#  - CAN_02PJ007 regridding starting.
#    CAN_02PJ007 regridding complete.
# Files have different raster sizes:
# Size (140, 180) occurs 60 times
# Size (140, 181) occurs 120 times
#  - CAN_02PJ030 regridding starting.
#    CAN_02PJ030 regridding complete.
# Files have different raster sizes:
# Size (200, 218) occurs 60 times
# Size (201, 218) occurs 120 times
#  - CAN_02PL005 regridding starting.
#    CAN_02PL005 regridding complete.
# All files have the same raster size: (246, 369)
#  - CAN_02QA002 OK as is.
# All files have the same raster size: (160, 272)
#  - CAN_02QC009 OK as is.
# All files have the same raster size: (257, 256)
#  - CAN_02RC011 OK as is.
# Files have different raster sizes:
# Size (849, 463) occurs 60 times
# Size (849, 462) occurs 120 times
#  - CAN_02RD003 regridding starting.
#    CAN_02RD003 regridding complete.
# Files have different raster sizes:
# Size (1038, 859) occurs 60 times
# Size (1038, 858) occurs 120 times
#  - CAN_02RF001 regridding starting.
#    CAN_02RF001 regridding complete.
# Files have different raster sizes:
# Size (146, 210) occurs 60 times
# Size (146, 211) occurs 120 times
#  - CAN_02RF009 regridding starting.
#    CAN_02RF009 regridding complete.
# All files have the same raster size: (428, 300)
#  - CAN_02RG005 OK as is.
# All files have the same raster size: (132, 183)
#  - CAN_02RH027 OK as is.
# All files have the same raster size: (253, 222)
#  - CAN_02RH035 OK as is.
# All files have the same raster size: (152, 196)
#  - CAN_02RH045 OK as is.
# Files have different raster sizes:
# Size (335, 297) occurs 60 times
# Size (335, 298) occurs 120 times
#  - CAN_02UA003 regridding starting.
#    CAN_02UA003 regridding complete.
# Files have different raster sizes:
# Size (1213, 990) occurs 60 times
# Size (1214, 991) occurs 120 times
#  - CAN_02UC002 regridding starting.
#    CAN_02UC002 regridding complete.
# Files have different raster sizes:
# Size (651, 694) occurs 60 times
# Size (652, 694) occurs 120 times
#  - CAN_02VB004 regridding starting.
#    CAN_02VB004 regridding complete.
# All files have the same raster size: (987, 1136)
#  - CAN_02WB003 OK as is.
# Files have different raster sizes:
# Size (339, 1067) occurs 60 times
# Size (339, 1068) occurs 120 times
#  - CAN_02XA003 regridding starting.
#    CAN_02XA003 regridding complete.
# Files have different raster sizes:
# Size (441, 678) occurs 60 times
# Size (441, 677) occurs 120 times
#  - CAN_02XC001 regridding starting.
#    CAN_02XC001 regridding complete.
# Files have different raster sizes:
# Size (18, 33) occurs 60 times
# Size (18, 32) occurs 120 times
#  - CAN_02YA002 regridding starting.
#    CAN_02YA002 regridding complete.
# Files have different raster sizes:
# Size (122, 250) occurs 60 times
# Size (122, 251) occurs 120 times
#  - CAN_02YC001 regridding starting.
#    CAN_02YC001 regridding complete.
# All files have the same raster size: (75, 120)
#  - CAN_02YD002 OK as is.
# All files have the same raster size: (54, 88)
#  - CAN_02YE001 OK as is.
# All files have the same raster size: (129, 194)
#  - CAN_02YG001 OK as is.
# Files have different raster sizes:
# Size (144, 261) occurs 60 times
# Size (143, 261) occurs 120 times
#  - CAN_02YJ001 regridding starting.
#    CAN_02YJ001 regridding complete.
# Files have different raster sizes:
# Size (83, 246) occurs 60 times
# Size (82, 245) occurs 120 times
#  - CAN_02YK002 regridding starting.
#    CAN_02YK002 regridding complete.
# Files have different raster sizes:
# Size (140, 171) occurs 60 times
# Size (139, 171) occurs 120 times
#  - CAN_02YK005 regridding starting.
#    CAN_02YK005 regridding complete.
# All files have the same raster size: (26, 29)
#  - CAN_02YK008 OK as is.
# Files have different raster sizes:
# Size (257, 345) occurs 60 times
# Size (258, 345) occurs 120 times
#  - CAN_02YL001 regridding starting.
#    CAN_02YL001 regridding complete.
# All files have the same raster size: (45, 57)
#  - CAN_02YL004 OK as is.
# Files have different raster sizes:
# Size (20, 36) occurs 60 times
# Size (21, 35) occurs 120 times
#  - CAN_02YL005 regridding starting.
#    CAN_02YL005 regridding complete.
# All files have the same raster size: (103, 192)
#  - CAN_02YL008 OK as is.
# All files have the same raster size: (18, 33)
#  - CAN_02YL011 OK as is.
# All files have the same raster size: (59, 73)
#  - CAN_02YM003 OK as is.
# All files have the same raster size: (73, 111)
#  - CAN_02YM004 OK as is.
# Files have different raster sizes:
# Size (112, 247) occurs 60 times
# Size (112, 246) occurs 120 times
#  - CAN_02YN002 regridding starting.
#    CAN_02YN002 regridding complete.
# All files have the same raster size: (73, 165)
#  - CAN_02YO006 OK as is.
# All files have the same raster size: (189, 285)
#  - CAN_02YO008 OK as is.
# Files have different raster sizes:
# Size (65, 79) occurs 60 times
# Size (64, 79) occurs 120 times
#  - CAN_02YO012 regridding starting.
#    CAN_02YO012 regridding complete.
# Files have different raster sizes:
# Size (394, 745) occurs 60 times
# Size (394, 744) occurs 120 times
#  - CAN_02YQ001 regridding starting.
#    CAN_02YQ001 regridding complete.
# Files have different raster sizes:
# Size (41, 99) occurs 60 times
# Size (41, 98) occurs 120 times
#  - CAN_02YQ005 regridding starting.
#    CAN_02YQ005 regridding complete.
# Files have different raster sizes:
# Size (56, 252) occurs 60 times
# Size (56, 253) occurs 120 times
#  - CAN_02YR001 regridding starting.
#    CAN_02YR001 regridding complete.
# Files have different raster sizes:
# Size (111, 251) occurs 60 times
# Size (111, 252) occurs 120 times
#  - CAN_02YR003 regridding starting.
#    CAN_02YR003 regridding complete.
# Files have different raster sizes:
# Size (36, 64) occurs 60 times
# Size (36, 63) occurs 120 times
#  - CAN_02YS003 regridding starting.
#    CAN_02YS003 regridding complete.
# Files have different raster sizes:
# Size (256, 568) occurs 60 times
# Size (257, 569) occurs 120 times
#  - CAN_02YS005 regridding starting.
#    CAN_02YS005 regridding complete.
# All files have the same raster size: (144, 313)
#  - CAN_02YS006 OK as is.
# All files have the same raster size: (62, 57)
#  - CAN_02ZA002 OK as is.
# Files have different raster sizes:
# Size (105, 135) occurs 60 times
# Size (105, 134) occurs 120 times
#  - CAN_02ZB001 regridding starting.
#    CAN_02ZB001 regridding complete.
# All files have the same raster size: (74, 118)
#  - CAN_02ZC002 OK as is.
# Files have different raster sizes:
# Size (364, 365) occurs 60 times
# Size (363, 365) occurs 120 times
#  - CAN_02ZD002 regridding starting.
#    CAN_02ZD002 regridding complete.
# All files have the same raster size: (53, 84)
#  - CAN_02ZE004 OK as is.
# All files have the same raster size: (244, 234)
#  - CAN_02ZF001 OK as is.
# Files have different raster sizes:
# Size (16, 23) occurs 60 times
# Size (16, 22) occurs 120 times
#  - CAN_02ZG001 regridding starting.
#    CAN_02ZG001 regridding complete.
# All files have the same raster size: (69, 69)
#  - CAN_02ZG003 OK as is.
# All files have the same raster size: (30, 59)
#  - CAN_02ZG004 OK as is.
# Files have different raster sizes:
# Size (164, 243) occurs 60 times
# Size (163, 244) occurs 120 times
#  - CAN_02ZH001 regridding starting.
#    CAN_02ZH001 regridding complete.
# Files have different raster sizes:
# Size (51, 56) occurs 60 times
# Size (51, 57) occurs 120 times
#  - CAN_02ZH002 regridding starting.
#    CAN_02ZH002 regridding complete.
# All files have the same raster size: (45, 84)
#  - CAN_02ZJ001 OK as is.
# Files have different raster sizes:
# Size (47, 75) occurs 60 times
# Size (46, 75) occurs 120 times
#  - CAN_02ZJ002 regridding starting.
#    CAN_02ZJ002 regridding complete.
# All files have the same raster size: (57, 77)
#  - CAN_02ZJ003 OK as is.
# All files have the same raster size: (120, 164)
#  - CAN_02ZK001 OK as is.
# All files have the same raster size: (77, 87)
#  - CAN_02ZK002 OK as is.
# All files have the same raster size: (27, 62)
#  - CAN_02ZK003 OK as is.
# Files have different raster sizes:
# Size (61, 104) occurs 60 times
# Size (60, 104) occurs 120 times
#  - CAN_02ZK004 regridding starting.
#    CAN_02ZK004 regridding complete.
# All files have the same raster size: (43, 61)
#  - CAN_02ZL004 OK as is.
# Files have different raster sizes:
# Size (27, 27) occurs 60 times
# Size (27, 28) occurs 120 times
#  - CAN_02ZL005 regridding starting.
#    CAN_02ZL005 regridding complete.
# Files have different raster sizes:
# Size (11, 15) occurs 60 times
# Size (12, 15) occurs 120 times
#  - CAN_02ZM006 regridding starting.
#    CAN_02ZM006 regridding complete.
# Files have different raster sizes:
# Size (43, 56) occurs 60 times
# Size (43, 57) occurs 120 times
#  - CAN_02ZM009 regridding starting.
#    CAN_02ZM009 regridding complete.
# All files have the same raster size: (29, 25)
#  - CAN_02ZM016 OK as is.
# Files have different raster sizes:
# Size (31, 22) occurs 60 times
# Size (31, 23) occurs 120 times
#  - CAN_02ZN002 regridding starting.
#    CAN_02ZN002 regridding complete.
# Files have different raster sizes:
# Size (868, 1674) occurs 60 times
# Size (869, 1673) occurs 120 times
#  - CAN_03AB002 regridding starting.
#    CAN_03AB002 regridding complete.
# Files have different raster sizes:
# Size (884, 1351) occurs 60 times
# Size (884, 1352) occurs 120 times
#  - CAN_03AC004 regridding starting.
#    CAN_03AC004 regridding complete.
# All files have the same raster size: (459, 1200)
#  - CAN_03BD002 OK as is.
# All files have the same raster size: (333, 975)
#  - CAN_03BF001 OK as is.
# Files have different raster sizes:
# Size (632, 3204) occurs 60 times
# Size (632, 3205) occurs 120 times
#  - CAN_03ED001 regridding starting.
#    CAN_03ED001 regridding complete.
# Files have different raster sizes:
# Size (577, 999) occurs 60 times
# Size (577, 998) occurs 120 times
#  - CAN_03FA003 regridding starting.
#    CAN_03FA003 regridding complete.
# All files have the same raster size: (1214, 1789)
#  - CAN_03KC004 OK as is.
# Files have different raster sizes:
# Size (1225, 1258) occurs 60 times
# Size (1225, 1259) occurs 120 times
#  - CAN_03MB002 regridding starting.
#    CAN_03MB002 regridding complete.
# All files have the same raster size: (984, 1415)
#  - CAN_03MD001 OK as is.
# Files have different raster sizes:
# Size (412, 1062) occurs 60 times
# Size (413, 1061) occurs 120 times
#  - CAN_03NF001 regridding starting.
#    CAN_03NF001 regridding complete.
# All files have the same raster size: (765, 1055)
#  - CAN_03OC003 OK as is.
# All files have the same raster size: (29, 147)
#  - CAN_03OE010 OK as is.
# All files have the same raster size: (554, 1131)
#  - CAN_03QC001 OK as is.
# Files have different raster sizes:
# Size (201, 518) occurs 60 times
# Size (201, 519) occurs 120 times
#  - CAN_03QC002 regridding starting.
#    CAN_03QC002 regridding complete.
# Files have different raster sizes:
# Size (581, 1177) occurs 60 times
# Size (581, 1176) occurs 120 times
#  - CAN_04AA004 regridding starting.
#    CAN_04AA004 regridding complete.
# Files have different raster sizes:
# Size (1425, 3339) occurs 60 times
# Size (1424, 3338) occurs 120 times
#  - CAN_04AB001 regridding starting.
#    CAN_04AB001 regridding complete.
# Files have different raster sizes:
# Size (1375, 2931) occurs 60 times
# Size (1374, 2931) occurs 120 times
#  - CAN_04AD002 regridding starting.
#    CAN_04AD002 regridding complete.
# All files have the same raster size: (697, 2352)
#  - CAN_04CA002 OK as is.
# Files have different raster sizes:
# Size (179, 222) occurs 60 times
# Size (179, 221) occurs 120 times
#  - CAN_04CA003 regridding starting.
#    CAN_04CA003 regridding complete.
# All files have the same raster size: (607, 984)
#  - CAN_04CB001 OK as is.
# Files have different raster sizes:
# Size (413, 989) occurs 60 times
# Size (414, 990) occurs 120 times
#  - CAN_04DA001 regridding starting.
#    CAN_04DA001 regridding complete.
# Files have different raster sizes:
# Size (365, 1167) occurs 60 times
# Size (364, 1168) occurs 120 times
#  - CAN_04DB001 regridding starting.
#    CAN_04DB001 regridding complete.
# Files have different raster sizes:
# Size (1299, 2530) occurs 60 times
# Size (1300, 2531) occurs 120 times
#  - CAN_04DC001 regridding starting.
#    CAN_04DC001 regridding complete.
# Files have different raster sizes:
# Size (445, 617) occurs 60 times
# Size (446, 618) occurs 120 times
#  - CAN_04DC002 regridding starting.
#    CAN_04DC002 regridding complete.
# All files have the same raster size: (789, 927)
#  - CAN_04EA001 OK as is.
# Files have different raster sizes:
# Size (438, 1053) occurs 60 times
# Size (438, 1052) occurs 120 times
#  - CAN_04FA001 regridding starting.
#    CAN_04FA001 regridding complete.
# Files have different raster sizes:
# Size (308, 986) occurs 60 times
# Size (309, 987) occurs 120 times
#  - CAN_04FA003 regridding starting.
#    CAN_04FA003 regridding complete.
# All files have the same raster size: (623, 2148)
#  - CAN_04FB001 OK as is.
# Files have different raster sizes:
# Size (991, 2970) occurs 60 times
# Size (991, 2969) occurs 120 times
#  - CAN_04FC001 regridding starting.
#    CAN_04FC001 regridding complete.
# Files have different raster sizes:
# Size (398, 731) occurs 60 times
# Size (398, 730) occurs 120 times
#  - CAN_04GA002 regridding starting.
#    CAN_04GA002 regridding complete.
# Files have different raster sizes:
# Size (679, 823) occurs 60 times
# Size (679, 822) occurs 120 times
#  - CAN_04GB004 regridding starting.
#    CAN_04GB004 regridding complete.
# Files have different raster sizes:
# Size (197, 228) occurs 60 times
# Size (198, 228) occurs 120 times
#  - CAN_04GB005 regridding starting.
#    CAN_04GB005 regridding complete.
# Files have different raster sizes:
# Size (330, 437) occurs 60 times
# Size (329, 438) occurs 120 times
#  - CAN_04JC002 regridding starting.
#    CAN_04JC002 regridding complete.
# All files have the same raster size: (164, 507)
#  - CAN_04JD005 OK as is.
# Files have different raster sizes:
# Size (443, 730) occurs 60 times
# Size (443, 731) occurs 120 times
#  - CAN_04JF001 regridding starting.
#    CAN_04JF001 regridding complete.
# All files have the same raster size: (424, 1008)
#  - CAN_04KA001 OK as is.
# All files have the same raster size: (735, 576)
#  - CAN_04LJ001 OK as is.
# All files have the same raster size: (1246, 1025)
#  - CAN_04LM001 OK as is.
# All files have the same raster size: (130, 134)
#  - CAN_04MD004 OK as is.
# Files have different raster sizes:
# Size (668, 417) occurs 60 times
# Size (669, 418) occurs 120 times
#  - CAN_04MF001 regridding starting.
#    CAN_04MF001 regridding complete.
# Files have different raster sizes:
# Size (351, 431) occurs 60 times
# Size (352, 431) occurs 120 times
#  - CAN_04NA001 regridding starting.
#    CAN_04NA001 regridding complete.
# Files have different raster sizes:
# Size (109, 98) occurs 60 times
# Size (110, 98) occurs 120 times
#  - CAN_05AA004 regridding starting.
#    CAN_05AA004 regridding complete.
# Files have different raster sizes:
# Size (103, 118) occurs 60 times
# Size (103, 119) occurs 120 times
#  - CAN_05AA008 regridding starting.
#    CAN_05AA008 regridding complete.
# All files have the same raster size: (106, 90)
#  - CAN_05AA011 OK as is.
# Files have different raster sizes:
# Size (184, 223) occurs 60 times
# Size (184, 222) occurs 120 times
#  - CAN_05AA022 regridding starting.
#    CAN_05AA022 regridding complete.
# Files have different raster sizes:
# Size (111, 173) occurs 60 times
# Size (110, 173) occurs 120 times
#  - CAN_05AA028 regridding starting.
#    CAN_05AA028 regridding complete.
# All files have the same raster size: (44, 64)
#  - CAN_05AA909 OK as is.
# All files have the same raster size: (96, 187)
#  - CAN_05AB005 OK as is.
# Files have different raster sizes:
# Size (110, 106) occurs 60 times
# Size (111, 106) occurs 120 times
#  - CAN_05AB013 regridding starting.
#    CAN_05AB013 regridding complete.
# All files have the same raster size: (73, 135)
#  - CAN_05AB029 OK as is.
# Files have different raster sizes:
# Size (99, 166) occurs 60 times
# Size (100, 167) occurs 120 times
#  - CAN_05AC030 regridding starting.
#    CAN_05AC030 regridding complete.
# Files have different raster sizes:
# Size (161, 171) occurs 60 times
# Size (162, 171) occurs 120 times
#  - CAN_05AD003 regridding starting.
#    CAN_05AD003 regridding complete.
# All files have the same raster size: (86, 120)
#  - CAN_05AD035 OK as is.
# All files have the same raster size: (91, 155)
#  - CAN_05AE005 OK as is.
# Files have different raster sizes:
# Size (116, 114) occurs 60 times
# Size (117, 113) occurs 120 times
#  - CAN_05AH037 regridding starting.
#    CAN_05AH037 regridding complete.
# All files have the same raster size: (72, 223)
#  - CAN_05AH041 OK as is.
# All files have the same raster size: (63, 71)
#  - CAN_05AH047 OK as is.
# Files have different raster sizes:
# Size (178, 242) occurs 60 times
# Size (178, 243) occurs 120 times
#  - CAN_05AH050 regridding starting.
# ...
#  - USA_11284400 OK as is.
# All files have the same raster size: (41, 44)
#  - USA_11299600 OK as is.
# Files have different raster sizes:
# Size (193, 242) occurs 60 times
# Size (193, 243) occurs 120 times
#  - USA_11381500 regridding starting.
#    USA_11381500 regridding complete.
# All files have the same raster size: (162, 268)
#  - USA_11383500 OK as is.
# Files have different raster sizes:
# Size (52, 100) occurs 60 times
# Size (52, 101) occurs 120 times
#  - USA_11451100 regridding starting.
#    USA_11451100 regridding complete.
# Files have different raster sizes:
# Size (76, 146) occurs 60 times
# Size (77, 147) occurs 120 times
#  - USA_11468500 regridding starting.
#    USA_11468500 regridding complete.
# Files have different raster sizes:
# Size (287, 264) occurs 60 times
# Size (288, 263) occurs 120 times
#  - USA_11473900 regridding starting.
#    USA_11473900 regridding complete.
# All files have the same raster size: (22, 32)
#  - USA_11475560 OK as is.
# All files have the same raster size: (58, 51)
#  - USA_11476600 OK as is.
# Files have different raster sizes:
# Size (142, 232) occurs 60 times
# Size (141, 232) occurs 120 times
#  - USA_11478500 regridding starting.
#    USA_11478500 regridding complete.
# Files have different raster sizes:
# Size (96, 110) occurs 60 times
# Size (96, 111) occurs 120 times
#  - USA_11480390 regridding starting.
#    USA_11480390 regridding complete.
# All files have the same raster size: (55, 86)
#  - USA_11481200 OK as is.
# Files have different raster sizes:
# Size (337, 178) occurs 60 times
# Size (338, 178) occurs 120 times
#  - USA_11482500 regridding starting.
#    USA_11482500 regridding complete.
# All files have the same raster size: (253, 258)
#  - USA_11522500 OK as is.
# Files have different raster sizes:
# Size (121, 142) occurs 60 times
# Size (121, 141) occurs 120 times
#  - USA_11523200 regridding starting.
#    USA_11523200 regridding complete.
# Files have different raster sizes:
# Size (270, 277) occurs 60 times
# Size (269, 277) occurs 120 times
#  - USA_11528700 regridding starting.
#    USA_11528700 regridding complete.
# All files have the same raster size: (279, 196)
#  - USA_11532500 OK as is.
# Files have different raster sizes:
# Size (78, 99) occurs 60 times
# Size (77, 99) occurs 120 times
#  - USA_12010000 regridding starting.
#    USA_12010000 regridding complete.
# Files have different raster sizes:
# Size (89, 142) occurs 60 times
# Size (90, 142) occurs 120 times
#  - USA_12013500 regridding starting.
#    USA_12013500 regridding complete.
# Files have different raster sizes:
# Size (105, 94) occurs 60 times
# Size (106, 94) occurs 120 times
#  - USA_12020000 regridding starting.
#    USA_12020000 regridding complete.
# Files have different raster sizes:
# Size (85, 214) occurs 60 times
# Size (85, 213) occurs 120 times
#  - USA_12025000 regridding starting.
#    USA_12025000 regridding complete.
# Files have different raster sizes:
# Size (53, 90) occurs 60 times
# Size (53, 91) occurs 120 times
#  - USA_12025700 regridding starting.
#    USA_12025700 regridding complete.
# All files have the same raster size: (195, 156)
#  - USA_12035000 OK as is.
# Files have different raster sizes:
# Size (136, 337) occurs 60 times
# Size (137, 338) occurs 120 times
#  - USA_12040500 regridding starting.
#    USA_12040500 regridding complete.
# Files have different raster sizes:
# Size (83, 327) occurs 60 times
# Size (83, 328) occurs 120 times
#  - USA_12041200 regridding starting.
#    USA_12041200 regridding complete.
# Files have different raster sizes:
# Size (69, 186) occurs 60 times
# Size (69, 187) occurs 120 times
#  - USA_12043000 regridding starting.
#    USA_12043000 regridding complete.
# All files have the same raster size: (113, 168)
#  - USA_12048000 OK as is.
# All files have the same raster size: (49, 166)
#  - USA_12054000 OK as is.
# Files have different raster sizes:
# Size (69, 103) occurs 60 times
# Size (69, 104) occurs 120 times
#  - USA_12056500 regridding starting.
#    USA_12056500 regridding complete.
# All files have the same raster size: (37, 18)
#  - USA_12073500 OK as is.
# Files have different raster sizes:
# Size (94, 162) occurs 60 times
# Size (94, 163) occurs 120 times
#  - USA_12082500 regridding starting.
#    USA_12082500 regridding complete.
# Files have different raster sizes:
# Size (77, 115) occurs 60 times
# Size (78, 116) occurs 120 times
#  - USA_12092000 regridding starting.
#    USA_12092000 regridding complete.
# Files have different raster sizes:
# Size (67, 127) occurs 60 times
# Size (67, 128) occurs 120 times
#  - USA_12095000 regridding starting.
#    USA_12095000 regridding complete.
# Files have different raster sizes:
# Size (41, 58) occurs 60 times
# Size (40, 57) occurs 120 times
#  - USA_12114500 regridding starting.
#    USA_12114500 regridding complete.
# Files have different raster sizes:
# Size (52, 101) occurs 60 times
# Size (51, 101) occurs 120 times
#  - USA_12115000 regridding starting.
#    USA_12115000 regridding complete.
# Files have different raster sizes:
# Size (30, 44) occurs 60 times
# Size (30, 43) occurs 120 times
#  - USA_12115500 regridding starting.
#    USA_12115500 regridding complete.
# All files have the same raster size: (28, 61)
#  - USA_12117000 OK as is.
# Files have different raster sizes:
# Size (85, 200) occurs 60 times
# Size (86, 199) occurs 120 times
#  - USA_12141300 regridding starting.
#    USA_12141300 regridding complete.
# Files have different raster sizes:
# Size (55, 149) occurs 60 times
# Size (56, 149) occurs 120 times
#  - USA_12143600 regridding starting.
#    USA_12143600 regridding complete.
# Files have different raster sizes:
# Size (64, 189) occurs 60 times
# Size (65, 189) occurs 120 times
#  - USA_12144000 regridding starting.
#    USA_12144000 regridding complete.
# Files have different raster sizes:
# Size (57, 70) occurs 60 times
# Size (58, 69) occurs 120 times
#  - USA_12145500 regridding starting.
#    USA_12145500 regridding complete.
# Files have different raster sizes:
# Size (38, 114) occurs 60 times
# Size (38, 113) occurs 120 times
#  - USA_12147500 regridding starting.
#    USA_12147500 regridding complete.
# Files have different raster sizes:
# Size (14, 36) occurs 60 times
# Size (14, 35) occurs 120 times
#  - USA_12147600 regridding starting.
#    USA_12147600 regridding complete.
# Files have different raster sizes:
# Size (130, 218) occurs 60 times
# Size (130, 217) occurs 120 times
#  - USA_12167000 regridding starting.
#    USA_12167000 regridding complete.
# Files have different raster sizes:
# Size (87, 162) occurs 60 times
# Size (88, 162) occurs 120 times
#  - USA_12175500 regridding starting.
#    USA_12175500 regridding complete.
# Files have different raster sizes:
# Size (44, 66) occurs 60 times
# Size (44, 67) occurs 120 times
#  - USA_12178100 regridding starting.
#    USA_12178100 regridding complete.
# Files have different raster sizes:
# Size (96, 182) occurs 60 times
# Size (95, 181) occurs 120 times
#  - USA_12186000 regridding starting.
#    USA_12186000 regridding complete.
# Files have different raster sizes:
# Size (210, 341) occurs 60 times
# Size (210, 342) occurs 120 times
#  - USA_12189500 regridding starting.
#    USA_12189500 regridding complete.
# All files have the same raster size: (417, 536)
#  - USA_12358500 OK as is.
# All files have the same raster size: (36, 65)
#  - USA_12374250 OK as is.
# Files have different raster sizes:
# Size (22, 52) occurs 60 times
# Size (23, 52) occurs 120 times
#  - USA_12375900 regridding starting.
#    USA_12375900 regridding complete.
# Files have different raster sizes:
# Size (29, 46) occurs 60 times
# Size (30, 45) occurs 120 times
#  - USA_12377150 regridding starting.
#    USA_12377150 regridding complete.
# Files have different raster sizes:
# Size (57, 110) occurs 60 times
# Size (57, 109) occurs 120 times
#  - USA_12381400 regridding starting.
#    USA_12381400 regridding complete.
# Files have different raster sizes:
# Size (21, 39) occurs 60 times
# Size (22, 40) occurs 120 times
#  - USA_12383500 regridding starting.
#    USA_12383500 regridding complete.
# Files have different raster sizes:
# Size (36, 63) occurs 60 times
# Size (37, 63) occurs 120 times
#  - USA_12388400 regridding starting.
#    USA_12388400 regridding complete.
# All files have the same raster size: (75, 217)
#  - USA_12390700 OK as is.
# All files have the same raster size: (168, 207)
#  - USA_12411000 OK as is.
# All files have the same raster size: (217, 546)
#  - USA_12414500 OK as is.
# Files have different raster sizes:
# Size (54, 56) occurs 60 times
# Size (55, 57) occurs 120 times
#  - USA_12447390 regridding starting.
#    USA_12447390 regridding complete.
# All files have the same raster size: (156, 195)
#  - USA_12451000 OK as is.
# Files have different raster sizes:
# Size (80, 156) occurs 60 times
# Size (81, 156) occurs 120 times
#  - USA_12488500 regridding starting.
#    USA_12488500 regridding complete.
# All files have the same raster size: (123, 193)
#  - USA_13011500 OK as is.
# Files have different raster sizes:
# Size (129, 277) occurs 60 times
# Size (129, 278) occurs 120 times
#  - USA_13011900 regridding starting.
#    USA_13011900 regridding complete.
# All files have the same raster size: (24, 46)
#  - USA_13018300 OK as is.
# Files have different raster sizes:
# Size (290, 180) occurs 60 times
# Size (289, 180) occurs 120 times
#  - USA_13023000 regridding starting.
#    USA_13023000 regridding complete.
# Files have different raster sizes:
# Size (58, 103) occurs 60 times
# Size (59, 103) occurs 120 times
#  - USA_13083000 regridding starting.
#    USA_13083000 regridding complete.
# All files have the same raster size: (239, 207)
#  - USA_13161500 OK as is.
# All files have the same raster size: (180, 294)
#  - USA_13235000 OK as is.
# Files have different raster sizes:
# Size (77, 59) occurs 60 times
# Size (77, 60) occurs 120 times
#  - USA_13240000 regridding starting.
#    USA_13240000 regridding complete.
# All files have the same raster size: (231, 140)
#  - USA_13310700 OK as is.
# All files have the same raster size: (187, 113)
#  - USA_13313000 OK as is.
# Files have different raster sizes:
# Size (226, 194) occurs 60 times
# Size (227, 194) occurs 120 times
#  - USA_13331500 regridding starting.
#    USA_13331500 regridding complete.
# All files have the same raster size: (267, 635)
#  - USA_13337000 OK as is.
# Files have different raster sizes:
# Size (253, 578) occurs 60 times
# Size (253, 579) occurs 120 times
#  - USA_13338500 regridding starting.
#    USA_13338500 regridding complete.
# All files have the same raster size: (559, 1010)
#  - USA_13340000 OK as is.
# Files have different raster sizes:
# Size (267, 443) occurs 60 times
# Size (267, 442) occurs 120 times
#  - USA_13340600 regridding starting.
#    USA_13340600 regridding complete.
# Files have different raster sizes:
# Size (92, 140) occurs 60 times
# Size (92, 141) occurs 120 times
#  - USA_14020000 regridding starting.
#    USA_14020000 regridding complete.
# Files have different raster sizes:
# Size (29, 78) occurs 60 times
# Size (29, 79) occurs 120 times
#  - USA_14092750 regridding starting.
#    USA_14092750 regridding complete.
# Files have different raster sizes:
# Size (85, 202) occurs 60 times
# Size (85, 201) occurs 120 times
#  - USA_14096850 regridding starting.
#    USA_14096850 regridding complete.
# Files have different raster sizes:
# Size (125, 207) occurs 60 times
# Size (124, 207) occurs 120 times
#  - USA_14137000 regridding starting.
#    USA_14137000 regridding complete.
# All files have the same raster size: (23, 45)
#  - USA_14138800 OK as is.
# All files have the same raster size: (14, 38)
#  - USA_14138870 OK as is.
# Files have different raster sizes:
# Size (35, 33) occurs 60 times
# Size (36, 34) occurs 120 times
#  - USA_14138900 regridding starting.
#    USA_14138900 regridding complete.
# All files have the same raster size: (21, 81)
#  - USA_14139800 OK as is.
# Files have different raster sizes:
# Size (21, 114) occurs 60 times
# Size (20, 113) occurs 120 times
#  - USA_14141500 regridding starting.
#    USA_14141500 regridding complete.
# All files have the same raster size: (124, 165)
#  - USA_14154500 OK as is.
# Files have different raster sizes:
# Size (73, 137) occurs 60 times
# Size (74, 137) occurs 120 times
#  - USA_14158500 regridding starting.
#    USA_14158500 regridding complete.
# Files have different raster sizes:
# Size (33, 49) occurs 60 times
# Size (33, 50) occurs 120 times
#  - USA_14158790 regridding starting.
#    USA_14158790 regridding complete.
# Files have different raster sizes:
# Size (111, 95) occurs 178 times
# Size (106, 95) occurs 2 times
#  - USA_14166500 regridding starting.
# Setting nodata to 0 instead of None in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/USA_14166500/geospatial/soilgrids/raw/clay/clay_0-5cm_mean.tif
# Setting nodata to 0 instead of None in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/USA_14166500/geospatial/soilgrids/raw/silt/silt_0-5cm_mean.tif
#    USA_14166500 regridding complete.
# Files have different raster sizes:
# Size (54, 199) occurs 60 times
# Size (55, 199) occurs 120 times
#  - USA_14182500 regridding starting.
#    USA_14182500 regridding complete.
# Files have different raster sizes:
# Size (97, 170) occurs 60 times
# Size (97, 171) occurs 120 times
#  - USA_14185000 regridding starting.
#    USA_14185000 regridding complete.
# Files have different raster sizes:
# Size (68, 163) occurs 60 times
# Size (68, 164) occurs 120 times
#  - USA_14185900 regridding starting.
#    USA_14185900 regridding complete.
# Files have different raster sizes:
# Size (53, 100) occurs 60 times
# Size (53, 99) occurs 118 times
# Size (51, 100) occurs 2 times
#  - USA_14187000 regridding starting.
# Setting nodata to 0 instead of None in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/USA_14187000/geospatial/soilgrids/raw/clay/clay_0-5cm_mean.tif
# Setting nodata to 0 instead of None in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/USA_14187000/geospatial/soilgrids/raw/silt/silt_0-5cm_mean.tif
#    USA_14187000 regridding complete.
# Files have different raster sizes:
# Size (111, 143) occurs 60 times
# Size (111, 142) occurs 120 times
#  - USA_14216500 regridding starting.
#    USA_14216500 regridding complete.
# All files have the same raster size: (80, 173)
#  - USA_14222500 OK as is.
# All files have the same raster size: (81, 179)
#  - USA_14236200 OK as is.
# All files have the same raster size: (192, 338)
#  - USA_14301000 OK as is.
# All files have the same raster size: (12, 20)
#  - USA_14303200 OK as is.
# Files have different raster sizes:
# Size (132, 144) occurs 60 times
# Size (132, 143) occurs 120 times
#  - USA_14305500 regridding starting.
#    USA_14305500 regridding complete.
# Files have different raster sizes:
# Size (17, 28) occurs 60 times
# Size (16, 29) occurs 118 times
# Size (16, 28) occurs 2 times
#  - USA_14306340 regridding starting.
# Setting nodata to 0 instead of None in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/USA_14306340/geospatial/soilgrids/raw/clay/clay_0-5cm_mean.tif
# Setting nodata to 0 instead of None in /gpfs/tp/gwf/gwf_cmt/wknoben/camels_spat/camels-spat-data/basin_data/USA_14306340/geospatial/soilgrids/raw/silt/silt_0-5cm_mean.tif
#    USA_14306340 regridding complete.
# Files have different raster sizes:
# Size (139, 221) occurs 60 times
# Size (138, 221) occurs 120 times
#  - USA_14306500 regridding starting.
#    USA_14306500 regridding complete.
# Files have different raster sizes:
# Size (64, 95) occurs 60 times
# Size (65, 95) occurs 120 times
#  - USA_14308990 regridding starting.
#    USA_14308990 regridding complete.
# Files have different raster sizes:
# Size (70, 121) occurs 60 times
# Size (69, 121) occurs 120 times
#  - USA_14309500 regridding starting.
#    USA_14309500 regridding complete.
# Files have different raster sizes:
# Size (118, 172) occurs 60 times
# Size (119, 173) occurs 120 times
#  - USA_14316700 regridding starting.
#    USA_14316700 regridding complete.
# Files have different raster sizes:
# Size (107, 139) occurs 60 times
# Size (107, 140) occurs 120 times
#  - USA_14325000 regridding starting.
#    USA_14325000 regridding complete.
# Files have different raster sizes:
# Size (27, 46) occurs 60 times
# Size (27, 47) occurs 120 times
#  - USA_14362250 regridding starting.
#    USA_14362250 regridding complete.
# Files have different raster sizes:
# Size (113, 197) occurs 60 times
# Size (114, 197) occurs 120 times
#  - USA_14400000 regridding starting.
#    USA_14400000 regridding complete.

# %% [markdown]
# ### Manual fixes
# The "no data" assumption doesn't work in 3 cases. Here we fix those.

# %%
rerun_these = ['CAN_02PD014','CAN_05EE006','CAN_08OA003']

# %%
for basin_id in rerun_these:

    # Main path
    soil_folder = basins_path / 'basin_data' / basin_id / 'geospatial' / 'soilgrids' / 'raw'

    # Restore the backup
    shutil.rmtree(soil_folder) # Removes the improperly processed files
    shutil.copytree(soil_folder.parent / 'raw_backup', soil_folder) # Restores backup folder as main

    # Find the files
    tif_files = []
    for sub_folder in sub_folders:
        tif_files.append(glob.glob( str( soil_folder / sub_folder / '*.tif' ) ))
        
    tif_files = [file for files in tif_files for file in files] # flattens
    tif_files = sorted(tif_files) # doesn't matter, but cleaner when looking at logs

    # Loop over the files and extract the raster sizes
    paths,sizes,counts = get_raster_size(tif_files)

    # Confirm that we do indeed need to process these restored backup files
    if check_if_regrid_needed(paths,sizes,counts, disp_individual = False):

        # Progress
        print(f' - {basin_id} regridding starting.')

        # Get the most common size
        most_common = max(counts, key=counts.get) # (height, width)
    
        # Get the associated GeoTIFF profile
        template_profile = get_most_common_profile(sizes, most_common)
    
        # Get the nodata mask, to fix those geotiffs that don't have proper nodata values set
        template_masked_array = get_most_common_nodata_mask(sizes,most_common)
    
        # Loop over the files and regrid if needed
        for path,size in sizes.items():
            if size != most_common:

                # Here we would originally call regrid_geotiff()
                # Now do this manually to skip the step we don't need

                # Specify function inputs
                input_file = path
                output_file = path
                new_height = most_common[0]
                new_width = most_common[1]
                nodata_template = template_masked_array
                profile_template = template_profile

                # -- Regrid
                # Resample the raster to the desired size
                with rasterio.open(input_file) as src:
                    data = src.read(
                        out_shape=(src.count, new_height, new_width),
                        resampling=Resampling.bilinear
                    )
                    profile = src.profile

                # Update the profile with the new (correct) transform and nodata values.
                profile['width'] = new_width
                profile['height'] = new_height
                profile['transform'] = profile_template['transform']

                # Apply the nodata mask      
                data[nodata_template.mask] = profile['nodata'] # This is where we have known nodata

                # Write the resampled data to a new GeoTIFF file
                with rasterio.open(output_file, 'w', **profile) as dst:
                    dst.write(data)
# Out:
# Files have different raster sizes:
# Size (7, 7) occurs 60 times
# Size (7, 8) occurs 120 times
#  - CAN_02PD014 regridding starting.
# Files have different raster sizes:
# Size (5, 5) occurs 60 times
# Size (6, 4) occurs 120 times
#  - CAN_05EE006 regridding starting.
# Files have different raster sizes:
# Size (5, 6) occurs 60 times
# Size (5, 5) occurs 120 times
#  - CAN_08OA003 regridding starting.
