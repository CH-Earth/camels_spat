# %% [markdown]
# # Subset geotiffs to basin shapefile outlines

# %%
import glob
import os
import pandas as pd
import sys
from pathlib import Path
sys.path.append(str(Path().absolute().parent))
import python_cs_functions as cs

# %% [markdown]
# ### Config handling

# %%
# Specify where the config file can be found
config_file = '../0_config/config.txt'

# %%
# Get the required info from the config file
data_path            = cs.read_from_config(config_file,'data_path')
geospatial_temp_path = cs.read_from_config(config_file,'geospatial_temp_path')

# CAMELS-spat metadata
cs_meta_path = cs.read_from_config(config_file,'cs_basin_path')
cs_meta_name = cs.read_from_config(config_file,'cs_meta_name')
cs_unusable_name = cs.read_from_config(config_file,'cs_unusable_name')

# Basin folder
cs_basin_folder = cs.read_from_config(config_file, 'cs_basin_path')
basins_path = Path(data_path) / cs_basin_folder

# %% [markdown]
# ### Data loading

# %%
# CAMELS-spat metadata file
cs_meta_path = Path(data_path) / cs_meta_path
cs_meta = pd.read_csv(cs_meta_path / cs_meta_name)

# %%
# Open list of unusable stations; Enforce reading IDs as string to keep leading 0's
cs_unusable = pd.read_csv(cs_meta_path / cs_unusable_name, dtype={'Station_id': object})

# %% [markdown]
# ### Find an overview of the data we have

# %%
data_folder = Path(data_path) / geospatial_temp_path
data_folders = glob.glob( str(data_folder/'*')) # E.g., geospatial_temp/lai

# %%
data_files = []
for root, dirnames, filenames in os.walk(data_folder):
    if filenames:
        for file in filenames:
            if file.endswith('.shp'):
                data_files.append(Path(root + '/' + file))

# %% [markdown]
# ### Processing

# %%
debug_message = f'\n!!! CHECK DEBUGGING STATUS: \n- Full run in progress'

# %%
print(debug_message)

# Loop over the files we want to subset
for file in data_files:

    # Load the source data now, so we only need to do that once
    src = gpd.read_file(file)
    print(f'Processing {file}')
        
    for ix,row in cs_meta.iterrows():

        # DEBUGGING
        #if ix != 0: continue

        # Get shapefile path to determine download coordinates, and forcing destination path
        basin_id, shp_lump_path, _, _, _ = cs.prepare_delineation_outputs(cs_meta, ix, basins_path)
        print(f' - Processing {basin_id}')

        # Get the relative path compared to download folder; 
        # In other words, find which folders we want to create for the basin
        relative_path = file.relative_to(data_folder)
        des_folder = basins_path / 'basin_data' / basin_id / 'geospatial' / os.path.dirname(relative_path)
        
        # Subset the file
        subset_shapefile_to_shapefile(src, file, shp_lump_path, des_folder)
# Out:
# !!! CHECK DEBUGGING STATUS:
# - Full run in progress
# Processing /Users/wmk934/data/CAMELS_spat/geospatial_temp/glhymps/raw/glhymps.shp
#  - Processing CAN_01AD002
#  - Processing CAN_01AD003
#  - Processing CAN_01AE001
#  - Processing CAN_01AF007
#  - Processing CAN_01AF009
#  - Processing CAN_01AJ003
#  - Processing CAN_01AJ004
#  - Processing CAN_01AJ010
#  - Processing CAN_01AK001
#  - Processing CAN_01AK006
#  - Processing CAN_01AK007
#  - Processing CAN_01AL002
#  - Processing CAN_01AL004
#  - Processing CAN_01AM001
#  - Processing CAN_01AN002
#  - Processing CAN_01AP002
#  - Processing CAN_01AP004
#  - Processing CAN_01AP006
#  - Processing CAN_01AQ001
#  - Processing CAN_01BC001
#  - Processing CAN_01BD008
#  - Processing CAN_01BE001
#  - Processing CAN_01BG005
#  - Processing CAN_01BG008
#  - Processing CAN_01BG009
#  - Processing CAN_01BH005
#  - Processing CAN_01BH010
#  - Processing CAN_01BJ003
#  - Processing CAN_01BJ007
#  - Processing CAN_01BJ010
#  - Processing CAN_01BJ012
#  - Processing CAN_01BL002
#  - Processing CAN_01BL003
#  - Processing CAN_01BO001
#  - Processing CAN_01BP001
#  - Processing CAN_01BP002
#  - Processing CAN_01BQ001
#  - Processing CAN_01BS001
#  - Processing CAN_01BU002
#  - Processing CAN_01BU009
#  - Processing CAN_01BV004
#  - Processing CAN_01BV006
#  - Processing CAN_01CA003
#  - Processing CAN_01CC005
#  - Processing CAN_01CD005
#  - Processing CAN_01DG003
#  - Processing CAN_01DJ005
#  - Processing CAN_01DL001
#  - Processing CAN_01DP004
#  - Processing CAN_01DR001
#  - Processing CAN_01EC001
#  - Processing CAN_01ED005
#  - Processing CAN_01ED007
#  - Processing CAN_01EE005
#  - Processing CAN_01EF001
#  - Processing CAN_01EO001
#  - Processing CAN_01FA001
#  - Processing CAN_01FB001
#  - Processing CAN_01FB003
#  - Processing CAN_01FJ002
#  - Processing CAN_02AB008
#  - Processing CAN_02AB014
#  - Processing CAN_02AB017
#  - Processing CAN_02AB021
#  - Processing CAN_02AC001
#  - Processing CAN_02AC002
#  - Processing CAN_02AD010
#  - Processing CAN_02AE001
#  - Processing CAN_02BA003
#  - Processing CAN_02BA005
#  - Processing CAN_02BB003
#  - Processing CAN_02BF001
#  - Processing CAN_02BF002
#  - Processing CAN_02BF004
#  - Processing CAN_02BF005
#  - Processing CAN_02BF006
#  - Processing CAN_02BF007
#  - Processing CAN_02BF008
#  - Processing CAN_02BF009
#  - Processing CAN_02BF012
#  - Processing CAN_02BF013
#  - Processing CAN_02CA002
#  - Processing CAN_02CB003
#  - Processing CAN_02CF007
#  - Processing CAN_02CF008
#  - Processing CAN_02CF011
#  - Processing CAN_02CG003
#  - Processing CAN_02DB007
#  - Processing CAN_02DC012
#  - Processing CAN_02DD012
#  - Processing CAN_02DD013
#  - Processing CAN_02DD015
#  - Processing CAN_02EA005
#  - Processing CAN_02EA010
#  - Processing CAN_02EB014
#  - Processing CAN_02EC002
#  - Processing CAN_02EC010
#  - Processing CAN_02EC011
#  - Processing CAN_02EC018
#  - Processing CAN_02ED003
#  - Processing CAN_02ED007
#  - Processing CAN_02ED013
#  - Processing CAN_02ED014
#  - Processing CAN_02ED015
#  - Processing CAN_02ED017
#  - Processing CAN_02ED024
#  - Processing CAN_02ED026
#  - Processing CAN_02ED101
#  - Processing CAN_02ED102
#  - Processing CAN_02FA002
#  - Processing CAN_02FA004
#  - Processing CAN_02FB007
#  - Processing CAN_02FB010
#  - Processing CAN_02FC011
#  - Processing CAN_02FC016
#  - Processing CAN_02FC017
#  - Processing CAN_02FD001
#  - Processing CAN_02FD002
#  - Processing CAN_02FE008
#  - Processing CAN_02FE009
#  - Processing CAN_02FE011
#  - Processing CAN_02FE013
#  - Processing CAN_02FE014
#  - Processing CAN_02FF004
#  - Processing CAN_02FF007
#  - Processing CAN_02FF008
#  - Processing CAN_02GA010
#  - Processing CAN_02GA018
#  - Processing CAN_02GA038
#  - Processing CAN_02GA041
#  - Processing CAN_02GA043
#  - Processing CAN_02GB007
#  - Processing CAN_02GC002
#  - Processing CAN_02GC010
#  - Processing CAN_02GC018
#  - Processing CAN_02GC021
#  - Processing CAN_02GC029
#  - Processing CAN_02GC030
#  - Processing CAN_02GC031
#  - Processing CAN_02GD004
#  - Processing CAN_02GD010
#  - Processing CAN_02GD019
#  - Processing CAN_02GD021
#  - Processing CAN_02GE007
#  - Processing CAN_02GG002
#  - Processing CAN_02GG003
#  - Processing CAN_02GG005
#  - Processing CAN_02GG006
#  - Processing CAN_02GG009
#  - Processing CAN_02GH002
#  - Processing CAN_02GH003
#  - Processing CAN_02HA006
#  - Processing CAN_02HA020
#  - Processing CAN_02HB012
#  - Processing CAN_02HB022
#  - Processing CAN_02HB023
#  - Processing CAN_02HC019
#  - Processing CAN_02HC023
#  - Processing CAN_02HC025
#  - Processing CAN_02HC038
#  - Processing CAN_02HC047
#  - Processing CAN_02HC049
#  - Processing CAN_02HD009
#  - Processing CAN_02HD012
#  - Processing CAN_02HG001
#  - Processing CAN_02HJ001
#  - Processing CAN_02HK007
#  - Processing CAN_02HK008
#  - Processing CAN_02HL003
#  - Processing CAN_02HL004
#  - Processing CAN_02HL005
#  - Processing CAN_02HM004
#  - Processing CAN_02HM005
#  - Processing CAN_02JB013
#  - Processing CAN_02JC008
#  - Processing CAN_02KF016
#  - Processing CAN_02KF017
#  - Processing CAN_02LA007
#  - Processing CAN_02LB006
#  - Processing CAN_02LB007
#  - Processing CAN_02LB008
#  - Processing CAN_02LB017
#  - Processing CAN_02LB020
#  - Processing CAN_02LB022
#  - Processing CAN_02LC027
#  - Processing CAN_02LC043
#  - Processing CAN_02LD005
#  - Processing CAN_02LG005
#  - Processing CAN_02MB006
#  - Processing CAN_02MC001
#  - Processing CAN_02MC026
#  - Processing CAN_02MC028
#  - Processing CAN_02NE011
#  - Processing CAN_02NF003
#  - Processing CAN_02OA057
#  - Processing CAN_02OB032
#  - Processing CAN_02OB037
#  - Processing CAN_02OD003
#  - Processing CAN_02OE027
#  - Processing CAN_02OE032
#  - Processing CAN_02OG026
#  - Processing CAN_02OJ024
#  - Processing CAN_02OJ026
#  - Processing CAN_02PA007
#  - Processing CAN_02PB006
#  - Processing CAN_02PC018
#  - Processing CAN_02PC019
#  - Processing CAN_02PD002
#  - Processing CAN_02PD004
#  - Processing CAN_02PD012
#  - Processing CAN_02PD013
#  - Processing CAN_02PD014
#  - Processing CAN_02PD015
#  - Processing CAN_02PE014
#  - Processing CAN_02PG006
#  - Processing CAN_02PG022
#  - Processing CAN_02PJ007
#  - Processing CAN_02PJ030
#  - Processing CAN_02PL005
#  - Processing CAN_02QA002
#  - Processing CAN_02QC009
#  - Processing CAN_02RC011
#  - Processing CAN_02RD003
#  - Processing CAN_02RF001
#  - Processing CAN_02RF009
#  - Processing CAN_02RG005
#  - Processing CAN_02RH027
#  - Processing CAN_02RH035
#  - Processing CAN_02RH045
#  - Processing CAN_02UA003
#  - Processing CAN_02UC002
#  - Processing CAN_02VB004
#  - Processing CAN_02WB003
#  - Processing CAN_02XA003
#  - Processing CAN_02XC001
#  - Processing CAN_02YA002
#  - Processing CAN_02YC001
#  - Processing CAN_02YD002
#  - Processing CAN_02YE001
#  - Processing CAN_02YG001
#  - Processing CAN_02YJ001
#  - Processing CAN_02YK002
#  - Processing CAN_02YK005
#  - Processing CAN_02YK008
#  - Processing CAN_02YL001
#  - Processing CAN_02YL004
#  - Processing CAN_02YL005
#  - Processing CAN_02YL008
#  - Processing CAN_02YL011
#  - Processing CAN_02YM003
#  - Processing CAN_02YM004
#  - Processing CAN_02YN002
#  - Processing CAN_02YO006
#  - Processing CAN_02YO008
#  - Processing CAN_02YO012
#  - Processing CAN_02YQ001
#  - Processing CAN_02YQ005
#  - Processing CAN_02YR001
#  - Processing CAN_02YR003
#  - Processing CAN_02YS003
#  - Processing CAN_02YS005
#  - Processing CAN_02YS006
#  - Processing CAN_02ZA002
#  - Processing CAN_02ZB001
#  - Processing CAN_02ZC002
#  - Processing CAN_02ZD002
#  - Processing CAN_02ZE004
#  - Processing CAN_02ZF001
#  - Processing CAN_02ZG001
#  - Processing CAN_02ZG003
#  - Processing CAN_02ZG004
#  - Processing CAN_02ZH001
#  - Processing CAN_02ZH002
#  - Processing CAN_02ZJ001
#  - Processing CAN_02ZJ002
#  - Processing CAN_02ZJ003
#  - Processing CAN_02ZK001
#  - Processing CAN_02ZK002
#  - Processing CAN_02ZK003
#  - Processing CAN_02ZK004
#  - Processing CAN_02ZL004
#  - Processing CAN_02ZL005
#  - Processing CAN_02ZM006
#  - Processing CAN_02ZM009
#  - Processing CAN_02ZM016
#  - Processing CAN_02ZN002
#  - Processing CAN_03AB002
#  - Processing CAN_03AC004
#  - Processing CAN_03BD002
#  - Processing CAN_03BF001
#  - Processing CAN_03ED001
#  - Processing CAN_03FA003
#  - Processing CAN_03KC004
#  - Processing CAN_03MB002
#  - Processing CAN_03MD001
#  - Processing CAN_03NF001
#  - Processing CAN_03OC003
#  - Processing CAN_03OE010
#  - Processing CAN_03QC001
#  - Processing CAN_03QC002
#  - Processing CAN_04AA004
#  - Processing CAN_04AB001
#  - Processing CAN_04AD002
#  - Processing CAN_04CA002
#  - Processing CAN_04CA003
#  - Processing CAN_04CB001
#  - Processing CAN_04DA001
#  - Processing CAN_04DB001
#  - Processing CAN_04DC001
#  - Processing CAN_04DC002
#  - Processing CAN_04EA001
#  - Processing CAN_04FA001
#  - Processing CAN_04FA003
#  - Processing CAN_04FB001
#  - Processing CAN_04FC001
#  - Processing CAN_04GA002
#  - Processing CAN_04GB004
#  - Processing CAN_04GB005
#  - Processing CAN_04JC002
#  - Processing CAN_04JD005
#  - Processing CAN_04JF001
#  - Processing CAN_04KA001
#  - Processing CAN_04LJ001
#  - Processing CAN_04LM001
#  - Processing CAN_04MD004
#  - Processing CAN_04MF001
#  - Processing CAN_04NA001
#  - Processing CAN_05AA004
#  - Processing CAN_05AA008
#  - Processing CAN_05AA011
#  - Processing CAN_05AA022
#  - Processing CAN_05AA028
#  - Processing CAN_05AA909
#  - Processing CAN_05AB005
#  - Processing CAN_05AB013
#  - Processing CAN_05AB029
#  - Processing CAN_05AC030
#  - Processing CAN_05AD003
#  - Processing CAN_05AD035
#  - Processing CAN_05AE005
#  - Processing CAN_05AH037
#  - Processing CAN_05AH041
#  - Processing CAN_05AH047
#  - Processing CAN_05AH050
#  - Processing CAN_05BA001
#  - Processing CAN_05BB001
#  - Processing CAN_05BG006
#  - Processing CAN_05BH013
#  - Processing CAN_05BJ004
#  - Processing CAN_05BJ010
#  - Processing CAN_05BK001
#  - Processing CAN_05BL013
#  - Processing CAN_05BL014
#  - Processing CAN_05BL019
#  - Processing CAN_05BL022
#  - Processing CAN_05BL023
#  - Processing CAN_05BL027
#  - Processing CAN_05BM014
#  - Processing CAN_05BM018
#  - Processing CAN_05CA002
#  - Processing CAN_05CA004
#  - Processing CAN_05CA009
#  - Processing CAN_05CA011
#  - Processing CAN_05CA012
#  - Processing CAN_05CB001
#  - Processing CAN_05CB002
#  - Processing CAN_05CB004
#  - Processing CAN_05CC001
#  - Processing CAN_05CC007
#  - Processing CAN_05CC008
#  - Processing CAN_05CC009
#  - Processing CAN_05CC010
#  - Processing CAN_05CC011
#  - Processing CAN_05CD006
#  - Processing CAN_05CD007
#  - Processing CAN_05CE002
#  - Processing CAN_05CE006
#  - Processing CAN_05CE010
#  - Processing CAN_05CE011
#  - Processing CAN_05CE018
#  - Processing CAN_05CE020
#  - Processing CAN_05CG004
#  - Processing CAN_05CG006
#  - Processing CAN_05CK001
#  - Processing CAN_05CK005
#  - Processing CAN_05DA007
#  - Processing CAN_05DA009
#  - Processing CAN_05DA010
#  - Processing CAN_05DB002
#  - Processing CAN_05DB005
#  - Processing CAN_05DB006
#  - Processing CAN_05DC006
#  - Processing CAN_05DC011
#  - Processing CAN_05DC012
#  - Processing CAN_05DD004
#  - Processing CAN_05DD007
#  - Processing CAN_05DD009
#  - Processing CAN_05DE007
#  - Processing CAN_05DF003
#  - Processing CAN_05DF004
#  - Processing CAN_05DF006
#  - Processing CAN_05DF007
#  - Processing CAN_05EA001
#  - Processing CAN_05EA002
#  - Processing CAN_05EA005
#  - Processing CAN_05EA010
#  - Processing CAN_05EB902
#  - Processing CAN_05EC002
#  - Processing CAN_05EC005
#  - Processing CAN_05ED002
#  - Processing CAN_05EE005
#  - Processing CAN_05EE006
#  - Processing CAN_05EE009
#  - Processing CAN_05EF004
#  - Processing CAN_05EF005
#  - Processing CAN_05EF006
#  - Processing CAN_05EG004
#  - Processing CAN_05FA001
#  - Processing CAN_05FA012
#  - Processing CAN_05FA014
#  - Processing CAN_05FA024
#  - Processing CAN_05FB002
#  - Processing CAN_05FC002
#  - Processing CAN_05FC004
#  - Processing CAN_05FC007
#  - Processing CAN_05FE002
#  - Processing CAN_05FF003
#  - Processing CAN_05GA008
#  - Processing CAN_05GA010
#  - Processing CAN_05GA012
#  - Processing CAN_05GB004
#  - Processing CAN_05GC007
#  - Processing CAN_05GD002
#  - Processing CAN_05GF001
#  - Processing CAN_05GF002
#  - Processing CAN_05GG010
#  - Processing CAN_05HA015
#  - Processing CAN_05HD036
#  - Processing CAN_05HE001
#  - Processing CAN_05HG021
#  - Processing CAN_05HH002
#  - Processing CAN_05HH003
#  - Processing CAN_05JA003
#  - Processing CAN_05JB004
#  - Processing CAN_05JB007
#  - Processing CAN_05JC004
#  - Processing CAN_05JC007
#  - Processing CAN_05JF011
#  - Processing CAN_05JF014
#  - Processing CAN_05JG001
#  - Processing CAN_05JG013
#  - Processing CAN_05JH005
#  - Processing CAN_05JJ009
#  - Processing CAN_05JK008
#  - Processing CAN_05JM010
#  - Processing CAN_05KB003
#  - Processing CAN_05KB006
#  - Processing CAN_05KB011
#  - Processing CAN_05KC001
#  - Processing CAN_05KE005
#  - Processing CAN_05KE007
#  - Processing CAN_05KE010
#  - Processing CAN_05KF001
#  - Processing CAN_05KG007
#  - Processing CAN_05KH007
#  - Processing CAN_05KJ014
#  - Processing CAN_05LA003
#  - Processing CAN_05LB004
#  - Processing CAN_05LB006
#  - Processing CAN_05LB008
#  - Processing CAN_05LB010
#  - Processing CAN_05LC001
#  - Processing CAN_05LD001
#  - Processing CAN_05LD003
#  - Processing CAN_05LE004
#  - Processing CAN_05LE005
#  - Processing CAN_05LE006
#  - Processing CAN_05LE008
#  - Processing CAN_05LE010
#  - Processing CAN_05LE011
#  - Processing CAN_05LG004
#  - Processing CAN_05LH005
#  - Processing CAN_05LJ005
#  - Processing CAN_05LJ007
#  - Processing CAN_05LJ027
#  - Processing CAN_05LJ045
#  - Processing CAN_05LL014
#  - Processing CAN_05LL015
#  - Processing CAN_05LL027
#  - Processing CAN_05MA020
#  - Processing CAN_05MA021
#  - Processing CAN_05MA025
#  - Processing CAN_05MC001
#  - Processing CAN_05MC002
#  - Processing CAN_05MC003
#  - Processing CAN_05MD005
#  - Processing CAN_05MD010
#  - Processing CAN_05ME003
#  - Processing CAN_05ME005
#  - Processing CAN_05ME007
#  - Processing CAN_05MF001
#  - Processing CAN_05MF008
#  - Processing CAN_05MG001
#  - Processing CAN_05MG003
#  - Processing CAN_05MH006
#  - Processing CAN_05MH007
#  - Processing CAN_05MH008
#  - Processing CAN_05NB033
#  - Processing CAN_05NB035
#  - Processing CAN_05ND011
#  - Processing CAN_05NE003
#  - Processing CAN_05NF002
#  - Processing CAN_05NF006
#  - Processing CAN_05NF008
#  - Processing CAN_05NF010
#  - Processing CAN_05NG010
#  - Processing CAN_05NG012
#  - Processing CAN_05NG020
#  - Processing CAN_05OA007
#  - Processing CAN_05OB010
#  - Processing CAN_05OB016
#  - Processing CAN_05OB021
#  - Processing CAN_05OC016
#  - Processing CAN_05OC019
#  - Processing CAN_05OC022
#  - Processing CAN_05OE004
#  - Processing CAN_05OE006
#  - Processing CAN_05OE007
#  - Processing CAN_05OE009
#  - Processing CAN_05OE010
#  - Processing CAN_05OF009
#  - Processing CAN_05OF011
#  - Processing CAN_05OF014
#  - Processing CAN_05OF017
#  - Processing CAN_05OF018
#  - Processing CAN_05OF020

# %% [markdown]
# ### Functions

# %%
import geopandas as gpd

# %%
def subset_shapefile_to_shapefile(src,src_file,src_shape,des_folder):

    # Input cleaning
    des_folder.mkdir(parents=True, exist_ok=True)
    des_file  = str(des_folder / os.path.basename(src_file))
    src_file  = str(src_file)
    src_shape = str(src_shape)
   
    # Open the basin shapefile
    shp = gpd.read_file(src_shape)
    
    # Loop over the geometries to check if they intersect, then use this info to create a HydroLAKES subset
    # Note: this is cleaner than des = gpd.overlay(src,shp, how='intersection'), because this alternative
    #   approach may be faster, but it clips the lake polygons to the catchment extent. The consequence of
    #   this is that the lake area reported as part of the HydroLAKES subset may be inaccurate, in cases
    #   where that polygon was clipped by the catchment outline. With the current approach we return the
    #   complete lake polygons.
    if 'hydrolakes' in src_file.lower():
        src['mask'] = src.apply(lambda row: row.geometry.intersects(shp.geometry), axis=1)
        des = src[src['mask'] == True].copy().reset_index(drop=True)
        des = des.drop('mask', axis=1)
    elif 'glhymps' in src_file.lower():
        des = gpd.overlay(src,shp,how='intersection') # Faster than above, clipping these polygons is fine because they don't contain an 'area' field
    
    # To file
    des.to_file(des_file)

    return # nothing
