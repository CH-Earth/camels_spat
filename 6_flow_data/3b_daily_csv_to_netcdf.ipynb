# %% [markdown]
# # Convert daily .csv files to .nc
#
# Netcdf instructions:
# - CF Conventions: http://cfconventions.org/
# - CF Standard names: http://cfconventions.org/Data/cf-standard-names/current/build/cf-standard-name-table.html
# - Oak Ridge National Lab guide: https://daac.ornl.gov/submit/netcdfrequirements/

# %%
import os
import sys
import shutil
import pandas as pd
from pathlib import Path
sys.path.append(str(Path().absolute().parent))
import python_cs_functions as cs

# %% [markdown]
# ### Config handling

# %%
# Specify where the config file can be found
config_file = '../0_config/config.txt'

# %%
# Get the required info from the config file
data_path     = cs.read_from_config(config_file,'data_path')

# CAMELS-spat metadata
cs_meta_path  = cs.read_from_config(config_file,'cs_basin_path')
cs_meta_name  = cs.read_from_config(config_file,'cs_meta_name')
cs_unusable_name = cs.read_from_config(config_file,'cs_unusable_name')

# Basin folder
cs_basin_folder = cs.read_from_config(config_file, 'cs_basin_path')
basins_path = Path(data_path) / cs_basin_folder

# %% [markdown]
# ### Data loading

# %%
# CAMELS-spat metadata file
cs_meta_path = Path(data_path) / cs_meta_path
cs_meta = pd.read_csv(cs_meta_path / cs_meta_name)

# %%
# Open list of unusable stations; Enforce reading IDs as string to keep leading 0's
cs_unusable = pd.read_csv(cs_meta_path / cs_unusable_name, dtype={'Station_id': object})

# %% [markdown]
# ## Processing
# ### NetCDF requirements:
#
# #### Time variable
# Needs to have attributes:
# - `standard_name` = `time`
# - `units`: CF conventions (e.g. `unit since date`)
# - `calendar`: http://cfconventions.org/Data/cf-conventions/cf-conventions-1.7/cf-conventions.html#calendar
# - `bounds` = `time_bnds`; a separate 2-dimensional variable that defines the start and end time points of each measurement. Variable "time_bnds" has the same attributes "units" and "calendar" as variable "time".
#
# #### Data variables
# Need to have attributes:
# - `units`: (UDUNITS-2) recommended
# - `long_name`: description of variable
# - `_FillValue`: ?
#
# #### Global attributes
# - `title`: data set name
# - `institution`: specifies where the original data was produced (USGS, WSC)
# - `source`: way data was derived?
# - `references`: USGS or WSC
# - `history`: audit trail for modifications to original data
# - `comment`: _optional_
#
# ### Variables and attributes to be included
# - var: `time`
# - var: `time_bnds`
# - var: `q_obs`
# - var: `quality`
# - att: `country`
# - att: `station_id`
# - att: `station_name`

# %%
# Determine what to do with raw files
remove_raw    = False # If True: removes the raw file
move_raw      = True # If True: moves raw file to new location specified by move_raw_here
assert not (remove_raw and move_raw), 'remove_raw and move_raw cannot both be True' # this means we can use simple logic later

# %%
if move_raw:
    move_raw_here = 'D:/CAMELS_spat' 
    move_raw_path = Path(move_raw_here) / cs_basin_folder / 'basin_data' # Mimic existing data structure

# %%
# Subset the cs_unusable list to those entries that indicate station does not have IV values
subset_column = 'Missing'
subset_to = 'dv'
cs_unusable_masked = cs_unusable[cs_unusable[subset_column] == subset_to]

# %%
for ix,row in cs_meta.iterrows():
    
    # Skip over metadata entries we cannot use
    if row.Station_id in cs_unusable_masked['Station_id'].values:
        continue # to next row
        
    # 1. Get paths, etc
    site, _, _, csv_path, _, nc_path = cs.prepare_flow_download_outputs(cs_meta, ix, basins_path, time='daily')
    print(f'{ix: >3}. Now working on {site}')
    
    # Resume after interupts
    if not os.path.isfile(csv_path): # If csv file doesn't exist it must have been processed already 
        continue                          #   Note: assumes remove_raw or move_raw are True 
       
    # 2. Load the csv
    csv = cs.prep_daily_country_csv_for_netcdf(csv_path, row.Country, row.dv_flow_obs_timezone)
    
    # 3. Add the time bounds for daily averages in UTC. Steps:
    # - Get the dates as string for later use
    # - Convert timezone string ('EST') to 'UTC-0xxx'
    # - Convert 'UTC-0xxx' to '+0x:00'
    # - Convert 'yy-mm-dd 00:00' to UTC datetime. This is the left bound of the interval
    # - Add 24 hours to the left bound to find the right bound
    csv['datetime']    = csv.index.strftime('%Y-%m-%d 00:00') 
    csv['tz_utc_str']  = csv.apply(lambda row: cs.tz_abbreviation_to_utc( row['q_obs_tz_cd'] ), axis=1)
    csv['tz_td_str']   = csv.apply(lambda row: cs.relative_utc_to_timedelta( row['tz_utc_str'] ), axis=1)
    csv['time_bnds_l'] = csv.apply(lambda row: cs.datetime_str_to_timeaware_datetime( row['datetime'], row['tz_td_str'], 
                                                                                     localize_to_UTC=False ), axis=1)
    csv['time_bnds_r'] = csv.apply(lambda row: row['time_bnds_l'] + pd.Timedelta(hours=24), axis=1)
    
    # 4. Convert to netcdf and save
    ds = cs.daily_flow_csv_to_netcdf(csv, nc_path, row.Country, site)
    ds.close()
    
    # 5. (Re)move the csv file
    if remove_raw:
        os.remove(csv_path)
    if move_raw:
        move_path = move_raw_path / f'{row.Country}_{site}' / 'observations'
        move_path.mkdir(parents=True, exist_ok=True)
        move_file = os.path.basename(csv_path)
        shutil.move(csv_path, move_path/move_file)
# Out:
#   0. Now working on 01AD002
#   1. Now working on 01AD003
#   2. Now working on 01AE001
#   3. Now working on 01AF007
#   4. Now working on 01AF009
#   5. Now working on 01AJ003
#   6. Now working on 01AJ004
#   7. Now working on 01AJ010
#   8. Now working on 01AK001
#   9. Now working on 01AK006
#  10. Now working on 01AK007
#  11. Now working on 01AL002
#  12. Now working on 01AL004
#  13. Now working on 01AM001
#  14. Now working on 01AN002
#  15. Now working on 01AP002
#  16. Now working on 01AP004
#  17. Now working on 01AP006
#  18. Now working on 01AQ001
#  19. Now working on 01BC001
#  20. Now working on 01BD008
#  21. Now working on 01BE001
#  22. Now working on 01BG005
#  23. Now working on 01BG008
#  24. Now working on 01BG009
#  25. Now working on 01BH005
#  26. Now working on 01BH010
#  27. Now working on 01BJ003
#  28. Now working on 01BJ007
#  29. Now working on 01BJ010
#  30. Now working on 01BJ012
#  31. Now working on 01BL002
#  32. Now working on 01BL003
#  33. Now working on 01BO001
#  34. Now working on 01BP001
#  35. Now working on 01BP002
#  36. Now working on 01BQ001
#  37. Now working on 01BS001
#  38. Now working on 01BU002
#  39. Now working on 01BU009
#  40. Now working on 01BV004
#  41. Now working on 01BV006
#  42. Now working on 01CA003
#  43. Now working on 01CC005
#  44. Now working on 01CD005
#  45. Now working on 01DG003
#  46. Now working on 01DJ005
#  47. Now working on 01DL001
#  48. Now working on 01DP004
#  49. Now working on 01DR001
#  50. Now working on 01EC001
#  51. Now working on 01ED005
#  52. Now working on 01ED007
#  53. Now working on 01EE005
#  54. Now working on 01EF001
#  55. Now working on 01EO001
#  56. Now working on 01FA001
#  57. Now working on 01FB001
#  58. Now working on 01FB003
#  59. Now working on 01FJ002
#  60. Now working on 02AB008
#  61. Now working on 02AB014
#  62. Now working on 02AB017
#  63. Now working on 02AB021
#  64. Now working on 02AC001
#  65. Now working on 02AC002
#  66. Now working on 02AD010
#  67. Now working on 02AE001
#  68. Now working on 02BA003
#  69. Now working on 02BA005
#  70. Now working on 02BB003
#  71. Now working on 02BF001
#  72. Now working on 02BF002
#  73. Now working on 02BF004
#  74. Now working on 02BF005
#  75. Now working on 02BF006
#  76. Now working on 02BF007
#  77. Now working on 02BF008
#  78. Now working on 02BF009
#  79. Now working on 02BF012
#  80. Now working on 02BF013
#  81. Now working on 02CA002
#  82. Now working on 02CB003
#  83. Now working on 02CF007
#  84. Now working on 02CF008
#  85. Now working on 02CF011
#  86. Now working on 02CG003
#  87. Now working on 02DB007
#  88. Now working on 02DC012
#  89. Now working on 02DD012
#  90. Now working on 02DD013
#  91. Now working on 02DD015
#  92. Now working on 02EA005
#  93. Now working on 02EA010
#  94. Now working on 02EB014
#  95. Now working on 02EC002
#  96. Now working on 02EC010
#  97. Now working on 02EC011
#  98. Now working on 02EC018
#  99. Now working on 02ED003
# 100. Now working on 02ED007
# 101. Now working on 02ED013
# 102. Now working on 02ED014
# 103. Now working on 02ED015
# 104. Now working on 02ED017
# 105. Now working on 02ED024
# 106. Now working on 02ED026
# 107. Now working on 02ED101
# 108. Now working on 02ED102
# 109. Now working on 02FA002
# 110. Now working on 02FA004
# 111. Now working on 02FB007
# 112. Now working on 02FB010
# 113. Now working on 02FC011
# 114. Now working on 02FC016
# 115. Now working on 02FC017
# 116. Now working on 02FD001
# 117. Now working on 02FD002
# 118. Now working on 02FE008
# 119. Now working on 02FE009
# 120. Now working on 02FE011
# 121. Now working on 02FE013
# 122. Now working on 02FE014
# 123. Now working on 02FF004
# 124. Now working on 02FF007
# 125. Now working on 02FF008
# 126. Now working on 02GA010
# 127. Now working on 02GA018
# 128. Now working on 02GA038
# 129. Now working on 02GA041
# 130. Now working on 02GA043
# 131. Now working on 02GB007
# 132. Now working on 02GC002
# 133. Now working on 02GC010
# 134. Now working on 02GC018
# 135. Now working on 02GC021
# 136. Now working on 02GC029
# 137. Now working on 02GC030
# 138. Now working on 02GC031
# 139. Now working on 02GD004
# 140. Now working on 02GD010
# 141. Now working on 02GD019
# 142. Now working on 02GD021
# 143. Now working on 02GE007
# 144. Now working on 02GG002
# 145. Now working on 02GG003
# 146. Now working on 02GG005
# 147. Now working on 02GG006
# 148. Now working on 02GG009
# 149. Now working on 02GH002
# 150. Now working on 02GH003
# 151. Now working on 02HA006
# 152. Now working on 02HA020
# 153. Now working on 02HB012
# 154. Now working on 02HB022
# 155. Now working on 02HB023
# 156. Now working on 02HC019
# 157. Now working on 02HC023
# 158. Now working on 02HC025
# 159. Now working on 02HC038
# 160. Now working on 02HC047
# 161. Now working on 02HC049
# 162. Now working on 02HD009
# 163. Now working on 02HD012
# 164. Now working on 02HG001
# 165. Now working on 02HJ001
# 166. Now working on 02HK007
# 167. Now working on 02HK008
# 168. Now working on 02HL003
# 169. Now working on 02HL004
# 170. Now working on 02HL005
# 171. Now working on 02HM004
# 172. Now working on 02HM005
# 173. Now working on 02JB013
# 174. Now working on 02JC008
# 175. Now working on 02KF016
# 176. Now working on 02KF017
# 177. Now working on 02LA007
# 178. Now working on 02LB006
# 179. Now working on 02LB007
# 180. Now working on 02LB008
# 181. Now working on 02LB017
# 182. Now working on 02LB020
# 183. Now working on 02LB022
# 184. Now working on 02LC027
# 185. Now working on 02LC043
# 186. Now working on 02LD005
# 187. Now working on 02LG005
# 188. Now working on 02MB006
# 189. Now working on 02MC001
# 190. Now working on 02MC026
# 191. Now working on 02MC028
# 192. Now working on 02NE011
# 193. Now working on 02NF003
# 194. Now working on 02OA057
# 195. Now working on 02OB032
# 196. Now working on 02OB037
# 197. Now working on 02OD003
# 198. Now working on 02OE027
# 199. Now working on 02OE032
# 200. Now working on 02OG026
# 201. Now working on 02OJ024
# 202. Now working on 02OJ026
# 203. Now working on 02PA007
# 204. Now working on 02PB006
# 205. Now working on 02PC018
# 206. Now working on 02PC019
# 207. Now working on 02PD002
# 208. Now working on 02PD004
# 209. Now working on 02PD012
# 210. Now working on 02PD013
# 211. Now working on 02PD014
# 212. Now working on 02PD015
# 213. Now working on 02PE014
# 214. Now working on 02PG006
# 215. Now working on 02PG022
# 216. Now working on 02PJ007
# 217. Now working on 02PJ030
# 218. Now working on 02PL005
# 219. Now working on 02QA002
# 220. Now working on 02QC009
# 221. Now working on 02RC011
# 222. Now working on 02RD003
# 223. Now working on 02RF001
# 224. Now working on 02RF009
# 225. Now working on 02RG005
# 226. Now working on 02RH027
# 227. Now working on 02RH035
# 228. Now working on 02RH045
# 229. Now working on 02UA003
# 230. Now working on 02UC002
# 231. Now working on 02VB004
# 232. Now working on 02WB003
# 233. Now working on 02XA003
# 234. Now working on 02XC001
# 235. Now working on 02YA002
# 236. Now working on 02YC001
# 237. Now working on 02YD002
# 238. Now working on 02YE001
# 239. Now working on 02YG001
# 240. Now working on 02YJ001
# 241. Now working on 02YK002
# 242. Now working on 02YK005
# 243. Now working on 02YK008
# 244. Now working on 02YL001
# 245. Now working on 02YL004
# 246. Now working on 02YL005
# 247. Now working on 02YL008
# 248. Now working on 02YL011
# 249. Now working on 02YM003
# 250. Now working on 02YM004
# 251. Now working on 02YN002
# 252. Now working on 02YO006
# 253. Now working on 02YO008
# 254. Now working on 02YO012
# 255. Now working on 02YQ001
# 256. Now working on 02YQ005
# 257. Now working on 02YR001
# 258. Now working on 02YR003
# 259. Now working on 02YS003
# 260. Now working on 02YS005
# 261. Now working on 02YS006
# 262. Now working on 02ZA002
# 263. Now working on 02ZB001
# 264. Now working on 02ZC002
# 265. Now working on 02ZD002
# 266. Now working on 02ZE004
# 267. Now working on 02ZF001
# 268. Now working on 02ZG001
# 269. Now working on 02ZG003
# 270. Now working on 02ZG004
# 271. Now working on 02ZH001
# 272. Now working on 02ZH002
# 273. Now working on 02ZJ001
# 274. Now working on 02ZJ002
# 275. Now working on 02ZJ003
# 276. Now working on 02ZK001
# 277. Now working on 02ZK002
# 278. Now working on 02ZK003
# 279. Now working on 02ZK004
# 280. Now working on 02ZL004
# 281. Now working on 02ZL005
# 282. Now working on 02ZM006
# 283. Now working on 02ZM009
# 284. Now working on 02ZM016
# 285. Now working on 02ZN002
# 286. Now working on 03AB002
# 287. Now working on 03AC004
# 288. Now working on 03BD002
# 289. Now working on 03BF001
# 290. Now working on 03ED001
# 291. Now working on 03FA003
# 292. Now working on 03KC004
# 293. Now working on 03MB002
# 294. Now working on 03MD001
# 295. Now working on 03NF001
# 296. Now working on 03OC003
# 297. Now working on 03OE010
# 298. Now working on 03QC001
# 299. Now working on 03QC002
# 300. Now working on 04AA004
# 301. Now working on 04AB001
# 302. Now working on 04AD002
# 303. Now working on 04CA002
# 304. Now working on 04CA003
# 305. Now working on 04CB001
# 306. Now working on 04DA001
# 307. Now working on 04DB001
# 308. Now working on 04DC001
# 309. Now working on 04DC002
# 310. Now working on 04EA001
# 311. Now working on 04FA001
# 312. Now working on 04FA003
# 313. Now working on 04FB001
# 314. Now working on 04FC001
# 315. Now working on 04GA002
# 316. Now working on 04GB004
# 317. Now working on 04GB005
# 318. Now working on 04JC002
# 319. Now working on 04JD005
# 320. Now working on 04JF001
# 321. Now working on 04KA001
# 322. Now working on 04LJ001
# 323. Now working on 04LM001
# 324. Now working on 04MD004
# 325. Now working on 04MF001
# 326. Now working on 04NA001
# 327. Now working on 05AA004
# 328. Now working on 05AA008
# 329. Now working on 05AA011
# 330. Now working on 05AA022
# 331. Now working on 05AA028
# 332. Now working on 05AA909
# 333. Now working on 05AB005
# 334. Now working on 05AB013
# 335. Now working on 05AB029
# 336. Now working on 05AC030
# 337. Now working on 05AD003
# 338. Now working on 05AD035
# 339. Now working on 05AE005
# 340. Now working on 05AH037
# 341. Now working on 05AH041
# 342. Now working on 05AH047
# 343. Now working on 05AH050
# 344. Now working on 05BA001
# 345. Now working on 05BB001
# 346. Now working on 05BG006
# 347. Now working on 05BH013
# 348. Now working on 05BJ004
# 349. Now working on 05BJ010
# 350. Now working on 05BK001
# 351. Now working on 05BL013
# 352. Now working on 05BL014
# 353. Now working on 05BL019
# 354. Now working on 05BL022
# 355. Now working on 05BL023
# 356. Now working on 05BL027
# 357. Now working on 05BM014
# 358. Now working on 05BM018
# 359. Now working on 05CA002
# 360. Now working on 05CA004
# 361. Now working on 05CA009
# 362. Now working on 05CA011
# 363. Now working on 05CA012
# 364. Now working on 05CB001
# 365. Now working on 05CB002
# 366. Now working on 05CB004
# 367. Now working on 05CC001
# 368. Now working on 05CC007
# 369. Now working on 05CC008
# 370. Now working on 05CC009
# 371. Now working on 05CC010
# 372. Now working on 05CC011
# 373. Now working on 05CD006
# 374. Now working on 05CD007
# 375. Now working on 05CE002
# 376. Now working on 05CE006
# 377. Now working on 05CE010
# 378. Now working on 05CE011
# 379. Now working on 05CE018
# 380. Now working on 05CE020
# 381. Now working on 05CG004
# 382. Now working on 05CG006
# 383. Now working on 05CK001
# 384. Now working on 05CK005
# 385. Now working on 05DA007
# 386. Now working on 05DA009
# 387. Now working on 05DA010
# 388. Now working on 05DB002
# 389. Now working on 05DB005
# 390. Now working on 05DB006
# 391. Now working on 05DC006
# 392. Now working on 05DC011
# 393. Now working on 05DC012
# 394. Now working on 05DD004
# 395. Now working on 05DD007
# 396. Now working on 05DD009
# 397. Now working on 05DE007
# 398. Now working on 05DF003
# 399. Now working on 05DF004
# 400. Now working on 05DF006
# 401. Now working on 05DF007
# 402. Now working on 05EA001
# 403. Now working on 05EA002
# 404. Now working on 05EA005
# 405. Now working on 05EA010
# 406. Now working on 05EB902
# 407. Now working on 05EC002
# 408. Now working on 05EC005
# 409. Now working on 05ED002
# 410. Now working on 05EE005
# 411. Now working on 05EE006
# 412. Now working on 05EE009
# 413. Now working on 05EF004
# 414. Now working on 05EF005
# 415. Now working on 05EF006
# 416. Now working on 05EG004
# 417. Now working on 05FA001
# 418. Now working on 05FA012
# 419. Now working on 05FA014
# 420. Now working on 05FA024
# 421. Now working on 05FB002
# 422. Now working on 05FC002
# 423. Now working on 05FC004
# 424. Now working on 05FC007
# 425. Now working on 05FE002
# 426. Now working on 05FF003
# 427. Now working on 05GA008
# 428. Now working on 05GA010
# 429. Now working on 05GA012
# 430. Now working on 05GB004
# 431. Now working on 05GC007
# 432. Now working on 05GD002
# 433. Now working on 05GF001
# 434. Now working on 05GF002
# 435. Now working on 05GG010
# 436. Now working on 05HA015
# 437. Now working on 05HD036
# 438. Now working on 05HE001
# 439. Now working on 05HG021
# 440. Now working on 05HH002
# 441. Now working on 05HH003
# 442. Now working on 05JA003
# 443. Now working on 05JB004
# 444. Now working on 05JB007
# 445. Now working on 05JC004
# 446. Now working on 05JC007
# 447. Now working on 05JF011
# 448. Now working on 05JF014
# 449. Now working on 05JG001
# 450. Now working on 05JG013
# 451. Now working on 05JH005
# 452. Now working on 05JJ009
# 453. Now working on 05JK008
# 454. Now working on 05JM010
# 455. Now working on 05KB003
# 456. Now working on 05KB006
# 457. Now working on 05KB011
# 458. Now working on 05KC001
# 459. Now working on 05KE005
# 460. Now working on 05KE007
# 461. Now working on 05KE010
# 462. Now working on 05KF001
# 463. Now working on 05KG007
# 464. Now working on 05KH007
# 465. Now working on 05KJ014
# 466. Now working on 05LA003
# 467. Now working on 05LB004
# 468. Now working on 05LB006
# 469. Now working on 05LB008
# 470. Now working on 05LB010
# 471. Now working on 05LC001
# 472. Now working on 05LD001
# 473. Now working on 05LD003
# 474. Now working on 05LE004
# 475. Now working on 05LE005
# 476. Now working on 05LE006
# 477. Now working on 05LE008
# 478. Now working on 05LE010
# 479. Now working on 05LE011
# 480. Now working on 05LG004
# 481. Now working on 05LH005
# 482. Now working on 05LJ005
# 483. Now working on 05LJ007
# 484. Now working on 05LJ027
# 485. Now working on 05LJ045
# 486. Now working on 05LL014
# 487. Now working on 05LL015
# 488. Now working on 05LL027
# 489. Now working on 05MA020
# 490. Now working on 05MA021
# 491. Now working on 05MA025
# 492. Now working on 05MC001
# 493. Now working on 05MC002
# 494. Now working on 05MC003
# 495. Now working on 05MD005
# 496. Now working on 05MD010
# 497. Now working on 05ME003
# 498. Now working on 05ME005
# 499. Now working on 05ME007
# 500. Now working on 05MF001
# 501. Now working on 05MF008
# 502. Now working on 05MG001
# 503. Now working on 05MG003
# 504. Now working on 05MH006
# 505. Now working on 05MH007
# 506. Now working on 05MH008
# 507. Now working on 05NB033
# 508. Now working on 05NB035
# 509. Now working on 05ND011
# 510. Now working on 05NE003
# 511. Now working on 05NF002
# 512. Now working on 05NF006
# 513. Now working on 05NF008
# 514. Now working on 05NF010
# 515. Now working on 05NG010
# 516. Now working on 05NG012
# 517. Now working on 05NG020
# 518. Now working on 05OA007
# 519. Now working on 05OB010
# 520. Now working on 05OB016
# 521. Now working on 05OB021
# 522. Now working on 05OC016
# 523. Now working on 05OC019
# 524. Now working on 05OC022
# 525. Now working on 05OE004
# 526. Now working on 05OE006
# 527. Now working on 05OE007
# 528. Now working on 05OE009
# 529. Now working on 05OE010
# 530. Now working on 05OF009
# 531. Now working on 05OF011
# 532. Now working on 05OF014
# 533. Now working on 05OF017
# 534. Now working on 05OF018
# 535. Now working on 05OF020
# 536. Now working on 05OH007
# 537. Now working on 05OJ008
# 538. Now working on 05OJ016
# 539. Now working on 05OJ017
# 540. Now working on 05PB014
# 541. Now working on 05PB018
# 542. Now working on 05PH003
# 543. Now working on 05QA004
# 544. Now working on 05QE008
# 545. Now working on 05QE009
# 546. Now working on 05QE012
# 547. Now working on 05RA001
# 548. Now working on 05RB003
# 549. Now working on 05RC001
# 551. Now working on 05SA002
# 552. Now working on 05SC002
# 553. Now working on 05SD003
# 554. Now working on 05TD001
# 555. Now working on 05TE002
# 556. Now working on 05TF002
# 557. Now working on 05TG002
# 558. Now working on 05TG003
# 559. Now working on 05TG006
# 560. Now working on 05UA003
# 561. Now working on 05UF004
# 562. Now working on 05UG001
# 563. Now working on 05UH001
# 564. Now working on 05UH002
# 565. Now working on 06AA001
# 566. Now working on 06AB001
# 567. Now working on 06AB002
# 568. Now working on 06AD001
# 569. Now working on 06AD006
# 570. Now working on 06AD008
# 571. Now working on 06AD010
# 572. Now working on 06AD011
# 573. Now working on 06AF001
# 574. Now working on 06AG001
# 575. Now working on 06AG002
# 576. Now working on 06BA002
# 577. Now working on 06BB003
# 578. Now working on 06BB005
# 579. Now working on 06BD001
# 580. Now working on 06CD002
# 582. Now working on 06DA002
# 583. Now working on 06DA004
# 584. Now working on 06DA005
# 585. Now working on 06DC001
# 586. Now working on 06FA001
# 587. Now working on 06FB002
# 588. Now working on 06FC001
# 589. Now working on 06FD002
# 590. Now working on 06GD001
# 591. Now working on 06HB002
# 592. Now working on 06JB001
# 593. Now working on 06JC002
# 594. Now working on 06KC003
# 595. Now working on 06LA001
# 596. Now working on 06LC001
# 597. Now working on 06MA006
# 598. Now working on 07AA001
# 599. Now working on 07AA002
# 600. Now working on 07AA007
# 601. Now working on 07AC001
# 602. Now working on 07AC007
# 603. Now working on 07AC008
# 604. Now working on 07AD002
# 605. Now working on 07AF002
# 606. Now working on 07AF003
# 607. Now working on 07AF010
# 608. Now working on 07AF013
# 609. Now working on 07AF014
# 610. Now working on 07AF015
# 611. Now working on 07AG003
# 612. Now working on 07AG004
# 613. Now working on 07AG007
# 614. Now working on 07AG008
# 615. Now working on 07AH001
# 616. Now working on 07AH002
# 617. Now working on 07AH003
# 618. Now working on 07BA002
# 619. Now working on 07BB002
# 620. Now working on 07BB005
# 621. Now working on 07BB011
# 622. Now working on 07BB014
# 623. Now working on 07BC006
# 624. Now working on 07BC007
# 625. Now working on 07BE003
# 626. Now working on 07BE004
# 627. Now working on 07BF001
# 628. Now working on 07BF002
# 629. Now working on 07BF009
# 630. Now working on 07BG004
# 631. Now working on 07BJ001
# 632. Now working on 07BJ003
# 634. Now working on 07BK001
# 635. Now working on 07BK005
# 636. Now working on 07BK007
# 637. Now working on 07BK009
# 638. Now working on 07CA003
# 639. Now working on 07CA005
# 640. Now working on 07CA006
# 641. Now working on 07CA008
# 642. Now working on 07CA012
# 643. Now working on 07CA013
# 644. Now working on 07CB002
# 645. Now working on 07CD001
# 646. Now working on 07CD004
# 647. Now working on 07CD005
# 648. Now working on 07CE002
# 649. Now working on 07CE003
# 650. Now working on 07DA006
# 651. Now working on 07DA008
# 652. Now working on 07DA018
# 653. Now working on 07DB001
# 654. Now working on 07DC001
# 655. Now working on 07DD002
# 656. Now working on 07EA004
# 657. Now working on 07EA005
# 658. Now working on 07EA007
# 659. Now working on 07EB002
# 660. Now working on 07EC002
# 661. Now working on 07EC003
# 662. Now working on 07EC004
# 663. Now working on 07ED003
# 664. Now working on 07EE007
# 665. Now working on 07EE009
# 666. Now working on 07EE010
# 667. Now working on 07FA003
# 668. Now working on 07FA005
# 669. Now working on 07FA006
# 670. Now working on 07FB001
# 671. Now working on 07FB002
# 672. Now working on 07FB003
# 673. Now working on 07FB004
# 674. Now working on 07FB006
# 675. Now working on 07FB008
# 676. Now working on 07FB009
# 677. Now working on 07FC001
# 678. Now working on 07FC003
# 679. Now working on 07FD001
# 680. Now working on 07FD006
# 681. Now working on 07FD007
# 682. Now working on 07FD009
# 683. Now working on 07FD011
# 684. Now working on 07FD012
# 685. Now working on 07FD013
# 686. Now working on 07GA001
# 687. Now working on 07GA002
# 688. Now working on 07GB003
# 689. Now working on 07GC002
# 690. Now working on 07GD001
# 691. Now working on 07GD004
# 692. Now working on 07GE001
# 693. Now working on 07GE003
# 694. Now working on 07GE007
# 695. Now working on 07GF001
# 696. Now working on 07GG001
# 697. Now working on 07GG002
# 698. Now working on 07GG003
# 699. Now working on 07GH002
# 700. Now working on 07GH004
# 701. Now working on 07GJ001
# 702. Now working on 07HA003
# 703. Now working on 07HA005
# 704. Now working on 07HB001
# 705. Now working on 07HC001
# 706. Now working on 07HC002
# 707. Now working on 07HF002
# 708. Now working on 07JA003
# 709. Now working on 07JC001
# 710. Now working on 07JC002
# 711. Now working on 07JD002
# 712. Now working on 07JD003
# 713. Now working on 07JF002
# 714. Now working on 07JF003
# 715. Now working on 07KE001
# 716. Now working on 07LB002
# 717. Now working on 07LE002
# 718. Now working on 07MA003
# 719. Now working on 07MB001
# 720. Now working on 07OA001
# 721. Now working on 07OB001
# 722. Now working on 07OB003
# 723. Now working on 07OB004
# 724. Now working on 07OB006
# 725. Now working on 07OC001
# 727. Now working on 07RD001
# 728. Now working on 07SA002
# 729. Now working on 07SA004
# 730. Now working on 07SB010
# 731. Now working on 07SB013
# 733. Now working on 07SC002
# 734. Now working on 07TA001
# 736. Now working on 08AA008
# 737. Now working on 08AA009
# 738. Now working on 08AC001
# 739. Now working on 08AC002
# 740. Now working on 08BB005
# 741. Now working on 08CD001
# 742. Now working on 08CE001
# 743. Now working on 08CF003
# 744. Now working on 08CG001
# 745. Now working on 08DA005
# 746. Now working on 08DB001
# 747. Now working on 08DB013
# 748. Now working on 08DB014
# 749. Now working on 08EB004
# 750. Now working on 08EB005
# 751. Now working on 08ED001
# 752. Now working on 08ED002
# 753. Now working on 08EE003
# 754. Now working on 08EE004
# 755. Now working on 08EE008
# 756. Now working on 08EE012
# 757. Now working on 08EE013
# 758. Now working on 08EE020
# 759. Now working on 08EE025
# 760. Now working on 08EF001
# 761. Now working on 08EF005
# 762. Now working on 08EG012
# 763. Now working on 08FA002
# 764. Now working on 08FB004
# 765. Now working on 08FB006
# 766. Now working on 08FC003
# 767. Now working on 08FE003
# 768. Now working on 08FF001
# 769. Now working on 08FF002
# 770. Now working on 08FF003
# 771. Now working on 08FF006
# 772. Now working on 08GA071
# 773. Now working on 08GA072
# 774. Now working on 08GA075
# 775. Now working on 08GA077
# 776. Now working on 08GA079
# 777. Now working on 08GB013
# 778. Now working on 08GD004
# 779. Now working on 08GD008
# 780. Now working on 08GE002
# 781. Now working on 08HA001
# 782. Now working on 08HA003
# 783. Now working on 08HA010
# 784. Now working on 08HA016
# 785. Now working on 08HA068
# 786. Now working on 08HB014
# 787. Now working on 08HB025
# 788. Now working on 08HB048
# 789. Now working on 08HB074
# 790. Now working on 08HB075
# 791. Now working on 08HB086
# 792. Now working on 08HD011
# 793. Now working on 08HD015
# 794. Now working on 08HF004
# 795. Now working on 08HF005
# 796. Now working on 08HF006
# 797. Now working on 08JA015
# 798. Now working on 08JB002
# 799. Now working on 08JB003
# 800. Now working on 08JD006
# 801. Now working on 08JE001
# 802. Now working on 08JE004
# 803. Now working on 08KA001
# 804. Now working on 08KA004
# 805. Now working on 08KA005
# 806. Now working on 08KA007
# 807. Now working on 08KA009
# 808. Now working on 08KB001
# 809. Now working on 08KB003
# 810. Now working on 08KB006
# 811. Now working on 08KC001
# 812. Now working on 08KD007
# 813. Now working on 08KE016
# 814. Now working on 08KE024
# 815. Now working on 08KG001
# 816. Now working on 08KH001
# 817. Now working on 08KH006
# 818. Now working on 08KH010
# 820. Now working on 08KH019
# 821. Now working on 08LA001
# 822. Now working on 08LB020
# 823. Now working on 08LB024
# 824. Now working on 08LB038
# 825. Now working on 08LB064
# 826. Now working on 08LB069
# 827. Now working on 08LB076
# 828. Now working on 08LC040
# 829. Now working on 08LD001
# 831. Now working on 08LE024
# 832. Now working on 08LE027
# 833. Now working on 08LE031
# 834. Now working on 08LE077
# 835. Now working on 08LE108
# 837. Now working on 08LF094
# 838. Now working on 08LG008
# 839. Now working on 08LG016
# 840. Now working on 08LG048
# 841. Now working on 08LG056
# 842. Now working on 08MA001
# 843. Now working on 08MA002
# 844. Now working on 08MA003
# 845. Now working on 08MA006
# 846. Now working on 08MB005
# 847. Now working on 08MB006
# 848. Now working on 08MB007
# 849. Now working on 08ME023
# 850. Now working on 08ME025
# 851. Now working on 08ME027
# 852. Now working on 08ME028
# 853. Now working on 08MF062
# 854. Now working on 08MF065
# 855. Now working on 08MF068
# 856. Now working on 08MG001
# 857. Now working on 08MG005
# 858. Now working on 08MG013
# 861. Now working on 08MH001
# 862. Now working on 08MH006
# 863. Now working on 08MH016
# 864. Now working on 08MH029
# 865. Now working on 08MH056
# 866. Now working on 08MH076
# 867. Now working on 08MH103
# 868. Now working on 08MH141
# 869. Now working on 08MH147
# 870. Now working on 08NA002
# 871. Now working on 08NA006
# 872. Now working on 08NB005
# 873. Now working on 08NB012
# 874. Now working on 08NB014
# 875. Now working on 08NB016
# 876. Now working on 08NB019
# 877. Now working on 08NC004
# 878. Now working on 08ND012
# 879. Now working on 08ND013
# 880. Now working on 08NE006
# 881. Now working on 08NE008
# 882. Now working on 08NE039
# 883. Now working on 08NE074
# 884. Now working on 08NE077
# 885. Now working on 08NE087
# 886. Now working on 08NE110
# 887. Now working on 08NE114
# 888. Now working on 08NF001
# 889. Now working on 08NG065
# 890. Now working on 08NG076
# 891. Now working on 08NG077
# 892. Now working on 08NH005
# 893. Now working on 08NH006
# 894. Now working on 08NH007
# 895. Now working on 08NH016
# 896. Now working on 08NH032
# 897. Now working on 08NH084
# 898. Now working on 08NH115
# 899. Now working on 08NH119
# 900. Now working on 08NH120
# 901. Now working on 08NH130
# 902. Now working on 08NH132
# 903. Now working on 08NJ013
# 904. Now working on 08NJ026
# 905. Now working on 08NJ061
# 906. Now working on 08NJ130
# 907. Now working on 08NJ160
# 908. Now working on 08NK026
# 909. Now working on 08NL004
# 910. Now working on 08NL007
# 911. Now working on 08NL024
# 912. Now working on 08NL038
# 913. Now working on 08NL050
# 914. Now working on 08NL069
# 915. Now working on 08NL070
# 916. Now working on 08NL071
# 917. Now working on 08NM134
# 918. Now working on 08NM142
# 919. Now working on 08NM171
# 920. Now working on 08NM173
# 921. Now working on 08NM174
# 922. Now working on 08NM240
# 923. Now working on 08NM241
# 924. Now working on 08NM242
# 925. Now working on 08NN002
# 926. Now working on 08NN012
# 927. Now working on 08NN013
# 928. Now working on 08NN015
# 929. Now working on 08NN019
# 930. Now working on 08NN023
# 931. Now working on 08NP001
# 932. Now working on 08NP004
# 933. Now working on 08OA002
# 934. Now working on 08OA003
# 935. Now working on 08OA004
# 936. Now working on 08OA005
# 937. Now working on 08OB002
# 939. Now working on 09AA012
# 940. Now working on 09AA013
# 941. Now working on 09AC001
# 942. Now working on 09AC007
# 944. Now working on 09AE003
# 945. Now working on 09AE006
# 946. Now working on 09AG001
# 947. Now working on 09AH003
# 948. Now working on 09AH004
# 949. Now working on 09BA001
# 950. Now working on 09BB001
# 951. Now working on 09BC001
# 952. Now working on 09BC004
# 953. Now working on 09CA004
# 954. Now working on 09CA006
# 955. Now working on 09CB001
# 956. Now working on 09CD001
# 957. Now working on 09DB001
# 958. Now working on 09DD003
# 959. Now working on 09DD004
# 960. Now working on 09EA003
# 961. Now working on 09EA004
# 962. Now working on 09EB003
# 963. Now working on 09ED001
# 964. Now working on 09FB002
# 965. Now working on 09FC001
# 966. Now working on 09FD002
# 967. Now working on 10AA001
# 968. Now working on 10AA004
# 969. Now working on 10AA005
# 970. Now working on 10AB001
# 971. Now working on 10AC005
# 972. Now working on 10BE001
# 973. Now working on 10BE004
# 974. Now working on 10BE007
# 975. Now working on 10BE009
# 976. Now working on 10BE013
# 977. Now working on 10CA001
# 978. Now working on 10CB001
# 979. Now working on 10CD001
# 980. Now working on 10CD003
# 981. Now working on 10CD004
# 982. Now working on 10CD005
# 983. Now working on 10EA003
# 984. Now working on 10EB001
# 985. Now working on 10ED001
# 986. Now working on 10ED002
# 987. Now working on 10ED003
# 988. Now working on 10ED007
# 989. Now working on 10ED009
# 990. Now working on 10FA002
# 991. Now working on 10FB005
# 992. Now working on 10GA001
# 993. Now working on 10GB006
# 994. Now working on 10GC003
# 995. Now working on 10JA002
# 996. Now working on 10JC003
# 997. Now working on 10KA007
# 998. Now working on 10KB001
# 999. Now working on 10LA002
# 1000. Now working on 10LC003
# 1001. Now working on 10LC007
# 1002. Now working on 10MA001
# 1003. Now working on 10MA002
# 1004. Now working on 10MA003
# 1005. Now working on 10MC002
# 1006. Now working on 10NC001
# 1007. Now working on 10ND002
# 1008. Now working on 10PB001
# 1009. Now working on 10PC004
# 1010. Now working on 10PC005
# 1011. Now working on 10QA001
# 1012. Now working on 10QC001
# 1013. Now working on 10QD001
# 1014. Now working on 10RA001
# 1015. Now working on 10RA002
# 1016. Now working on 10RC001
# 1017. Now working on 10TF001
# 1018. Now working on 10UH001
# 1019. Now working on 11AA026
# 1020. Now working on 11AA032
# 1021. Now working on 11AB075
# 1022. Now working on 11AB117
# 1023. Now working on 11AC025
# 1024. Now working on 11AE008
# 1025. Now working on 11AE009
# 1026. Now working on 11AE014
# 1027. Now working on 01013500
# 1028. Now working on 01022500
# 1029. Now working on 01030500
# 1030. Now working on 01031500
# 1031. Now working on 01047000
# 1032. Now working on 01052500
# 1033. Now working on 01054200
# 1034. Now working on 01055000
# 1035. Now working on 01057000
# 1036. Now working on 01073000
# 1037. Now working on 01078000
# 1038. Now working on 01118300
# 1039. Now working on 01121000
# 1040. Now working on 01123000
# 1041. Now working on 01134500
# 1042. Now working on 01137500
# 1043. Now working on 01139000
# 1044. Now working on 01139800
# 1045. Now working on 01142500
# 1046. Now working on 01144000
# 1047. Now working on 01162500
# 1048. Now working on 01169000
# 1049. Now working on 01170100
# 1050. Now working on 01181000
# 1051. Now working on 01187300
# 1052. Now working on 01195100
# 1053. Now working on 01333000
# 1054. Now working on 01350000
# 1055. Now working on 01350080
# 1056. Now working on 01350140
# 1057. Now working on 01365000
# 1058. Now working on 01411300
# 1059. Now working on 01413500
# 1060. Now working on 01414500
# 1061. Now working on 01415000
# 1062. Now working on 01423000
# 1063. Now working on 01434025
# 1064. Now working on 01435000
# 1065. Now working on 01439500
# 1066. Now working on 01440000
# 1067. Now working on 01440400
# 1068. Now working on 01451800
# 1069. Now working on 01466500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1070. Now working on 01484100
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1071. Now working on 01485500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1072. Now working on 01486000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1073. Now working on 01487000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1074. Now working on 01491000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1075. Now working on 01510000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1076. Now working on 01516500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1077. Now working on 01518862
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1078. Now working on 01532000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1079. Now working on 01539000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1080. Now working on 01542810
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1081. Now working on 01543000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1082. Now working on 01543500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1083. Now working on 01544500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1084. Now working on 01545600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1085. Now working on 01547700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1086. Now working on 01548500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1087. Now working on 01549500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1088. Now working on 01550000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1089. Now working on 01552000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1090. Now working on 01552500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1091. Now working on 01557500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1092. Now working on 01567500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1093. Now working on 01568000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1094. Now working on 01580000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1095. Now working on 01583500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1096. Now working on 01586610
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1097. Now working on 01591400
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1098. Now working on 01594950
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1099. Now working on 01596500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1100. Now working on 01605500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1101. Now working on 01606500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1102. Now working on 01613050
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1103. Now working on 01620500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1104. Now working on 01632000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1105. Now working on 01632900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1106. Now working on 01634500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1107. Now working on 01638480
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1108. Now working on 01639500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1109. Now working on 01644000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1110. Now working on 01658500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1111. Now working on 01664000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1112. Now working on 01666500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1113. Now working on 01667500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1114. Now working on 01669000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1115. Now working on 01669520
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1116. Now working on 02011400
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1117. Now working on 02011460
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1118. Now working on 02013000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1119. Now working on 02014000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1120. Now working on 02015700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1121. Now working on 02016000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1122. Now working on 02017500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1123. Now working on 02018000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1124. Now working on 02027000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1125. Now working on 02027500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1126. Now working on 02028500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1127. Now working on 02038850
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1128. Now working on 02046000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1129. Now working on 02051000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1130. Now working on 02051500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1131. Now working on 02053200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1132. Now working on 02053800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1133. Now working on 02055100
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1134. Now working on 02056900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1135. Now working on 02059500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1136. Now working on 02064000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1137. Now working on 02065500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1138. Now working on 02069700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1139. Now working on 02070000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1140. Now working on 02074500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1141. Now working on 02077200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1142. Now working on 02081500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1143. Now working on 02082950
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1144. Now working on 02092500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1145. Now working on 02096846
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1146. Now working on 02102908
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1147. Now working on 02108000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1148. Now working on 02111180
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1149. Now working on 02111500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1150. Now working on 02112120
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1151. Now working on 02112360
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1152. Now working on 02118500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1153. Now working on 02125000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1154. Now working on 02128000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1155. Now working on 02137727
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1156. Now working on 02140991
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1157. Now working on 02143000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1158. Now working on 02143040
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1159. Now working on 02149000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1160. Now working on 02152100
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1161. Now working on 02177000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1162. Now working on 02178400
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1163. Now working on 02193340
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1164. Now working on 02196000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1165. Now working on 02198100
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1166. Now working on 02202600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1167. Now working on 02212600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1168. Now working on 02215100
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1169. Now working on 02216180
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1170. Now working on 02221525
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1171. Now working on 02231000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1172. Now working on 02231342
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1173. Now working on 02235200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1174. Now working on 02245500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1175. Now working on 02246000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1176. Now working on 02296500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1177. Now working on 02297155
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1178. Now working on 02297310
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1179. Now working on 02298123
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1180. Now working on 02298608
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1181. Now working on 02299950
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1182. Now working on 02300700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1183. Now working on 02310947
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1184. Now working on 02312200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1185. Now working on 02314500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1186. Now working on 02315500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1187. Now working on 02324400
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1188. Now working on 02327100
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1189. Now working on 02342933
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1190. Now working on 02349900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1191. Now working on 02350900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1192. Now working on 02361000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1193. Now working on 02363000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1194. Now working on 02369800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1195. Now working on 02371500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1196. Now working on 02372250
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1197. Now working on 02374500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1198. Now working on 02381600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1199. Now working on 02384540
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1200. Now working on 02395120
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1201. Now working on 02408540
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1202. Now working on 02415000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1203. Now working on 02422500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1204. Now working on 02427250
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1205. Now working on 02430085
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1206. Now working on 02430615
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1207. Now working on 02450250
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1208. Now working on 02464000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1209. Now working on 02464146
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1210. Now working on 02464360
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1211. Now working on 02465493
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1212. Now working on 02469800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1213. Now working on 02472000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1214. Now working on 02472500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1215. Now working on 02479155
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1216. Now working on 02479300
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1217. Now working on 02479560
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1218. Now working on 02481000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1219. Now working on 02481510
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1220. Now working on 03010655
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1221. Now working on 03011800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1222. Now working on 03015500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1223. Now working on 03021350
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1224. Now working on 03026500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1225. Now working on 03028000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1226. Now working on 03049000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1227. Now working on 03049800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1228. Now working on 03050000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1229. Now working on 03066000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1230. Now working on 03069500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1231. Now working on 03070500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1232. Now working on 03076600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1233. Now working on 03078000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1234. Now working on 03140000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1235. Now working on 03144000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1236. Now working on 03159540
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1237. Now working on 03161000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1238. Now working on 03164000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1239. Now working on 03165000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1240. Now working on 03170000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1241. Now working on 03173000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1242. Now working on 03180500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1243. Now working on 03182500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1244. Now working on 03186500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1245. Now working on 03187500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1246. Now working on 03213700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1247. Now working on 03237280
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1248. Now working on 03237500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1249. Now working on 03238500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1250. Now working on 03241500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1251. Now working on 03280700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1252. Now working on 03281100
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1253. Now working on 03281500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1254. Now working on 03285000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1255. Now working on 03291780
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1256. Now working on 03300400
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1257. Now working on 03338780
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1258. Now working on 03340800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1259. Now working on 03346000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1260. Now working on 03357350
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1261. Now working on 03364500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1262. Now working on 03366500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1263. Now working on 03368000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1264. Now working on 03384450
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1265. Now working on 03439000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1266. Now working on 03450000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1267. Now working on 03455500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1268. Now working on 03456500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1269. Now working on 03460000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1270. Now working on 03463300
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1271. Now working on 03471500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1272. Now working on 03473000
# ...
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1521. Now working on 09081600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1522. Now working on 09107000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1523. Now working on 09210500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1524. Now working on 09223000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1525. Now working on 09306242
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1526. Now working on 09312600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1527. Now working on 09352900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1528. Now working on 09378170
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1529. Now working on 09378630
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1530. Now working on 09386900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1531. Now working on 09404450
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1532. Now working on 09430500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1533. Now working on 09430600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1534. Now working on 09447800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1535. Now working on 09480000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1536. Now working on 09484000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1537. Now working on 09484600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1538. Now working on 09492400
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1539. Now working on 09494000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1540. Now working on 09497800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1541. Now working on 09497980
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1542. Now working on 09505200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1543. Now working on 09505350
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1544. Now working on 09505800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1545. Now working on 09508300
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1546. Now working on 09510200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1547. Now working on 09512280
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1548. Now working on 09513780
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1549. Now working on 10023000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1550. Now working on 10166430
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1551. Now working on 10172700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1552. Now working on 10172800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1553. Now working on 10173450
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1554. Now working on 10205030
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1555. Now working on 10234500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1556. Now working on 10242000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1557. Now working on 10244950
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1558. Now working on 10249300
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1559. Now working on 10258000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1560. Now working on 10258500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1561. Now working on 10259000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1562. Now working on 10259200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1563. Now working on 10263500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1564. Now working on 10310500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1565. Now working on 10316500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1566. Now working on 10329500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1567. Now working on 10336645
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1568. Now working on 10336660
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1569. Now working on 10336740
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1570. Now working on 10343500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1571. Now working on 10348850
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1572. Now working on 10396000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1573. Now working on 11098000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1574. Now working on 11124500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1575. Now working on 11141280
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1576. Now working on 11143000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1577. Now working on 11148900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1578. Now working on 11151300
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1579. Now working on 11162500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1580. Now working on 11176400
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1581. Now working on 11180500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1582. Now working on 11180960
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1583. Now working on 11224500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1584. Now working on 11230500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1585. Now working on 11237500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1586. Now working on 11253310
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1587. Now working on 11264500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1588. Now working on 11266500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1589. Now working on 11274500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1590. Now working on 11274630
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1591. Now working on 11284400
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1592. Now working on 11299600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1593. Now working on 11381500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1594. Now working on 11383500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1595. Now working on 11451100
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1596. Now working on 11468500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1597. Now working on 11473900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1598. Now working on 11475560
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1599. Now working on 11476600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1600. Now working on 11478500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1601. Now working on 11480390
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1602. Now working on 11481200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1603. Now working on 11482500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1604. Now working on 11522500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1605. Now working on 11523200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1606. Now working on 11528700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1607. Now working on 11532500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1608. Now working on 12010000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1609. Now working on 12013500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1610. Now working on 12020000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1611. Now working on 12025000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1612. Now working on 12025700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1613. Now working on 12035000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1614. Now working on 12040500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1615. Now working on 12041200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1616. Now working on 12043000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1617. Now working on 12048000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1618. Now working on 12054000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1619. Now working on 12056500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1620. Now working on 12073500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1621. Now working on 12082500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1622. Now working on 12092000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1623. Now working on 12095000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1624. Now working on 12114500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1625. Now working on 12115000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1626. Now working on 12115500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1627. Now working on 12117000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1628. Now working on 12141300
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1629. Now working on 12143600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1630. Now working on 12144000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1631. Now working on 12145500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1632. Now working on 12147500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1633. Now working on 12147600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1634. Now working on 12167000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1635. Now working on 12175500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1636. Now working on 12178100
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1637. Now working on 12186000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1638. Now working on 12189500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1639. Now working on 12358500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1640. Now working on 12374250
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1641. Now working on 12375900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1642. Now working on 12377150
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1643. Now working on 12381400
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1644. Now working on 12383500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1645. Now working on 12388400
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1646. Now working on 12390700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1647. Now working on 12411000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1648. Now working on 12414500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1649. Now working on 12447390
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1650. Now working on 12451000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1651. Now working on 12488500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1652. Now working on 13011500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1653. Now working on 13011900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1654. Now working on 13018300
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1655. Now working on 13023000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1656. Now working on 13083000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1657. Now working on 13161500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1658. Now working on 13235000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1659. Now working on 13240000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1660. Now working on 13310700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1661. Now working on 13313000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1662. Now working on 13331500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1663. Now working on 13337000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1664. Now working on 13338500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1665. Now working on 13340000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1666. Now working on 13340600
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1667. Now working on 14020000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1668. Now working on 14092750
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1669. Now working on 14096850
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1670. Now working on 14137000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1671. Now working on 14138800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1672. Now working on 14138870
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1673. Now working on 14138900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1674. Now working on 14139800
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1675. Now working on 14141500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1676. Now working on 14154500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1677. Now working on 14158500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1678. Now working on 14158790
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1679. Now working on 14166500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1680. Now working on 14182500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1681. Now working on 14185000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1682. Now working on 14185900
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1683. Now working on 14187000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1684. Now working on 14216500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1685. Now working on 14222500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1686. Now working on 14236200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1687. Now working on 14301000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1688. Now working on 14303200
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1689. Now working on 14305500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1690. Now working on 14306340
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1691. Now working on 14306500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1692. Now working on 14308990
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1693. Now working on 14309500
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1694. Now working on 14316700
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1695. Now working on 14325000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1696. Now working on 14362250
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1
# 1697. Now working on 14400000
# Warning: converting data from units feet^3 s^-1 to m^3 s^-1

# %% [markdown]
# ## Run only once - find out which streamflow codes we have in the daily data files

# %% [markdown]
# ### USA

# %%
def remove_strings_starting_with_number(arr):
    return [string for string in arr if (type(string) == str) and (not re.match(r'^\d', str(string)))]

# %%
usa_streamflow_codes = []
for ix, row in cs_meta.iterrows():
     if row.Country == 'USA':
        site, _, _, csv_path, _, nc_path = cs.prepare_flow_download_outputs(cs_meta, ix, basins_path, time='daily')
        csv = pd.read_csv(csv_path, index_col=0, parse_dates=True, dtype='object')
        values = csv['obs_00060_00003'].unique()
        values = remove_strings_starting_with_number(values)
        usa_streamflow_codes.append(values)

# %%
np.unique(np.concatenate(usa_streamflow_codes))
# Out:
# array(['***', '-0.00', '-0.03', '-0.42', 'Bkw', 'Dis', 'Eqp', 'Ice',
#        'Rat'], dtype='<U32')

# %% [markdown]
#  - `***`: value unavailale - no need to do anything, will be nan later
#  - `-x.`: negative values - no need to do anything, will be nan later
#  - `Bkw`: backwater-affected
#  - `Dis`: station discontinued - no need to do anything
#  - `Eqp`: equipment malfunction
#  - `Ice`: ice-affected
#  - `Rat`: rating curve being developed - no need to do anything

# %% [markdown]
# ### CAN

# %% [markdown]
# We have already checked the Canadian streamflow codes in `2c_can_daily_flow_obs_from_hydat.ipynb`. For posterity:

# %%
cs.find_table_contents(db,'DATA_SYMBOLS',to_screen=True);
# Out:
# ('A', 'Partial Day', 'Journée incomplète')
# ('B', 'Ice Conditions', 'Conditions à glace')
# ('D', 'Dry', 'Sec')
# ('E', 'Estimated', 'Estimé')
# ('S', 'Sample(s) collected this day', 'échantillons prélevés ce jour-là')
