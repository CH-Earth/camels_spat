# %%
import xarray as xr
from pathlib import Path

# %%
folder = Path('/Users/wmk934/data/CAMELS_spat/camels-spat-data/basin_data/CAN_01AD003/forcing/')

# %% [markdown]
# ### Check forcing file contents

# %%
era = xr.open_dataset(folder/'raw'/'ERA5_1951-10.nc')
eme = xr.open_dataset(folder/'raw'/'EM_Earth_1951-10.nc')

# %%
eme
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 8, longitude: 6, time: 744)
# Coordinates:
#   * latitude   (latitude) float64 47.85 47.75 47.65 47.55 ... 47.35 47.25 47.15
#   * longitude  (longitude) float64 -69.45 -69.35 -69.25 -69.15 -69.05 -68.95
#   * time       (time) datetime64[ns] 1951-10-01 ... 1951-10-31T23:00:00
# Data variables:
#     tmean      (time, latitude, longitude) float32 ...
#     prcp       (time, latitude, longitude) float32 ...
# Attributes:
#     Reason:                 Merging separate EM-Earth download files
#     Source:                 github.com/cH-Earth/camels_spat
#     Conventions:            CF-1.6
#     History_source_file_1:  Fri Feb 18 04:46:07 2022: ncks -O --mk_rec_dmn ti...
#     History_source_file_2:  Fri Feb 18 04:07:16 2022: ncks -O --mk_rec_dmn ti...
#     History:                Created Wed Sep  6 16:10:16 2023 On Mon Sep 11 21...

# %%
era
# Out:
# <xarray.Dataset>
# Dimensions:        (longitude: 3, latitude: 3, time: 744)
# Coordinates:
#   * longitude      (longitude) float32 -69.5 -69.25 -69.0
#   * latitude       (latitude) float32 47.75 47.5 47.25
#   * time           (time) datetime64[ns] 1951-10-01 ... 1951-10-31T23:00:00
# Data variables: (12/16)
#     msdwlwrf       (time, latitude, longitude) float32 ...
#     msnlwrf        (time, latitude, longitude) float32 ...
#     msdwswrf       (time, latitude, longitude) float32 ...
#     msnswrf        (time, latitude, longitude) float32 ...
#     mtpr           (time, latitude, longitude) float32 ...
#     sp             (time, latitude, longitude) float32 ...
#     ...             ...
#     v              (time, latitude, longitude) float32 ...
#     reflected_sw   (time, latitude, longitude) float32 ...
#     net_radiation  (time, latitude, longitude) float32 ...
#     e              (time, latitude, longitude) float32 ...
# ...
