# %% [markdown]
# # Add hourly Canadian data
# Apparently, since last checking the Water Survey of Canada now provides longer records of sub-daily data for each gauge. We'll try and add these to CAMELS-SPAT.

# %%
from collections import defaultdict
from concurrent.futures import ProcessPoolExecutor
import lzma
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import re
import sys
import xarray as xr

import netCDF4 as nc4
import time
from datetime import timedelta
from datetime import datetime

sys.path.append(str(Path().absolute().parent))
import python_cs_functions as cs

# %%
# Data location
cs_main_folder = Path("/scratch/gwf/gwf_cmt/wknoben/camels-spat-upload")

# %%
# Destination location
cs_update_folder = Path("/scratch/gwf/gwf_cmt/wknoben/camels-spat-upload-updates")

# %%
# Working folder
cs_working_folder = Path("/scratch/gwf/gwf_cmt/wknoben/camels-spat-wip")

# %%
# Specify the folder structure
obs_path_part1 = "observations"
obs_path_parts2 = ["headwater", "macro-scale", "meso-scale"]
obs_path_part3 = "obs-hourly"

# %%
# Load the meta-data, so we known which basins we have
cs_meta = pd.read_csv(cs_main_folder / "camels-spat-metadata.csv")

# %%
# Ensure we have our working dir
cs_working_folder.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# ## Data download
# Data is stored here:
# https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/ in subfolders numbered `01..11`

# %%
# Loop over the subfolders on the webpage and grab the download links
main_url = "https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/"
all_urls = []
for folder_num in range(1,12):
    subfolder = f"{folder_num:02}"
    sub_urls = cs.find_files_in_webpage_folder(f"{main_url}/{subfolder}/", extension='xz')
    all_urls.extend(sub_urls)

# %%
# Download the URLs for stations we actually have in CAMELS-SPAT
downloaded_new_obs = []
for url in all_urls:
    file_name = Path(url).name
    basin = file_name.split("@")[1].split(".")[0] # assumes: Discharge.Working@01AD003.20110101_corrected.csv.xz
    if (cs_meta['Station_id'] == basin).any():
        downloaded_new_obs.append(basin)
        cs.download_url_into_folder(url,cs_working_folder)
# Out:
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AD003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AF007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AF009.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AJ003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AJ004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AJ010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AK001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AK006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AK007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AL002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AL004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AM001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AN002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AP002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AP004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AP006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01AQ001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BC001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BE001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BJ003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BJ007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BJ010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BJ012.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BL002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BL003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BO001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BP001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BP002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BQ001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BS001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BU002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BU009.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BV004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01BV006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01CA003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01CC005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01CD005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01DG003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01DJ005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01DL001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01DP004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01DR001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01EC001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01ED005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01ED007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01EE005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01EF001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01EO001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01FA001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01FB001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01FB003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/01/Discharge.Working@01FJ002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02AB008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02AB014.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02AB017.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02AB021.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02AC001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02AC002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02AD010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02AE001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02BA003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02BA005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02BB003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02BF001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02BF002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02BF004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02CA002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02CB003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02CF007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02CF008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02CF011.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02CG003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02DC012.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02DD012.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02DD013.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02DD015.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02EA005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02EA010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02EB014.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02EC002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02EC010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02EC011.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02EC018.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ED003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ED007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ED013.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ED015.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ED017.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ED024.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ED026.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ED101.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ED102.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FA002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FA004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FB007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FB010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FC011.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FC016.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FC017.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FD002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FE008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FE009.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FE011.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FE013.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FE014.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FF007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02FF008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GA010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GA018.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GA038.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GA041.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GA043.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GC002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GC010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GC018.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GC021.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GC029.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GC030.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GC031.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GD004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GD010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GD019.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GD021.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GE007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GG002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GG003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GG005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GG006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GG009.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02GH002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HA006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HA020.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HB012.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HB022.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HB023.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HC019.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HC023.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HC025.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HC038.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HC047.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HC049.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HD009.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HD012.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HJ001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HK007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HK008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HL003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HL004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HL005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HM004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02HM005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02JC008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02KF016.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02KF017.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02LA007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02LB006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02LB007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02LB008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02LB020.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02LB022.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02MB006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02MC001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02MC026.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02MC028.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02XA003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YA002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YC001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YD002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YE001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YG001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YJ001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YK002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YK005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YK008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YL001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YL004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YL005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YL008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YM003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YM004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YN002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YO006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YO008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YO012.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YQ001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YQ005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YR001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YR003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YS003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YS005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02YS006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZA002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZB001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZC002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZD002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZE004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZF001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZG001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZG003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZG004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZH001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZH002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZJ001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZJ002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZJ003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZK001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZK002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZK004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZL004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZL005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZM006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZM009.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZM016.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/02/Discharge.Working@02ZN002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/03/Discharge.Working@03NF001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/03/Discharge.Working@03QC002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04AA004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04CA003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04DA001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04DB001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04DC002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04EA001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04FA001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04FA003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04GA002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04GB005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04JC002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04JD005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04JF001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04KA001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04LJ001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04MD004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/04/Discharge.Working@04MF001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AA004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AA008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AA011.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AA022.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AA028.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AB005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AB029.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AC030.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AD003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AD035.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AE005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AH037.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AH041.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AH047.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05AH050.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BA001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BB001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BG006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BH013.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BJ004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BJ010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BK001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BL013.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BL014.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BL019.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BL022.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BL023.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BL027.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BM014.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05BM018.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CA002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CA004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CA009.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CA011.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CA012.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CB001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CB002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CB004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CC001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CC007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CC008.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CC009.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CC010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CC011.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CD006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CD007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CE002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CE006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CE010.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CE011.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/05/Discharge.Working@05CE018.20110101_corrected.csv.xz
# ...
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NG076.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NG077.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NH005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NH007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NH016.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NH084.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NH115.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NH119.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NH132.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NJ013.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NJ026.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NJ061.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NJ130.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NJ160.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NL004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NL007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NL024.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NL038.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NL050.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NL069.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NL070.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NL071.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NM134.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NM171.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NM174.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NM240.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NM241.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NM242.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NN002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NN015.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NN019.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08NN023.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08OA002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08OA003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08OA004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08OA005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/08/Discharge.Working@08OB002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09AA012.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09AA013.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09AC001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09AC007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09AE003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09AE006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09AG001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09AG001.20160101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09AH003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09AH004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09BA001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09BB001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09CA004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09CA006.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09CB001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09DB001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09DD004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09EA003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09EA004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09EB003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/09/Discharge.Working@09FB002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10AA004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10AA005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10AC005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10BE004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10BE007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10BE009.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10BE013.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10CA001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10CB001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10CD003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10CD004.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10CD005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10EA003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10ED003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10ED007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10ED009.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10FA002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10FB005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10GA001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10GC003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10KA007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10KB001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10LC003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10LC007.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10MA002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10MA002.20160101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10MA003.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10ND002.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10PC005.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10QA001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10TF001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/10/Discharge.Working@10UH001.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/11/Discharge.Working@11AA026.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/11/Discharge.Working@11AB075.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/11/Discharge.Working@11AB117.20110101_corrected.csv.xz
# Successfully downloaded https://collaboration.cmc.ec.gc.ca/cmc/hydrometrics/www/UnitValueData/Discharge/corrected/11/Discharge.Working@11AC025.20110101_corrected.csv.xz

# %%
# Check for how many stations we downloaded data
num_files = len(list(cs_working_folder.glob("*.xz")))
num_basin = (cs_meta['Country'] == 'CAN').sum()
print(f"Downloaded {num_files} files for an expected {num_basin} basins.")
# Out:
# Downloaded 768 files for an expected 764 basins.

# %%
# Figure out what we have extra
new_files = list(cs_working_folder.glob("*.xz"))

# %%
download_basins = []
for file in new_files:
    download_basins.append(file.name.split("@")[1].split(".")[0])

# %%
# anything snuck in that shouldn't be there?
not_in_meta = [basin for basin in download_basins if basin not in cs_meta['Station_id'].values]
print(not_in_meta)
# Out:
# []

# %%
# any duplicates?
from collections import Counter
duplicates = [basin for basin, count in Counter(download_basins).items() if count > 1]
print(duplicates)
# Out:
# ['09AG001', '07FA003', '05MA025', '10MA002']

# %%
# what's different for these?
for file in sorted(new_files):
    basin = file.name.split("@")[1].split(".")[0]
    if basin in duplicates:
        print(file)
# Out:
# /scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/Discharge.Working@05MA025.20110101_corrected.csv.xz
# /scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/Discharge.Working@05MA025.20120301_corrected.csv.xz
# /scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/Discharge.Working@07FA003.20110101_corrected.csv.xz
# /scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/Discharge.Working@07FA003.20121002_corrected.csv.xz
# /scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/Discharge.Working@09AG001.20110101_corrected.csv.xz
# /scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/Discharge.Working@09AG001.20160101_corrected.csv.xz
# /scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/Discharge.Working@10MA002.20110101_corrected.csv.xz
# /scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/Discharge.Working@10MA002.20160101_corrected.csv.xz

# %%
# different dates, apparently. Why?
# 10MA002 just has reduced data coverage (starts at 2016) - the 2016 file has more recent data
# 09AG001 - 2016 file also has more recent data
# 07FA003 - 2012 file has more recent data
# 05MA025 - 2012 file has more recent data

# we'll manually remove the older ones

# %% [markdown]
# ## Find current Qobs
# We need to already look in the `updated` folder, because in the previous step we updated all Qobs files with the more recent ones I had on my laptop that have all times in LST (apart from hourly observations for basin `02ZH002` - but we still have an hourly file for this one in the update location, we just can't run the same comparison for this one as for others).

# %%
scales = []
basins = []
files = []
paths = []
for obs_path_part2 in obs_path_parts2:
    search_this = cs_update_folder / obs_path_part1 / obs_path_part2 / obs_path_part3
    old_paths = list(search_this.glob('*.nc'))
    for old_path in old_paths:
        old_file = old_path.name
        scales.append(obs_path_part2)
        basins.append(f"{old_file.split('_')[0]}_{old_file.split('_')[1]}")
        files.append(old_file)
        paths.append(old_path)
old_nc_lookup = pd.DataFrame(data={'basin': basins,
                                   'scale': scales,
                                   'filename': files,
                                   'path': paths})

# %%
old_nc_lookup.head(1)
# Out:
#           basin      scale                                  filename  \
# 0  USA_02143040  headwater  USA_02143040_hourly_flow_observations.nc
#
#                                                 path
# 0  /scratch/gwf/gwf_cmt/wknoben/camels-spat-uploa...

# %% [markdown]
# ## Process into new Qobs
# We already have processing code for this, that ultimately results in a netcdf. Here we:
# - Convert the new downloads into the same format that our existing code expects;
#   - Already remove initial or final parts of the data where we don't have at least 1 observation per hour
# - Re-run that code;
# - Compare the old netcdf with the new one, to confirm our overlapping dates haven't changed.

# %%
num_basin = (cs_meta['Country'] == 'CAN').sum()
new_files = list(cs_working_folder.glob("*.xz"))
print(f"Have {len(new_files)} files for an expected {num_basin} basins.")
# Out:
# Have 764 files for an expected 764 basins.

# %%
# CRITICAL for parallel processing: sort the files
new_files = sorted(new_files)

# %% [markdown]
# ### Example of current netcdf

# %%
example_path = cs_update_folder / "observations" / "headwater" / "obs-hourly"
example_file = "CAN_01AK006_hourly_flow_observations.nc"
ds = xr.open_dataset(example_path / example_file)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                      (time: 9224, nbnds: 2)
# Coordinates:
#   * time                         (time) datetime64[ns] 2021-11-20T16:00:00 .....
#   * nbnds                        (nbnds) int64 1 2
# Data variables:
#     q_obs                        (time) float64 ...
#     q_obs_is_ice_affected        (time) int64 ...
#     q_obs_is_below_sensor_level  (time) int64 ...
#     q_obs_data_quality           (time) object ...
#     time_bnds                    (nbnds, time) datetime64[ns] ...
# Attributes:
#     title:        CAMELS-spat streamflow data
#     conventions:  CF-1.10
#     source:       Streamflow derived from observed water levels
#     country:      CAN
#     station:      01AK006
#     institution:  Water Survey of Canada
#     references:   Original data extracted from the Environment and Climate Ch...
#     history:      2023-12-27 13:21:12 | File prepared using CAMELS-spat scrip...

# %%
ds.close() # still lives in memory but releases file handle

# %% [markdown]
# ### Convert new downloads into hourly netcdfs

# %%
def extract_csv_header_metadata(xz_path, header_out_path):
    header_lines = []
    start_line = None
    pattern = re.compile(r"# CSV data starts at line (\d+)\.?")

    with lzma.open(xz_path, "rt") as f:
        for i, line in enumerate(f, start=1):
            header_lines.append(line)
            match = pattern.search(line)
            if match:
                start_line = int(match.group(1))
                break

    if start_line is None:
        raise ValueError("Could not find marker line: '# CSV data starts at line X'")

    # Write metadata header lines to a new file
    with open(header_out_path, "w") as out_f:
        out_f.writelines(header_lines)

    return start_line

# %%
def extract_metadata_fields_from_txt(header_txt_path):
    patterns = {
        "time_series_identifier": re.compile(r"#\s*Time-series identifier:\s*(.*)"),
        "location": re.compile(r"#\s*Location:\s*(.*)"),
        "utc_offset": re.compile(r"#\s*UTC offset:\s*(.*)"),
        "value_units": re.compile(r"#\s*Value units:\s*(.*)"),
        "value_parameter": re.compile(r"#\s*Value parameter:\s*(.*)"),
    }

    results = {}

    with open(header_txt_path, "r") as f:
        for line in f:
            for key, pattern in patterns.items():
                match = pattern.match(line)
                if match:
                    value = match.group(1).strip()

                    if key == "time_series_identifier" and value.startswith("Discharge.Working@"):
                        value = value.replace("Discharge.Working@", "")
                    elif key == "utc_offset" and value.startswith("(") and value.endswith(")"):
                        value = value[1:-1]

                    results[key] = value

    return results

# %%
def check_header_info(basin,row,header_dict):
    assert header_info['value_parameter'].lower() == 'discharge', f"Header variable not discharge for {basin}"
    assert header_info['value_units'].lower() == 'm^3/s', f"Header units not m^3/s for {basin}"

# %%
def extract_offset(value):
    return value[-6:]

# %%
def compare_netcdf_dataframe_hourly_values(df, nc_path, basin, log=[]):
    
    ds = xr.open_dataset(str(nc_path), engine='netcdf4')

    # ensure matching dtype
    ds['time'] = pd.to_datetime(ds['time'].values)
    df.index = pd.to_datetime(df.index)

    # merge
    xr_series = ds["q_obs"].to_series()
    aligned_df, aligned_xr = df["Value/Valeur"].align(xr_series, join="inner")

    # Check if df contains all time steps from the NetCDF file
    missing_times = ds['time'].values[~np.isin(ds['time'].values, df.index.values)]
    if len(missing_times) > 0:
        msg = f"Basin {basin}: {len(missing_times)} time steps from NetCDF are missing in the DataFrame."
        log_message(log, msg) if log else print(msg)

    # compare data in absolute and relative terms
    diff_abs = np.abs(aligned_df.values - aligned_xr.values)
    diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values 

    abs_mask = diff_abs > 0.1  # difference > 0.1 m3/s
    rel_mask = diff_rel > 0.01  # difference > 1%

    n_abs = abs_mask.sum()
    n_rel = rel_mask.sum()

    if n_abs > 0:
        msg = f"Basin {basin}: {n_abs}/{len(aligned_df.values)} values more than 0.1 m3/s different."
        log_message(log, msg) if log else print(msg)
        
        if n_abs > 750:
            msg = f"    Absolute difference stats for {n_abs} mismatches:"
            log_message(log, msg) if log else print(msg)
            msg = f"    Max abs diff: {diff_abs[abs_mask].max():.4f}"
            log_message(log, msg) if log else print(msg)
            msg = f"    Mean abs diff: {diff_abs[abs_mask].mean():.4f}"
            log_message(log, msg) if log else print(msg)
            msg = f"    95th percentile: {np.percentile(diff_abs[abs_mask], 95):.4f}"
            log_message(log, msg) if log else print(msg)

    if n_rel > 0:
        msg = f"Basin {basin}: {n_rel}/{len(aligned_df.values)} values more than 1% different."
        log_message(log, msg) if log else print(msg)
        if n_rel > 750:
            msg = f"    Relative difference stats for {n_rel} mismatches:"
            log_message(log, msg) if log else print(msg)
            msg = f"    Max rel diff: {diff_rel[rel_mask].max():.4f}"
            log_message(log, msg) if log else print(msg)
            msg = f"    Mean rel diff: {diff_rel[rel_mask].mean():.4f}"
            log_message(log, msg) if log else print(msg)
            msg = f"    95th percentile: {np.percentile(diff_rel[rel_mask], 95):.4f}"
            log_message(log, msg) if log else print(msg)

# %%
def subdaily_flow_csv_to_netcdf(csv, nc_path, country, station, tz, center_window):
    
    '''Converts a standardized csv file with flow observations to xarray data set and saves as netcdf'''
    
    # 1. Define standard values
    # -------------------------
    
    # Auxiliary
    global_att_countries = ['USA', 'CAN', 'MEX']
    global_att_i = global_att_countries.index(country)
    global_att_now = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    
    # Global attributes
    global_att_ttl = 'CAMELS-spat streamflow data'
    global_att_con = 'CF-1.10'
    global_att_src = 'Streamflow derived from observed water levels'
    global_att_ins = ['United States Geological Survey',
                      'Water Survey of Canada']
    global_att_ref = [('U.S. Geological Survey, 2016, National Water Information System data available ' +
                       'on the World Wide Web (USGS Water Data for the Nation), accessed 2023-03-23, at '+
                       'URL [http://waterdata.usgs.gov/nwis/]'),
                      ('Original data extracted from the Environment and Climate Change Canada Real-time ' +
                       'Hydrometric Data web site (https://wateroffice.ec.gc.ca/mainmenu/real_time_data_index_e.html) ' + 
                       'on 2023-04-05')]
    global_att_his = (f'{global_att_now} | File prepared using CAMELS-spat scripts. See:' + 
                       'https://github.com/CH-Earth/camels-spat')
    global_att_com = 'n/a'
    
    # Data variables
    q_obs_unit = 'm3 s-1'
    q_obs_long = 'observed streamflow values'
    q_obs_anc = [column for column in csv.columns if '_is_' in column] # Get names of all ancillary variables in .csv 
    q_obs_anc.append('q_obs_data_quality') # add the 'q_obs_data_quality' variable that's not captured by the above
    q_obs_anc = ' '.join([f"'{anc}'" for anc in q_obs_anc]) # convert full list into single string
    
    # Time settings
    time_unit = 'minutes since 1950-01-01 00:00:00'
    time_cal = 'proleptic_gregorian'
    
    # 2. Create a basic data set to build from
    ds = csv.to_xarray()
    
    # 3. Global attributes
    ds.attrs['title'] = global_att_ttl
    ds.attrs['conventions'] = global_att_con
    ds.attrs['source'] = global_att_src
    ds.attrs['country'] = country
    ds.attrs['station'] = station
    ds.attrs['institution'] = global_att_ins[global_att_i]
    ds.attrs['references'] = global_att_ref[global_att_i]
    ds.attrs['history'] = global_att_his
    #ds.attrs['comment'] = global_att_com

    # 4a. Time attributes (coordinate already exists)
    # NOTE: attributes 'units' and 'calendar' are automatically specified when writing to netcdf
    #       This can be checked by saving to netcdf, and then loading as follows: xr.open_dataset(nc_path, decode_times=False)
    ds.time.attrs['standard_name'] = 'time'
    ds.time.attrs['bounds'] = 'time_bnds'
    ds.time.encoding['units'] = time_unit
    ds.time.encoding['calendar'] = time_cal
        
    # 4b. Time bounds variable
    ds = ds.assign_coords(nbnds=[1,2])
    if center_window:    
        ds = ds.assign(time_bnds=(['nbnds','time'], [csv.index - pd.Timedelta('30min'), csv.index + pd.Timedelta('30min')]))
    else:
        ds = ds.assign(time_bnds=(['nbnds','time'], [csv.index, csv.index + pd.Timedelta('1h')]))
    ds.nbnds.attrs['standard_name'] = 'bounds for timestep intervals'
    ds.time_bnds.attrs['long_name'] = 'start and end points of each time step'
    ds.time_bnds.attrs['time_zone'] = tz
    
    # 5. Observed streamflow
    ds.q_obs.attrs['units'] = q_obs_unit
    ds.q_obs.attrs['long_name'] = q_obs_long
    ds.q_obs.attrs['cell_methods'] = 'time:mean' # indicating that values are average values over the timestep
    ds.q_obs.attrs['ancillary_variables'] = q_obs_anc
    ## TO DO: add other variables to ancillary_variables list
    
    # 6. Data quality flags
    flags = [str(s) for s in csv['q_obs_data_quality'].unique()]
    flags.sort()
    meanings = cs.return_data_quality_flag_meaning(flags,country)
    ds.q_obs_data_quality.attrs['standard_name'] = 'quality_flag'
    ds.q_obs_data_quality.attrs['long_name'] = 'lowest data quality flag listed in the values used to generate an average flow value for each timestep'
    ds.q_obs_data_quality.attrs['flag_values'] = ' '.join([f"'{flag}'" for flag in flags])
    ds.q_obs_data_quality.attrs['flag_meanings'] = ' '.join([f"'{meaning}'" for meaning in meanings])
    
    # 7. Other status variables
    for variable in ds.variables:
        if '_is_' in variable:
            ds[variable].attrs['standard_name'] = 'quality_flag'
            ds[variable].attrs['long_name'] = 'flag indicating if main variable is affected by process in variable name'
            ds[variable].attrs['flag_values'] = "'0' '1'"
            ds[variable].attrs['flag_meanings'] = "'no' 'yes'"
    
    # Save to file
    #ds = ds.drop_indexes(['time','nbnds'])
    ds.to_netcdf(nc_path)
    
    return ds

# %%
def lst_to_tz_name(lst):
    # https://en.wikipedia.org/wiki/List_of_tz_database_time_zones
    tz_map = {
        'CST': 'America/Chicago',
        'PST': 'America/Los_Angeles',
        'MST': 'America/Denver',
        'EST': 'America/New_York',
        'AST': 'America/Halifax',
        'NST': 'America/St_Johns'
    }   
    return tz_map[lst]

# %%
def log_message(log_path, message):
    with open(log_path, "a") as f:
        f.write(message + "\n")

# %%
def merge_logs(log_dir, output_file, pattern="log_*"):
    log_files = sorted(Path(log_dir).glob(pattern))  # Sort for consistent order
    with open(output_file, "w") as outfile:
        for log_file in log_files:
            with open(log_file, "r") as infile:
                outfile.write(infile.read())
                outfile.write("\n")  # Optional: add newline between logs
    print(f"Merged {len(log_files)} files into {output_file}")

# %%
def summarize_log(log_file_path):
    with open(log_file_path, "r") as f:
        lines = f.readlines()

    basins_checked = 0
    last_was_basin_line = False
    no_warning = 0
    abs_warning = 0
    rel_warning = 0
    abs_big = 0
    rel_big = 0
    
    for line in lines:
        line = line.strip()
        if line == "" and last_was_basin_line:
            no_warning += 1        
        if 'Processing' in line:
            basins_checked += 1
            last_was_basin_line = True
        else:
            last_was_basin_line = False
        if 'more than 0.1 m3/s different.' in line:
            abs_warning += 1
        if 'more than 1% different.' in line:
            rel_warning += 1
        if 'Absolute difference stats' in line:
            abs_big += 1
        if 'Relative difference stats' in line:
            rel_big += 1

    print(f"Total basins checked:                        {basins_checked}")
    print(f"Basins with no warnings:                     {no_warning}")
    print(f"Basins with absolute diff warning:           {abs_warning}")
    print(f"Basins with more than 750 abs diff warnings: {abs_warning}")
    print(f"Basins with relative diff warning:           {abs_big}")
    print(f"Basins with more than 750 rel diff warnings: {rel_big}")

# %%
def compare_netcdf_timeseries_scatter(file_list1, file_list2, var_name, color_var, save_dir):
    # Build dict for quick lookup by filename
    file_map2 = {Path(f).name: f for f in file_list2}

    for f1 in file_list1:
        name = Path(f1).name
        basin = f"{name.split('_')[0]}_{name.split('_')[1]}"
        f2 = file_map2.get(name)
        if not f2:
            print(f"No match found for {name} in second list. Skipping.")
            continue

        # Open both datasets
        ds1 = xr.open_dataset(f1)
        ds2 = xr.open_dataset(f2)

        # Extract variables and align by time
        var1 = ds1[var_name].to_series()
        var2 = ds2[var_name].to_series()
        color_series = ds2[color_var].to_series()

        # Align for scatter plot
        aligned1, aligned2 = var1.align(var2, join="inner")
        aligned_colors = color_series.reindex(aligned2.index)

        # ---- Plotting ----
        fig, axes = plt.subplots(2, 1, figsize=(12, 8), constrained_layout=True)

        # 1. Time series
        axes[0].plot(var1.index, var1.values, label="File 1")
        axes[0].plot(var2.index, var2.values, label="File 2", alpha=0.7)
        axes[0].set_ylabel(f"{var_name}  [m3 s-1]")
        axes[0].legend()

        # 2. Scatter plot
        scatter = axes[1].scatter(aligned1, 
                                  aligned2, 
                                  c=aligned_colors, 
                                  cmap="viridis", 
                                  alpha=0.7,
                                  vmin=0,
                                  vmax=1)
        axes[1].set_xlabel("Q_obs (File 1) [m3 s-1]")
        axes[1].set_ylabel("Q_obs (File 2) [m3 s-1]")
        plt.colorbar(scatter, ax=axes[1], label=color_var)

        all_vals = pd.concat([aligned1, aligned2])
        min_val, max_val = all_vals.min(), all_vals.max()
        axes[1].plot([min_val, max_val], [min_val, max_val], color="black", linestyle="--", linewidth=1)
                
        plt.suptitle(f"{basin}: old and new data")
        plt.savefig(save_dir/f"{basin}.png", dpi=150)
        plt.close()

        # Close datasets
        ds1.close()
        ds2.close()

# %%
# Make an even more temporary working dir
cs_tmp = cs_working_folder / f"tmp_new_csv_and_netcdf"
cs_tmp.mkdir(exist_ok=True, parents=True)

# %%
# Wrap the processing in a function that simply accepts an index
def process_new_file(new_file):

    # Setup
    # ----------------------------------------------------------------------
    # Extract the basin name from the file
    file_name = new_file.name
    basin = file_name.split("@")[1].split(".")[0]

    # Define the log path
    log_path = cs_tmp / f"log_{basin}.txt"
    log_message(log_path, f"Processing {basin}")

    # Get the associated row from the metadata
    row = cs_meta[cs_meta['Station_id'] == basin].iloc[0]

    # Output file (useful for resuming after interrupts
    nc_path = cs_tmp / f"{row.Country}_{basin}_hourly_flow_observations.nc"
    #if nc_path.exists():
    #    log_message(log_path, f"Basin {basin}: final netcdf already found. Skipping.")
    #    return f"Basin {basin} skipped (already complete)'"

    # Handle file header
    # ----------------------------------------------------------------------
    # Extract the header
    start_line = extract_csv_header_metadata(new_file, cs_tmp/f'header_{basin}.txt')
    
    # Get header values and match against expectations
    header_info = extract_metadata_fields_from_txt(cs_tmp/f'header_{basin}.txt')
    check_header_info(basin, row, header_info) # is discharge, is m3/s, same timezone as metadata

    # Process data
    # ----------------------------------------------------------------------
    # Read the xz file into memory
    df = pd.read_csv(new_file, skiprows=start_line-1, # line-1 accounts for 0-index
                     index_col=0, parse_dates=True,
                     usecols=range(5), # only get 'ISO 8601 UTC','Timestamp (UTC-HH:mm)', 'Value, 'Approval Level', 'Grade' 
                     low_memory=False)
    
    # Rename the columns
    df = df.rename(columns={'Value': 'Value/Valeur',
                            'Grade': 'Qualifier/Qualificatif',
                            'Approval Level': 'Approval/Approbation'})
    df.index.name = 'Date'
    
    # Subset the data to not go before or beyond what we already have forcing data for
    lst = row['dv_flow_obs_timezone'] # e.g. 'AST'
    tz_name = lst_to_tz_name(lst)
    time_s = min(pd.to_datetime(row['iv_flow_obs_availability_start']), 
                 pd.to_datetime(row['dv_flow_obs_availability_start'])).tz_localize(tz_name)
    time_e = max(pd.to_datetime(row['iv_flow_obs_availability_end']), 
                 pd.to_datetime(row['dv_flow_obs_availability_end'])).tz_localize(tz_name)
    raw = df.loc[time_s:time_e].copy()

    # Timezone stuff
    # ----------------------------------------------------------------------    
    # UTC to LST
    # 2a. Find what we're converting to
    #lst = row['dv_flow_obs_timezone'] # e.g. 'AST' - we already use this above
    utc = cs.tz_abbreviation_to_utc(lst) # e.g. 'UTC-04'
    offset = cs.relative_utc_to_timedelta(utc) # e.g. '+4:00:00'
    
    # 2b. Convert the UTC timestamps into Local Standard Time
    raw['datetime_str'] = raw.index.astype(str)
    raw['offset_str'] = raw['datetime_str'].apply(extract_offset)
    # ensure that we know that what we're modifying is in fact UTC
    assert all(raw['offset_str'] == '+00:00'), f'Not all timezone offsets are +00:00'
    raw.index = raw.index.tz_convert(None) + pd.Timedelta(offset)
    
    # Check that we now match the Local time column
    timestamp_col = next(col for col in df.columns if col.startswith("Timestamp (UTC-"))
    
    # 2c. Clean up the extra columns
    raw = raw.drop(['datetime_str','offset_str'], axis=1)
    
    # 2d. Replace any streamflow codes that are not part of the docs with 0
    known_codes = set([-1, 10, 20, 30, 40, 50])
    is_known = raw['Qualifier/Qualificatif'].isin(known_codes) | raw['Qualifier/Qualificatif'].isna()
    invalid_values = raw.loc[~is_known, 'Qualifier/Qualificatif']
    n_replaced = invalid_values.shape[0]
    unique_replaced = invalid_values.unique()
    raw['Qualifier/Qualificatif'] = raw['Qualifier/Qualificatif'].where(is_known, 0)
    if n_replaced > 0:
        log_message(log_path, f"Basin {basin}: Replaced {n_replaced} value(s): {', '.join(map(str, unique_replaced))}")
    
    # 2e. Replace any random statuses that don't exist in the docs
    raw.loc[raw['Approval/Approbation'] == 'Checked', 'Approval/Approbation'] = 'Reviewed'
    raw.loc[raw['Approval/Approbation'] == 'Ready for Approval', 'Approval/Approbation'] = 'Reviewed'
    raw.loc[raw['Approval/Approbation'] == 'Undefined', 'Approval/Approbation'] = 'nan'

    # hourly average
    # ---------------------------------------------------------------------- 
    # 3a. Create a temporary dataframe for hourly averaging
    tmp = raw.copy()
    tmp = tmp.drop(columns={'Qualifier/Qualificatif','Approval/Approbation',  # remove the QC column
                            timestamp_col})

    # 3b. Replace any negative streamflow values with nan
    tmp.loc[tmp['Value/Valeur'] < 0, 'Value/Valeur'] = np.nan   

    # 4. Create hourly average flow rates
    _,raw_H = cs.resample_arbitrary_flux_observations_to_hourly(tmp, data='Value/Valeur', center_window=False)   

    # 5. Assign quality flags to the dataframe
    raw['Qualifier/Qualificatif'] = raw['Qualifier/Qualificatif'].fillna(0).astype(int) # Replace any NaN with 0 (unknown)
    raw_H = cs.assign_hourly_quality_flag(raw, raw_H, 'CAN', center_window=False)

    # 6. Check that we have similar values now as in the existing file
    # Note that there will be some differences due to two reasons:
    # - the old files had flow values in 3 decimals, the new ones use 6
    # - most of the old files were "provisional" data, in the new ones all should be final
    old_file_path = old_nc_lookup[old_nc_lookup['basin'] == f"CAN_{basin}"]['path'].iloc[0]
    compare_netcdf_dataframe_hourly_values(raw_H, old_file_path, basin, log=log_path)

    # 7. Save the hourly file as .csv
    csv_path = cs_tmp/f'{basin}_hourly.csv'
    raw_H.to_csv(csv_path)

    # hourly netcdf
    # ---------------------------------------------------------------------- 
    # 8. Load the csv
    csv = cs.prep_subdaily_country_csv_for_netcdf(csv_path,row.Country)
    
    # 9. Convert to netcdf and save
    ds = subdaily_flow_csv_to_netcdf(csv, nc_path, row.Country, basin, lst, False) # False to set center_window = False
    ds.close()

    return f"Basin {basin} complete"

# %%
with ProcessPoolExecutor(max_workers=30) as executor:
    results = list(executor.map(process_new_file, new_files))
# Out:
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/857485775.py:21: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values

# %%
# Check the outcomes
print(f"Results contains entries for {len(results)} out of {len(new_files)} expected")

# Check the logs
merge_logs(cs_tmp, cs_tmp/'logs_merged.txt', pattern="log_*.txt")
summarize_log(cs_tmp/'logs_merged.txt')
# Out:
# Results contains entries for 764 out of 764 expected
# Merged 764 files into /scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/tmp_new_csv_and_netcdf/logs_merged.txt
# Total basins checked:                        764
# Basins with no warnings:                     6
# Basins with absolute diff warning:           644
# Basins with more than 750 abs diff warnings: 644
# Basins with relative diff warning:           321
# Basins with more than 750 rel diff warnings: 434

# %%
# Create summary plots
new_files = list(cs_tmp.glob('CAN_*_hourly_flow_observations.nc'))
old_files = []
for obs_path_part2 in obs_path_parts2:
    old_files.extend(
        list(
            (cs_update_folder / obs_path_part1 / obs_path_part2 / obs_path_part3).glob('CAN_*_hourly_flow_observations.nc')
        )
    )

cs_img = cs_working_folder / 'img'
cs_img.mkdir(exist_ok=True, parents=True)

compare_netcdf_timeseries_scatter(old_files, new_files, 
                                  'q_obs', 'q_obs_is_ice_affected',
                                  cs_img)

# %%
# Update the metadata file with new start and end times, and missing values
cs_meta = pd.read_csv(cs_main_folder / "camels-spat-metadata.csv") # reload the file

# loop
for new_file in new_files:
    basin = new_file.name.split("_")[1]
    basin_mask = cs_meta['Station_id'] == basin
    ds = xr.open_dataset(new_file)
    h_start = pd.to_datetime(ds['time'][0].values).strftime('%Y-%m-%d %X')
    h_end = pd.to_datetime(ds['time'][-1].values).strftime('%Y-%m-%d %X')
    cs_meta.loc[basin_mask,'iv_flow_obs_availability_start'] = h_start
    cs_meta.loc[basin_mask,'iv_flow_obs_availability_end'] = h_end
    cs_meta.loc[basin_mask,'flow_obs_missing_hourly'] = ds['q_obs'].isnull().sum()
    ds.close()

# %%
# Save new metadata to file
cs_meta.to_csv(cs_update_folder / "camels-spat-metadata.csv", index=False)

# %% [markdown]
# ### Replace existing netcdf files with these longer new ones

# %%
import hashlib
import shutil

# %%
def file_hash(path, algo='sha256'):
    hasher = hashlib.new(algo)
    with open(path, 'rb') as f:
        for chunk in iter(lambda: f.read(4096), b""):
            hasher.update(chunk)
    return hasher.hexdigest()

# %%
for new_file in new_files:

    # identify where we want to move this file
    file_name = new_file.name
    mask = old_nc_lookup['filename'] == file_name
    assert mask.sum() == 1, "Indentified file paths not equal to 1"
    move_here = old_nc_lookup[mask]['path'].iloc[0]

    # we want to be sure the move succeeded, so we'll compute a hash before and after move
    src_hash = file_hash(new_file)
    shutil.copy(new_file, move_here)
    dst_hash = file_hash(move_here)
    assert src_hash == dst_hash, f"Basin {basin}: file copy may not have succeeded."

# %% [markdown]
# ### BACKUP (SERIAL CODE)

# %%
# Loop over the new files and process into hourly netcdfs
for ix,new_file in enumerate(new_files):

    # Setup
    # ----------------------------------------------------------------------
    # Extract the basin name from the file
    file_name = new_file.name
    basin = file_name.split("@")[1].split(".")[0]
    print(f"\n{ix:03}. Processing {basin}")

    # Get the associated row from the metadata
    row = cs_meta[cs_meta['Station_id'] == basin].iloc[0]

    # Output file (useful for resuming after interrupts
    nc_path = cs_tmp / f"{row.Country}_{basin}_hourly_flow_observations.nc"
    if nc_path.exists():
        print(f"Basin {basin}: final netcdf already found. Skipping.")
        continue

    # Handle file header
    # ----------------------------------------------------------------------
    # Extract the header
    start_line = extract_csv_header_metadata(new_file, cs_tmp/f'header_{basin}.txt')
    
    # Get header values and match against expectations
    header_info = extract_metadata_fields_from_txt(cs_tmp/f'header_{basin}.txt')
    check_header_info(basin, row, header_info) # is discharge, is m3/s, same timezone as metadata

    # Process data
    # ----------------------------------------------------------------------
    # Read the xz file into memory
    df = pd.read_csv(new_file, skiprows=start_line-1, # line-1 accounts for 0-index
                     index_col=0, parse_dates=True,
                     usecols=range(5), # only get 'ISO 8601 UTC','Timestamp (UTC-HH:mm)', 'Value, 'Approval Level', 'Grade' 
                     low_memory=False)
    
    # Rename the columns
    df = df.rename(columns={'Value': 'Value/Valeur',
                            'Grade': 'Qualifier/Qualificatif',
                            'Approval Level': 'Approval/Approbation'})
    df.index.name = 'Date'
    
    # Subset the data to not go before or beyond what we already have forcing data for
    lst = row['dv_flow_obs_timezone'] # e.g. 'AST'
    tz_name = lst_to_tz_name(lst)
    time_s = min(pd.to_datetime(row['iv_flow_obs_availability_start']), 
                 pd.to_datetime(row['dv_flow_obs_availability_start'])).tz_localize(tz_name)
    time_e = max(pd.to_datetime(row['iv_flow_obs_availability_end']), 
                 pd.to_datetime(row['dv_flow_obs_availability_end'])).tz_localize(tz_name)
    raw = df.loc[time_s:time_e].copy()

    # Timezone stuff
    # ----------------------------------------------------------------------    
    # UTC to LST
    # 2a. Find what we're converting to
    #lst = row['dv_flow_obs_timezone'] # e.g. 'AST' - we already use this above
    utc = cs.tz_abbreviation_to_utc(lst) # e.g. 'UTC-04'
    offset = cs.relative_utc_to_timedelta(utc) # e.g. '+4:00:00'
    
    # 2b. Convert the UTC timestamps into Local Standard Time
    raw['datetime_str'] = raw.index.astype(str)
    raw['offset_str'] = raw['datetime_str'].apply(extract_offset)
    # ensure that we know that what we're modifying is in fact UTC
    assert all(raw['offset_str'] == '+00:00'), f'Not all timezone offsets are +00:00'
    raw.index = raw.index.tz_convert(None) + pd.Timedelta(offset)
    
    # Check that we now match the Local time column
    timestamp_col = next(col for col in df.columns if col.startswith("Timestamp (UTC-"))
    
    # 2c. Clean up the extra columns
    raw = raw.drop(['datetime_str','offset_str'], axis=1)
    
    # 2d. Replace any streamflow codes that are not part of the docs with 0
    known_codes = set([-1, 10, 20, 30, 40, 50])
    is_known = raw['Qualifier/Qualificatif'].isin(known_codes) | raw['Qualifier/Qualificatif'].isna()
    invalid_values = raw.loc[~is_known, 'Qualifier/Qualificatif']
    n_replaced = invalid_values.shape[0]
    unique_replaced = invalid_values.unique()
    raw['Qualifier/Qualificatif'] = raw['Qualifier/Qualificatif'].where(is_known, 0)
    if n_replaced > 0:
        print(f"Basin {basin}: Replaced {n_replaced} value(s): {', '.join(map(str, unique_replaced))}")
    
    # 2e. Replace any random statuses that don't exist in the docs
    raw.loc[raw['Approval/Approbation'] == 'Checked', 'Approval/Approbation'] = 'Reviewed'
    raw.loc[raw['Approval/Approbation'] == 'Ready for Approval', 'Approval/Approbation'] = 'Reviewed'
    raw.loc[raw['Approval/Approbation'] == 'Undefined', 'Approval/Approbation'] = 'nan'

    # hourly average
    # ---------------------------------------------------------------------- 
    # 3a. Create a temporary dataframe for hourly averaging
    tmp = raw.copy()
    tmp = tmp.drop(columns={'Qualifier/Qualificatif','Approval/Approbation',  # remove the QC column
                            timestamp_col})

    # 3b. Replace any negative streamflow values with nan
    tmp.loc[tmp['Value/Valeur'] < 0, 'Value/Valeur'] = np.nan   

    # 4. Create hourly average flow rates
    _,raw_H = cs.resample_arbitrary_flux_observations_to_hourly(tmp, data='Value/Valeur', center_window=False)   

    # 5. Assign quality flags to the dataframe
    raw['Qualifier/Qualificatif'] = raw['Qualifier/Qualificatif'].fillna(0).astype(int) # Replace any NaN with 0 (unknown)
    raw_H = cs.assign_hourly_quality_flag(raw, raw_H, 'CAN', center_window=False)

    # 6. Check that we have similar values now as in the existing file
    # Note that there will be some differences due to two reasons:
    # - the old files had flow values in 3 decimals, the new ones use 6
    # - most of the old files were "provisional" data, in the new ones all should be final
    old_file_path = old_nc_lookup[old_nc_lookup['basin'] == f"CAN_{basin}"]['path'].iloc[0]
    compare_netcdf_dataframe_hourly_values(raw_H, old_file_path, basin)

    # 7. Save the hourly file as .csv
    csv_path = cs_tmp/'hourly.csv'
    raw_H.to_csv(csv_path)

    # hourly netcdf
    # ---------------------------------------------------------------------- 
    # 8. Load the csv
    csv = cs.prep_subdaily_country_csv_for_netcdf(csv_path,row.Country)
    
    # 9. Convert to netcdf and save
    ds = subdaily_flow_csv_to_netcdf(csv, nc_path, row.Country, basin, lst, False) # False to set center_window = False
    ds.close()

    # metadata update
    # ---------------------------------------------------------------------- 
    # 10. Update metadata start and end date
    # We'll do this at the very end, after we've ensured we've not lost any data
    basin_mask = cs_meta['Station_id'] == basin
    h_start = pd.to_datetime(ds['time'][0].values).strftime('%Y-%m-%d %X')
    h_end = pd.to_datetime(ds['time'][-1].values).strftime('%Y-%m-%d %X')
    cs_meta.loc[basin_mask,'iv_flow_obs_availability_start'] = h_start
    cs_meta.loc[basin_mask,'iv_flow_obs_availability_end'] = h_end
    cs_meta.loc[basin_mask,'flow_obs_missing_hourly'] = ds['q_obs'].isnull().sum()
# Out:
# 000. Processing 05BL022
# Basin 05BL022: final netcdf already found. Skipping.
#
# 001. Processing 05MC003
# Basin 05MC003: final netcdf already found. Skipping.
#
# 002. Processing 07AA001
# Basin 07AA001: final netcdf already found. Skipping.
#
# 003. Processing 08KA001
# Basin 08KA001: final netcdf already found. Skipping.
#
# 004. Processing 10FA002
# Basin 10FA002: final netcdf already found. Skipping.
#
# 005. Processing 08NN015
# Basin 08NN015: final netcdf already found. Skipping.
#
# 006. Processing 05DB002
# Basin 05DB002: final netcdf already found. Skipping.
#
# 007. Processing 02CG003
# Basin 02CG003: final netcdf already found. Skipping.
#
# 008. Processing 02FE011
# Basin 02FE011: final netcdf already found. Skipping.
#
# 009. Processing 02EC018
# Basin 02EC018: final netcdf already found. Skipping.
#
# 010. Processing 07JC001
# Basin 07JC001: final netcdf already found. Skipping.
#
# 011. Processing 02ZA002
# Basin 02ZA002: final netcdf already found. Skipping.
#
# 012. Processing 08MA003
# Basin 08MA003: final netcdf already found. Skipping.
#
# 013. Processing 10ED003
# Basin 10ED003: final netcdf already found. Skipping.
#
# 014. Processing 02ZM016
# Basin 02ZM016: final netcdf already found. Skipping.
#
# 015. Processing 02GH002
# Basin 02GH002: final netcdf already found. Skipping.
#
# 016. Processing 02FE014
# Basin 02FE014: final netcdf already found. Skipping.
#
# 017. Processing 08KH019
# Basin 08KH019: final netcdf already found. Skipping.
#
# 018. Processing 09BA001
# Basin 09BA001: final netcdf already found. Skipping.
#
# 019. Processing 05CE002
# Basin 05CE002: final netcdf already found. Skipping.
#
# 020. Processing 07GG001
# Basin 07GG001: final netcdf already found. Skipping.
#
# 021. Processing 07EB002
# Basin 07EB002: final netcdf already found. Skipping.
#
# 022. Processing 02ZG003
# Basin 02ZG003: final netcdf already found. Skipping.
#
# 023. Processing 01AD003
# Basin 01AD003: final netcdf already found. Skipping.
#
# 024. Processing 05LL015
# Basin 05LL015: final netcdf already found. Skipping.
#
# 025. Processing 01AK006
# Basin 01AK006: final netcdf already found. Skipping.
#
# 026. Processing 07BK005
# Basin 07BK005: final netcdf already found. Skipping.
#
# 027. Processing 02DC012
# Basin 02DC012: final netcdf already found. Skipping.
#
# 028. Processing 07GE003
# Basin 07GE003: final netcdf already found. Skipping.
#
# 029. Processing 05RB003
# Basin 05RB003: final netcdf already found. Skipping.
#
# 030. Processing 02ZM006
# Basin 02ZM006: final netcdf already found. Skipping.
#
# 031. Processing 10KB001
# Basin 10KB001: final netcdf already found. Skipping.
#
# 032. Processing 02ZH002
# Basin 02ZH002: final netcdf already found. Skipping.
#
# 033. Processing 05OF014
# Basin 05OF014: final netcdf already found. Skipping.
#
# 034. Processing 05OE006
# Basin 05OE006: final netcdf already found. Skipping.
#
# 035. Processing 08NL069
# Basin 08NL069: final netcdf already found. Skipping.
#
# 036. Processing 05OJ008
# Basin 05OJ008: final netcdf already found. Skipping.
#
# 037. Processing 08NJ130
# Basin 08NJ130: final netcdf already found. Skipping.
#
# 038. Processing 08GA075
# Basin 08GA075: final netcdf already found. Skipping.
#
# 039. Processing 02ZN002
# Basin 02ZN002: final netcdf already found. Skipping.
#
# 040. Processing 02ED017
# Basin 02ED017: final netcdf already found. Skipping.
#
# 041. Processing 09AG001
# Basin 09AG001: final netcdf already found. Skipping.
#
# 042. Processing 02YO008
# Basin 02YO008: final netcdf already found. Skipping.
#
# 043. Processing 07EA007
# Basin 07EA007: final netcdf already found. Skipping.
#
# 044. Processing 08AA009
# Basin 08AA009: final netcdf already found. Skipping.
#
# 045. Processing 07AC008
# Basin 07AC008: final netcdf already found. Skipping.
#
# 046. Processing 07DA008
# Basin 07DA008: final netcdf already found. Skipping.
#
# 047. Processing 07CA013
# Basin 07CA013: final netcdf already found. Skipping.
#
# 048. Processing 08LE077
# Basin 08LE077: final netcdf already found. Skipping.
#
# 049. Processing 02ZL005
# Basin 02ZL005: final netcdf already found. Skipping.
#
# 050. Processing 08NE008
# Basin 08NE008: final netcdf already found. Skipping.
#
# 051. Processing 02LA007
# Basin 02LA007: final netcdf already found. Skipping.
#
# 052. Processing 08NB014
# Basin 08NB014: final netcdf already found. Skipping.
#
# 053. Processing 05JJ009
# Basin 05JJ009: final netcdf already found. Skipping.
#
# 054. Processing 02FF008
# Basin 02FF008: final netcdf already found. Skipping.
#
# 055. Processing 02HA020
# Basin 02HA020: final netcdf already found. Skipping.
#
# 056. Processing 08NE074
# Basin 08NE074: final netcdf already found. Skipping.
#
# 057. Processing 05BG006
# Basin 05BG006: final netcdf already found. Skipping.
#
# 058. Processing 05PH003
# Basin 05PH003: final netcdf already found. Skipping.
#
# 059. Processing 07EE010
# Basin 07EE010: final netcdf already found. Skipping.
#
# 060. Processing 07BJ001
# Basin 07BJ001: final netcdf already found. Skipping.
#
# 061. Processing 08OA004
# Basin 08OA004: final netcdf already found. Skipping.
#
# 062. Processing 02FA002
# Basin 02FA002: final netcdf already found. Skipping.
#
# 063. Processing 08NE114
# Basin 08NE114: final netcdf already found. Skipping.
#
# 064. Processing 04JD005
# Basin 04JD005: final netcdf already found. Skipping.
#
# 065. Processing 08NM174
# Basin 08NM174: final netcdf already found. Skipping.
#
# 066. Processing 05NG012
# Basin 05NG012: final netcdf already found. Skipping.
#
# 067. Processing 05OC019
# Basin 05OC019: final netcdf already found. Skipping.
#
# 068. Processing 07GD001
# Basin 07GD001: final netcdf already found. Skipping.
#
# 069. Processing 02ED015
# Basin 02ED015: final netcdf already found. Skipping.
#
# 070. Processing 10CB001
# Basin 10CB001: final netcdf already found. Skipping.
#
# 071. Processing 02YK005
# Basin 02YK005: final netcdf already found. Skipping.
#
# 072. Processing 05EA005
# Basin 05EA005: final netcdf already found. Skipping.
#
# 073. Processing 08CD001
# Basin 08CD001: final netcdf already found. Skipping.
#
# 074. Processing 02HC049
# Basin 02HC049: final netcdf already found. Skipping.
#
# 075. Processing 08MF068
# Basin 08MF068: final netcdf already found. Skipping.
#
# 076. Processing 08EG012
# Basin 08EG012: final netcdf already found. Skipping.
#
# 077. Processing 05OE009
# Basin 05OE009: final netcdf already found. Skipping.
#
# 078. Processing 07CE002
# Basin 07CE002: final netcdf already found. Skipping.
#
# 079. Processing 07HC002
# Basin 07HC002: final netcdf already found. Skipping.
#
# 080. Processing 05AH047
# Basin 05AH047: final netcdf already found. Skipping.
#
# 081. Processing 09DD004
# Basin 09DD004: final netcdf already found. Skipping.
#
# 082. Processing 08EE004
# Basin 08EE004: final netcdf already found. Skipping.
#
# 083. Processing 05OF020
# Basin 05OF020: final netcdf already found. Skipping.
#
# 084. Processing 05QA004
# Basin 05QA004: final netcdf already found. Skipping.
#
# 085. Processing 10EA003
# Basin 10EA003: final netcdf already found. Skipping.
#
# 086. Processing 01AK007
# Basin 01AK007: final netcdf already found. Skipping.
#
# 087. Processing 04CA003
# Basin 04CA003: final netcdf already found. Skipping.
#
# 088. Processing 01BC001
# Basin 01BC001: final netcdf already found. Skipping.
#
# 089. Processing 01CD005
# Basin 01CD005: final netcdf already found. Skipping.
#
# 090. Processing 07GG003
# Basin 07GG003: final netcdf already found. Skipping.
#
# 091. Processing 05CA002
# Basin 05CA002: final netcdf already found. Skipping.
#
# 092. Processing 06BD001
# Basin 06BD001: final netcdf already found. Skipping.
#
# 093. Processing 08HB048
# Basin 08HB048: final netcdf already found. Skipping.
#
# 094. Processing 06FB002
# Basin 06FB002: final netcdf already found. Skipping.
#
# 095. Processing 05RC001
# Basin 05RC001: final netcdf already found. Skipping.
#
# 096. Processing 05CB001
# Basin 05CB001: final netcdf already found. Skipping.
#
# 097. Processing 07GF001
# Basin 07GF001: final netcdf already found. Skipping.
#
# 098. Processing 01AM001
# Basin 01AM001: final netcdf already found. Skipping.
#
# 099. Processing 05LD001
# Basin 05LD001: final netcdf already found. Skipping.
#
# 100. Processing 08KE024
# Basin 08KE024: final netcdf already found. Skipping.
#
# 101. Processing 10LC007
# Basin 10LC007: final netcdf already found. Skipping.
#
# 102. Processing 05DA009
# Basin 05DA009: final netcdf already found. Skipping.
#
# 103. Processing 02ED026
# Basin 02ED026: final netcdf already found. Skipping.
#
# 104. Processing 08KA005
# Basin 08KA005: final netcdf already found. Skipping.
#
# 105. Processing 05AA008
# Basin 05AA008: final netcdf already found. Skipping.
#
# 106. Processing 05AH050
# Basin 05AH050: final netcdf already found. Skipping.
#
# 107. Processing 09AE006
# Basin 09AE006: final netcdf already found. Skipping.
#
# 108. Processing 02LB020
# Basin 02LB020: final netcdf already found. Skipping.
#
# 109. Processing 08NJ013
# Basin 08NJ013: final netcdf already found. Skipping.
#
# 110. Processing 02KF017
# Basin 02KF017: final netcdf already found. Skipping.
#
# 111. Processing 08MH001
# Basin 08MH001: final netcdf already found. Skipping.
#
# 112. Processing 02ZG001
# Basin 02ZG001: final netcdf already found. Skipping.
#
# 113. Processing 08LG016
# Basin 08LG016: final netcdf already found. Skipping.
#
# 114. Processing 08LB076
# Basin 08LB076: final netcdf already found. Skipping.
#
# 115. Processing 02HK007
# Basin 02HK007: final netcdf already found. Skipping.
#
# 116. Processing 05NB035
# Basin 05NB035: final netcdf already found. Skipping.
#
# 117. Processing 08ME023
# Basin 08ME023: final netcdf already found. Skipping.
#
# 118. Processing 02YQ001
# Basin 02YQ001: final netcdf already found. Skipping.
#
# 119. Processing 08HB086
# Basin 08HB086: final netcdf already found. Skipping.
#
# 120. Processing 05TG006
# Basin 05TG006: final netcdf already found. Skipping.
#
# 121. Processing 07AF014
# Basin 07AF014: final netcdf already found. Skipping.
#
# 122. Processing 07FD011
# Basin 07FD011: final netcdf already found. Skipping.
#
# 123. Processing 06AA001
# Basin 06AA001: final netcdf already found. Skipping.
#
# 124. Processing 11AB117
# Basin 11AB117: final netcdf already found. Skipping.
#
# 125. Processing 01AL002
# Basin 01AL002: final netcdf already found. Skipping.
#
# 126. Processing 02HB012
# Basin 02HB012: Replaced 1 value(s): -2
# Basin 02HB012: 74/9821 values more than 1% different.
#
# 127. Processing 07FD012
# Basin 07FD012: Replaced 36 value(s): -2
# /tmp/ipykernel_3516413/3532253610.py:20: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# Basin 07FD012: 1436/5880 values more than 1% different.
#     Relative difference stats for 1436 mismatches:
#     Max rel diff: 1.4768
#     Mean rel diff: 0.2805
#     95th percentile: 1.0000
#
# 128. Processing 01EF001
# Basin 01EF001: Replaced 13 value(s): -2
# Basin 01EF001: 300/9794 values more than 0.1 m3/s different.
# Basin 01EF001: 1/9794 values more than 1% different.
#
# 129. Processing 08NB016
# Basin 08NB016: Replaced 907 value(s): -2
# Basin 08NB016: 1/9770 values more than 1% different.
#
# 130. Processing 08HF006
# Basin 08HF006: 1/9770 values more than 0.1 m3/s different.
# Basin 08HF006: 1/9770 values more than 1% different.
#
# 131. Processing 08ND012
# Basin 08ND012: 5852/9770 values more than 0.1 m3/s different.
#     Absolute difference stats for 5852 mismatches:
#     Max abs diff: 8.2040
#     Mean abs diff: 0.5340
#     95th percentile: 1.3824
# Basin 08ND012: 3804/9770 values more than 1% different.
#     Relative difference stats for 3804 mismatches:
#     Max rel diff: 0.6595
#     Mean rel diff: 0.0920
#     95th percentile: 0.2211
#
# 132. Processing 05EA002
# Basin 05EA002: Replaced 371 value(s): -2
# Basin 05EA002: 2813/5952 values more than 0.1 m3/s different.
#     Absolute difference stats for 2813 mismatches:
#     Max abs diff: 6.3212
#     Mean abs diff: 3.5226
#     95th percentile: 5.6075
# Basin 05EA002: 3134/5952 values more than 1% different.
#     Relative difference stats for 3134 mismatches:
#     Max rel diff: 8.7157
#     Mean rel diff: 3.7082
#     95th percentile: 8.1912
#
# 133. Processing 05LJ045
# /tmp/ipykernel_3516413/3532253610.py:20: RuntimeWarning: divide by zero encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# /tmp/ipykernel_3516413/3532253610.py:20: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# Basin 05LJ045: 2065/5880 values more than 0.1 m3/s different.
#     Absolute difference stats for 2065 mismatches:
#     Max abs diff: 10.6861
#     Mean abs diff: 1.2187
#     95th percentile: 2.8253
# Basin 05LJ045: 5040/5880 values more than 1% different.
#     Relative difference stats for 5040 mismatches:
#     Max rel diff: inf
#     Mean rel diff: inf
#     95th percentile: 1.0000
#
# 134. Processing 01EE005
# Basin 01EE005: Replaced 10 value(s): -2
# Basin 01EE005: 448/9794 values more than 0.1 m3/s different.
# Basin 01EE005: 1952/9794 values more than 1% different.
#     Relative difference stats for 1952 mismatches:
#     Max rel diff: 0.5948
#     Mean rel diff: 0.0942
#     95th percentile: 0.3013
#
# 135. Processing 07DA006
# Basin 07DA006: 1/9774 values more than 1% different.
#
# 136. Processing 05QE012
# Basin 05QE012: 603/9770 values more than 0.1 m3/s different.
# Basin 05QE012: 3018/9770 values more than 1% different.
#     Relative difference stats for 3018 mismatches:
#     Max rel diff: 0.1001
#     Mean rel diff: 0.0139
#     95th percentile: 0.0188
#
# 137. Processing 08HA003
# Basin 08HA003: 20/9770 values more than 0.1 m3/s different.
# Basin 08HA003: 1/9770 values more than 1% different.
#
# 138. Processing 02ZF001
# Basin 02ZF001: 6064/9791 values more than 0.1 m3/s different.
#     Absolute difference stats for 6064 mismatches:
#     Max abs diff: 37.6942
#     Mean abs diff: 1.4103
#     95th percentile: 5.8925
# Basin 02ZF001: 4675/9791 values more than 1% different.
#     Relative difference stats for 4675 mismatches:
#     Max rel diff: 0.5830
#     Mean rel diff: 0.0298
#     95th percentile: 0.0750
#
# 139. Processing 05LJ007
# /tmp/ipykernel_3516413/3532253610.py:20: RuntimeWarning: invalid value encountered in true_divide
#   diff_rel = np.abs(aligned_df.values - aligned_xr.values) / aligned_df.values
# Basin 05LJ007: 3114/5879 values more than 0.1 m3/s different.
#     Absolute difference stats for 3114 mismatches:
#     Max abs diff: 58.2120
#     Mean abs diff: 2.1515
#     95th percentile: 4.4860
# Basin 05LJ007: 5497/5879 values more than 1% different.
#     Relative difference stats for 5497 mismatches:
#     Max rel diff: 5.5159
#     Mean rel diff: 0.1366
#     95th percentile: 0.6624
#
# 140. Processing 07DC001
# Basin 07DC001: 182/9775 values more than 0.1 m3/s different.
# Basin 07DC001: 1/9775 values more than 1% different.
#
# 141. Processing 05DB005
# Basin 05DB005: Replaced 17544 value(s): -2
# Basin 05DB005: 1675/6038 values more than 0.1 m3/s different.
#     Absolute difference stats for 1675 mismatches:
#     Max abs diff: 20.2437
#     Mean abs diff: 0.7180
#     95th percentile: 2.8674
# Basin 05DB005: 2641/6038 values more than 1% different.
#     Relative difference stats for 2641 mismatches:
#     Max rel diff: 0.4634
#     Mean rel diff: 0.1189
#     95th percentile: 0.3231
#
# 142. Processing 06DA004
# Basin 06DA004: 1845/9770 values more than 0.1 m3/s different.
#     Absolute difference stats for 1845 mismatches:
#     Max abs diff: 4.3975
#     Mean abs diff: 1.1236
#     95th percentile: 4.0293
# Basin 06DA004: 1427/9770 values more than 1% different.
#     Relative difference stats for 1427 mismatches:
#     Max rel diff: 0.1554
#     Mean rel diff: 0.0483
#     95th percentile: 0.1440
#
# 143. Processing 08LD001
# Basin 08LD001: 666/9770 values more than 0.1 m3/s different.
# Basin 08LD001: 1/9770 values more than 1% different.
#
# 144. Processing 05ME003
# Basin 05ME003: 3606/5880 values more than 0.1 m3/s different.
#     Absolute difference stats for 3606 mismatches:
#     Max abs diff: 4.0635
#     Mean abs diff: 0.8409
#     95th percentile: 2.6506
# Basin 05ME003: 4814/5880 values more than 1% different.
#     Relative difference stats for 4814 mismatches:
#     Max rel diff: 2.0342
#     Mean rel diff: 0.1698
#     95th percentile: 0.6322
#
# 145. Processing 02FE009
# Basin 02FE009: 1/9793 values more than 0.1 m3/s different.
# Basin 02FE009: 1/9793 values more than 1% different.
#
# 146. Processing 10LC003
# Basin 10LC003: Replaced 8 value(s): -2
# Basin 10LC003: 2969/9738 values more than 0.1 m3/s different.
#     Absolute difference stats for 2969 mismatches:
#     Max abs diff: 32.0926
#     Mean abs diff: 2.0697
#     95th percentile: 8.0762
# Basin 10LC003: 4249/9738 values more than 1% different.
#     Relative difference stats for 4249 mismatches:
#     Max rel diff: 156559.3926
#     Mean rel diff: 3789.9452
#     95th percentile: 8890.0353
#
# 147. Processing 08NE110
# Basin 08NE110: 1/9770 values more than 1% different.
#
# 148. Processing 05UF004
# Basin 05UF004: 1/9770 values more than 0.1 m3/s different.
# Basin 05UF004: 1/9770 values more than 1% different.
#
# 149. Processing 05CK001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3516413/3909739143.py in <module>
#     101     # 5. Assign quality flags to the dataframe
#     102     raw['Qualifier/Qualificatif'] = raw['Qualifier/Qualificatif'].fillna(0).astype(int) # Replace any NaN with 0 (unknown)
# --> 103     raw_H = cs.assign_hourly_quality_flag(raw, raw_H, 'CAN', center_window=False)
#     104
#     105     # 6. Check that we have similar values now as in the existing file
#
# ~/camels_spat/python_cs_functions/time_processing.py in assign_hourly_quality_flag(df, df_H, country, center_window)
#     478             dataq = subset['Qualifier/Qualificatif'].to_list() # Get data quality tag
#     479             merge = ["{}:{}".format(a_, b_) for a_, b_ in zip(flags, dataq)] # combine into a single list
# --> 480             df_H.at[row.name, 'minimum_data_quality'] = select_minimal_wsc_data_quality_flag(merge)
#     481
#     482         elif country == 'MEX':
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2271             return
#    2272
# -> 2273         return super().__setitem__(key, value)
#    2274
#    2275
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2226             raise ValueError("Not enough indexers for scalar access (setting)!")
#    2227
# -> 2228         self.obj._set_value(*key, value=value, takeable=self._takeable)
#    2229
#    2230
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/pandas/core/frame.py in _set_value(self, index, col, value, takeable)
#    3869
#    3870             series = self._get_item_cache(col)
# -> 3871             loc = self.index.get_loc(index)
#    3872             dtype = series.dtype
#    3873             if isinstance(dtype, np.dtype) and dtype.kind not in ["m", "M"]:
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py in get_loc(self, key, method, tolerance)
#     637             # needed to localize naive datetimes
#     638             self._deprecate_mismatched_indexing(key)
# --> 639             key = self._maybe_cast_for_get_loc(key)
#     640
#     641         elif isinstance(key, str):
#
# /cvmfs/soft.computecanada.ca/easybuild/software/2020/avx2/Core/scipy-stack/2022a/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py in _maybe_cast_for_get_loc(self, key)
#     685         key = Timestamp(key)
#     686         if key.tzinfo is None:
# --> 687             key = key.tz_localize(self.tz)
#     688         else:
#     689             key = key.tz_convert(self.tz)
#
# KeyboardInterrupt:

# %% [markdown]
# ## DEV

# %%
# we'll work through the whole process with 1 file first
new_file = new_files[0]
new_file
# Out:
# PosixPath('/scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/Discharge.Working@05BL022.20110101_corrected.csv.xz')

# %%
new_file = Path('/scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/Discharge.Working@10LC007.20110101_corrected.csv.xz')

# %%
new_file
# Out:
# PosixPath('/scratch/gwf/gwf_cmt/wknoben/camels-spat-wip/Discharge.Working@10LC007.20110101_corrected.csv.xz')

# %%
# Extract the basin name from the file
file_name = new_file.name
basin = file_name.split("@")[1].split(".")[0]

# %%
# Get the associated row from the metadata
row = cs_meta[cs_meta['Station_id'] == basin].iloc[0]

# %%
# Make an even more temporary working dir
cs_tmp = cs_working_folder / f"tmp_{basin}"
cs_tmp.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# #### Header

# %%
# Extract the header
start_line = extract_csv_header_metadata(new_file, cs_tmp/'header.txt')

# %%
# Get header values and match against expectations
header_info = extract_metadata_fields_from_txt(cs_tmp/'header.txt')
check_header_info(basin, row, header_info) # is discharge, is m3/s, same UTC as metadata

# %% [markdown]
# #### Data

# %%
# Read the xz file into memory
df = pd.read_csv(new_file, skiprows=start_line-1, # line-1 accounts for 0-index
                 index_col=0, parse_dates=True,
                 usecols=range(5), # only get 'ISO 8601 UTC','Timestamp (UTC-HH:mm)', 'Value, 'Approval Level', 'Grade' 
                 low_memory=False)

# %%
# Rename the columns
df = df.rename(columns={'Value': 'Value/Valeur',
                        'Grade': 'Qualifier/Qualificatif',
                        'Approval Level': 'Approval/Approbation'})
df.index.name = 'Date'

# %%
# Subset the data to not go before or beyond what we already have forcing data for
lst = row['dv_flow_obs_timezone'] # e.g. 'AST'
tz_name = lst_to_tz_name(lst)
time_s = min(pd.to_datetime(row['iv_flow_obs_availability_start']), 
             pd.to_datetime(row['dv_flow_obs_availability_start'])).tz_localize(tz_name)
time_e = max(pd.to_datetime(row['iv_flow_obs_availability_end']), 
             pd.to_datetime(row['dv_flow_obs_availability_end'])).tz_localize(tz_name)
raw = df.loc[time_s:time_e].copy()

# %% [markdown]
# #### Timezone

# %%
# UTC to LST
# 2a. Find what we're converting to
#lst = row['dv_flow_obs_timezone'] # e.g. 'AST' - we already use this above
utc = cs.tz_abbreviation_to_utc(lst) # e.g. 'UTC-04'
offset = cs.relative_utc_to_timedelta(utc) # e.g. '+4:00:00'
print(lst,utc,offset)
# Out:
# MST UTC-07 -7:00:00

# %%
# 2b. Convert the UTC timestamps into Local Standard Time
raw['datetime_str'] = raw.index.astype(str)
raw['offset_str'] = raw['datetime_str'].apply(extract_offset)
# ensure that we know that what we're modifying is in fact UTC
assert all(raw['offset_str'] == '+00:00'), f'Not all timezone offsets are +00:00'
raw.index = raw.index.tz_convert(None) + pd.Timedelta(offset)

# Check that we now match the Local time column
timestamp_col = next(col for col in df.columns if col.startswith("Timestamp (UTC-"))

# %%
# 2c. Clean up the extra columns
raw = raw.drop(['datetime_str','offset_str'], axis=1)

# %%
# 2d. Replace any streamflow codes that are not part of the docs with 0
known_codes = set([-1, 10, 20, 30, 40, 50])
is_known = raw['Qualifier/Qualificatif'].isin(known_codes) | raw['Qualifier/Qualificatif'].isna()
invalid_values = raw.loc[~is_known, 'Qualifier/Qualificatif']
n_replaced = invalid_values.shape[0]
unique_replaced = invalid_values.unique()
raw['Qualifier/Qualificatif'] = raw['Qualifier/Qualificatif'].where(is_known, 0)
print(f"Basin {basin}: Replaced {n_replaced} value(s): {', '.join(map(str, unique_replaced))}")
# Out:
# Basin 10LC007: Replaced 74 value(s): -2

# %%
# 2e. Replace any random statuses that don't exist in the docs
raw.loc[raw['Approval/Approbation'] == 'Checked', 'Approval/Approbation'] = 'Reviewed'
raw.loc[raw['Approval/Approbation'] == 'Ready for Approval', 'Approval/Approbation'] = 'Reviewed'
raw.loc[raw['Approval/Approbation'] == 'Undefined', 'Approval/Approbation'] = 'nan'

# %% [markdown]
# #### hourly average

# %%
# 3a. Create a temporary dataframe for hourly averaging
tmp = raw.copy()
tmp = tmp.drop(columns={'Qualifier/Qualificatif','Approval/Approbation',  # remove the QC column
                        timestamp_col})

# %%
# 3b. Replace any negative streamflow values with nan
tmp.loc[tmp['Value/Valeur'] < 0, 'Value/Valeur'] = np.nan

# %%
# 4. Create hourly average flow rates
_,raw_H = cs.resample_arbitrary_flux_observations_to_hourly(tmp, data='Value/Valeur', center_window=False)

# %%
# 5. Assign quality flags to the dataframe
raw['Qualifier/Qualificatif'] = raw['Qualifier/Qualificatif'].fillna(0).astype(int) # Replace any NaN with 0 (unknown)
raw_H = cs.assign_hourly_quality_flag(raw, raw_H, 'CAN', center_window=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3511447/2520311730.py in <module>
#       1 # 5. Assign quality flags to the dataframe
#       2 raw['Qualifier/Qualificatif'] = raw['Qualifier/Qualificatif'].fillna(0).astype(int) # Replace any NaN with 0 (unknown)
# ----> 3 raw_H = cs.assign_hourly_quality_flag(raw, raw_H, 'CAN', center_window=False)
#
# ~/camels_spat/python_cs_functions/time_processing.py in assign_hourly_quality_flag(df, df_H, country, center_window)
#     469             dataq = subset['Qualifier/Qualificatif'].to_list() # Get data quality tag
#     470             merge = ["{}:{}".format(a_, b_) for a_, b_ in zip(flags, dataq)] # combine into a single list
# --> 471             df_H.at[row.name, 'minimum_data_quality'] = select_minimal_wsc_data_quality_flag(merge)
#     472
#     473         elif country == 'MEX':
#
# ~/camels_spat/python_cs_functions/time_processing.py in select_minimal_wsc_data_quality_flag(flags)
#     410         for flag in flags:
#     411             if (type(flag) == float) and (np.isnan(flag)): flag = 'nan'
# --> 412             order.append(standards.index(flag))
#     413         min_qc = standards[min(order)]
#     414     else:
#
# ValueError: 'nan:10' is not in list

# %%
# 6. Check that we have similar values now as in the existing file
# Note that there will be some differences due to two reasons:
# - the old files had flow values in 3 decimals, the new ones use 6
# - most of the old files were "provisional" data, in the new ones all should be final
old_file_path = old_nc_lookup[old_nc_lookup['basin'] == f"CAN_{basin}"]['path'].iloc[0]

# %%
compare_netcdf_dataframe_hourly_values(raw_H, old_file_path, basin)
# Out:
# Basin 05BL022: 1/9774 values more than 0.1% different.

# %%
# 7. Save the hourly file as .csv
csv_path = cs_tmp/'hourly.csv'
raw_H.to_csv(csv_path)

# %% [markdown]
# #### make the netcdf

# %%
# 8. Load the csv
csv = cs.prep_subdaily_country_csv_for_netcdf(csv_path,row.Country)

# %%
nc_path = cs_tmp / f"{row.Country}_{basin}_hourly_flow_observations.nc"

# %%
# 9. Convert to netcdf and save
ds = subdaily_flow_csv_to_netcdf(csv, nc_path, row.Country, basin, lst, False) # False to set center_window = False
ds.close()

# %% [markdown]
# #### metadata

# %%
# 10. Update metadata start and end date
# We'll do this at the very end, after we've ensured we've not lost any data
basin_mask = cs_meta['Station_id'] == basin
h_start = pd.to_datetime(ds['time'][0].values).strftime('%Y-%m-%d %X')
h_end = pd.to_datetime(ds['time'][-1].values).strftime('%Y-%m-%d %X')
cs_meta.loc[basin_mask,'iv_flow_obs_availability_start'] = h_start
cs_meta.loc[basin_mask,'iv_flow_obs_availability_end'] = h_end
cs_meta.loc[basin_mask,'flow_obs_missing_hourly'] = ds['q_obs'].isnull().sum()

# %% [markdown]
# ## End DEV
